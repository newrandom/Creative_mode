# %%
import mysql
import mysql.connector
from selenium import *
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import sys, time
import pandas as pd

# ====================== #

# # host 정보 확인
# host = int(input('which is your host? 1. local / 2. server  >> '))
# if host == 1:
#     host = '192.168.35.159'
# elif host == 2:
#     host = input('input server address: ')
# else:
#     sys.exit()
    
mydb = mysql.connector.connect(host = '192.168.35.159', port = '3306', user='', password = '')
mydb

mycursor = mydb.cursor(buffered = True)

mycursor.execute('USE lotto_db')

# DB에 저장된 모든 회차 정보 조회
mycursor.execute('SELECT ID FROM lotto_nums ORDER BY ID DESC')
all_num_in_sql = mycursor.fetchall()
all_num_in_sql = [all_num_in_sql[i][0] for i in range(0,len(all_num_in_sql))]
# print(all_num_in_sql)       # 저장된 전체 회차 조회

# # DB에 저장된 최신 회차 정보 조회
# mycursor.execute('SELECT * FROM lotto_nums ORDER BY ID DESC LIMIT 1')
# latest_num_in_sql = mycursor.fetchall()
# print(latest_num_in_sql[0])
# print(f'DB에 저장된 최신회차는 : {latest_num_in_sql} 회차 입니다.')

# ================= 위의 쿼리 진행해보기 =============== #
# 로또 홈페이지 접속
service = Service('../chromedriver')
url = 'https://www.dhlottery.co.kr/gameResult.do?method=byWin'
try:
    driver = webdriver.Chrome(service = service)
except:
    print('chromedriver의 버전을 확인해 주세요 😣')
    time.sleep(2)
    sys.exit()

driver.get(url)


# 최신회차 조회
new = int(driver.find_element(By.XPATH, '//*[@id="dwrNoList"]').text.strip().split()[0])
print('최신 회차 : {}회'.format(new))

# 최신회차 검사
if new in all_num_in_sql:
    print('최신 회차 ({})가 DB에 저장되어 있습니다.'.format(new))

else:
    print('최신 회차 ({})가 저장되어 있지 않습니다. (현재 저장되어있는 최신회차 : {}회)'.format(new, all_num_in_sql[0]))
    q = int(input('최신회차 정보를 업데이트 하시겠습니까? (1 : yes, 2: no)'))
    if q == 1:

        for i in range(all_num_in_sql[0]+1, new+1):     # DB에 저장된 최신회차 + 1 부터 신규 회차까지 루프 > 데이터 저장
                        ## 콤보박스에서 맨 처음 숫자 1을 불러오지 못하는 현상 발생 >> 최신부터 역순으로 올라가는 순서를 고려할 것

            driver.find_element(By.XPATH, '//*[@id="dwrNoList"]').send_keys(i)
            driver.implicitly_wait(10)
            driver.find_element(By.XPATH, '//*[@id="searchBtn"]').send_keys(Keys.ENTER)

            nums = []
            for _ in range(1, 7):

                # 신규 회차의 로또번호 6개를 리스트에 넣기
                nums.append(driver.find_element(By.XPATH, '//*[@id="article"]/div[2]/div/div[2]/div/div[1]/p/span[{}]'.format(_)).text)

            # 새로운 회차 및 번호 DB에 저장
            print({i}, '회차가 저장됩니다.', '{}'.format(nums))
            mycursor.execute('INSERT INTO lotto_nums (ID, num1, num2, num3, num4, num5, num6) VALUES ({}, {}, {}, {}, {}, {}, {})'.format(i, nums[0],nums[1],nums[2],nums[3],nums[4],nums[5]))
                                            ## lotto_nums table desc : ID, num1 ~ num6
            mydb.commit()       # 커서의 쿼리 실행 저장

            # DB의 저장된 데이터 확인
            mycursor.execute('SELECT * FROM lotto_nums ORDER BY ID DESC LIMIT 1')
            latest_info = mycursor.fetchall()[0]
            print('{} 회차 : [{}, {}, {}, {}, {}, {}] 저장 됨'.format(latest_info[0], latest_info[1],latest_info[2],latest_info[3],latest_info[4],latest_info[5],latest_info[6]))
            
driver.close()
mydb.close()
# Out:
# 최신 회차 : 1024회
# 최신 회차 (1024)가 DB에 저장되어 있습니다.

# %%
## 새로운 테이블 만들기
import mysql
import mysql.connector
from selenium import *
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import sys, time
import pandas as pd

# ====================== #

# # host 정보 확인
# host = int(input('which is your host? 1. local / 2. server  >> '))
# if host == 1:
#     host = '192.168.35.159'
# elif host == 2:
#     host = input('input server address: ')
# else:
#     sys.exit()
    
mydb = mysql.connector.connect(host = '192.168.35.159', port = '3306', user='', password = '')
mydb

table_name = 'lot_num'      # table name 지정

mycursor = mydb.cursor(buffered = True)


## =========== get db ============= ##
mycursor.execute('USE lotto_db')

# DB 에 새로운 table 만들기
mycursor.execute('CREATE TABLE {} (ID INT NOT NULL AUTO_INCREMENT PRIMARY KEY, NUM1 INT NOT NULL, NUM2 INT NOT NULL, NUM3 INT NOT NULL, NUM4 INT NOT NULL, NUM5 INT NOT NULL, NUM6 INT NOT NULL)'.format(table_name))
mydb.commit()

# TABLE 의 DESC 확인
mycursor.execute('DESC {}'.format(table_name))
mycursor.fetchall()

# DB에 저장된 모든 회차 정보 조회
mycursor.execute('SELECT ID FROM {} ORDER BY ID DESC'.format(table_name))
all_num_in_sql = mycursor.fetchall()
all_num_in_sql = [all_num_in_sql[i][0] for i in range(0,len(all_num_in_sql))]
# print(all_num_in_sql)       # 저장된 전체 회차 조회

# # DB에 저장된 최신 회차 정보 조회
# mycursor.execute('SELECT * FROM {} ORDER BY ID DESC LIMIT 1'.format(table_name))
# latest_num_in_sql = mycursor.fetchall()
# print(latest_num_in_sql[0])
# print(f'TABLE에 저장된 최신회차는 : {latest_num_in_sql} 회차 입니다.')

# ================= 위의 쿼리 진행해보기 =============== #
# 로또 홈페이지 접속
service = Service('../chromedriver')
url = 'https://www.dhlottery.co.kr/gameResult.do?method=byWin'
try:
    driver = webdriver.Chrome(service = service)
except:
    print('chromedriver의 버전을 확인해 주세요 😣')
    time.sleep(2)
    sys.exit()

driver.get(url)


# 최신회차 조회
new = int(driver.find_element(By.XPATH, '//*[@id="dwrNoList"]').text.strip().split()[0])
print('최신 회차 : {}회'.format(new))

# 최신회차 검사
if new in all_num_in_sql:
    print('최신 회차 ({})가 DB에 저장되어 있습니다.'.format(new))

elif all_num_in_sql == []:
    print('TABLE 에 로또 정보가 없습니다.')
    q = int(input('웹에서 정보를 받아오시겠습니까? (1 : yes, 2: no) '))
    if q == 1:

        for i in range(1, new+1):     # 1회차 부터 신규 회차까지 루프 > 데이터 저장

            driver.find_element(By.XPATH, '//*[@id="dwrNoList"]').send_keys(i)
            driver.implicitly_wait(10)
            driver.find_element(By.XPATH, '//*[@id="searchBtn"]').send_keys(Keys.ENTER)

            nums = []
            for _ in range(1, 7):

                # 신규 회차의 로또번호 6개를 리스트에 넣기
                nums.append(driver.find_element(By.XPATH, '//*[@id="article"]/div[2]/div/div[2]/div/div[1]/p/span[{}]'.format(_)).text)

            # 새로운 회차 및 번호 DB에 저장
            print({i}, '회차가 저장됩니다.', '{}'.format(nums))
            mycursor.execute('INSERT INTO {} (ID, NUM1, NUM2, NUM3, NUM4, NUM5, NUM6) VALUES ({}, {}, {}, {}, {}, {}, {})'.format(table_name, i, nums[0],nums[1],nums[2],nums[3],nums[4],nums[5]))
                                            ## {table_name} table desc : ID, num1 ~ num6
            mydb.commit()       # 커서의 쿼리 실행 저장

            # DB의 저장된 데이터 확인
            mycursor.execute('SELECT * FROM {} ORDER BY ID DESC LIMIT 1'.format(table_name))
            latest_info = mycursor.fetchall()[0]
            print('{} 회차 : [{}, {}, {}, {}, {}, {}] 저장 됨'.format(latest_info[0], latest_info[1],latest_info[2],latest_info[3],latest_info[4],latest_info[5],latest_info[6]))
            
else:
    print('최신 회차 ({})가 저장되어 있지 않습니다. (현재 저장되어있는 최신회차 : {}회)'.format(new, all_num_in_sql[0]))
    q = int(input('최신회차 정보를 업데이트 하시겠습니까? (1 : yes, 2: no)'))
    if q == 1:

        for i in range(all_num_in_sql[0]+1, new+1):     # DB에 저장된 최신회차 + 1 부터 신규 회차까지 루프 > 데이터 저장

            driver.find_element(By.XPATH, '//*[@id="dwrNoList"]').send_keys(i)
            driver.implicitly_wait(10)
            driver.find_element(By.XPATH, '//*[@id="searchBtn"]').send_keys(Keys.ENTER)

            nums = []
            for _ in range(1, 7):

                # 신규 회차의 로또번호 6개를 리스트에 넣기
                nums.append(driver.find_element(By.XPATH, '//*[@id="article"]/div[2]/div/div[2]/div/div[1]/p/span[{}]'.format(_)).text)

            # 새로운 회차 및 번호 DB에 저장
            print({i}, '회차가 저장됩니다.', '{}'.format(nums))
            mycursor.execute('INSERT INTO {} (ID, NUM1, NUM2, NUM3, NUM4, NUM5, NUM6) VALUES ({}, {}, {}, {}, {}, {}, {})'.format(table_name, i, nums[0],nums[1],nums[2],nums[3],nums[4],nums[5]))
                                            ## {table_name} table desc : ID, num1 ~ num6
            mydb.commit()       # 커서의 쿼리 실행 저장

            # DB의 저장된 데이터 확인
            mycursor.execute('SELECT * FROM {} ORDER BY ID DESC LIMIT 1'.format(table_name))
            latest_info = mycursor.fetchall()[0]
            print('{} 회차 : [{}, {}, {}, {}, {}, {}] 저장 됨'.format(latest_info[0], latest_info[1],latest_info[2],latest_info[3],latest_info[4],latest_info[5],latest_info[6]))
            
driver.close()
mydb.close()
# Out:
# 최신 회차 : 1024회
# TABLE 에 로또 정보가 없습니다.
# {1} 회차가 저장됩니다. ['10', '14', '16', '18', '29', '35']
# 1 회차 : [10, 14, 16, 18, 29, 35] 저장 됨
# {2} 회차가 저장됩니다. ['1', '3', '20', '25', '36', '45']
# 2 회차 : [1, 3, 20, 25, 36, 45] 저장 됨
# {3} 회차가 저장됩니다. ['6', '7', '13', '15', '21', '43']
# 3 회차 : [6, 7, 13, 15, 21, 43] 저장 됨
# {4} 회차가 저장됩니다. ['14', '27', '30', '31', '40', '42']
# 4 회차 : [14, 27, 30, 31, 40, 42] 저장 됨
# {5} 회차가 저장됩니다. ['5', '12', '17', '29', '34', '35']
# 5 회차 : [5, 12, 17, 29, 34, 35] 저장 됨
# {6} 회차가 저장됩니다. ['5', '8', '14', '15', '19', '39']
# 6 회차 : [5, 8, 14, 15, 19, 39] 저장 됨
# {7} 회차가 저장됩니다. ['2', '9', '16', '25', '26', '40']
# 7 회차 : [2, 9, 16, 25, 26, 40] 저장 됨
# {8} 회차가 저장됩니다. ['8', '19', '20', '21', '33', '39']
# 8 회차 : [8, 19, 20, 21, 33, 39] 저장 됨
# {9} 회차가 저장됩니다. ['1', '3', '10', '27', '29', '37']
# 9 회차 : [1, 3, 10, 27, 29, 37] 저장 됨
# {10} 회차가 저장됩니다. ['9', '25', '30', '33', '41', '44']
# 10 회차 : [9, 25, 30, 33, 41, 44] 저장 됨
# {11} 회차가 저장됩니다. ['9', '18', '20', '22', '38', '44']
# 11 회차 : [9, 18, 20, 22, 38, 44] 저장 됨
# {12} 회차가 저장됩니다. ['19', '23', '25', '28', '38', '42']
# 12 회차 : [19, 23, 25, 28, 38, 42] 저장 됨
# {13} 회차가 저장됩니다. ['22', '23', '25', '37', '38', '42']
# 13 회차 : [22, 23, 25, 37, 38, 42] 저장 됨
# {14} 회차가 저장됩니다. ['2', '11', '21', '34', '41', '42']
# 14 회차 : [2, 11, 21, 34, 41, 42] 저장 됨
# {15} 회차가 저장됩니다. ['3', '4', '16', '30', '31', '37']
# 15 회차 : [3, 4, 16, 30, 31, 37] 저장 됨
# {16} 회차가 저장됩니다. ['16', '27', '35', '37', '43', '45']
# 16 회차 : [16, 27, 35, 37, 43, 45] 저장 됨
# {17} 회차가 저장됩니다. ['3', '4', '9', '17', '32', '37']
# 17 회차 : [3, 4, 9, 17, 32, 37] 저장 됨
# {18} 회차가 저장됩니다. ['8', '14', '32', '35', '37', '45']
# 18 회차 : [8, 14, 32, 35, 37, 45] 저장 됨
# {19} 회차가 저장됩니다. ['6', '30', '38', '39', '40', '43']
# 19 회차 : [6, 30, 38, 39, 40, 43] 저장 됨
# {20} 회차가 저장됩니다. ['2', '7', '18', '20', '24', '33']
# 20 회차 : [2, 7, 18, 20, 24, 33] 저장 됨
# {21} 회차가 저장됩니다. ['6', '12', '17', '18', '31', '32']
# 21 회차 : [6, 12, 17, 18, 31, 32] 저장 됨
# {22} 회차가 저장됩니다. ['9', '13', '21', '25', '32', '42']
# 22 회차 : [9, 13, 21, 25, 32, 42] 저장 됨
# {23} 회차가 저장됩니다. ['11', '15', '24', '39', '41', '44']
# 23 회차 : [11, 15, 24, 39, 41, 44] 저장 됨
# {24} 회차가 저장됩니다. ['7', '8', '27', '29', '36', '43']
# 24 회차 : [7, 8, 27, 29, 36, 43] 저장 됨
# {25} 회차가 저장됩니다. ['4', '5', '14', '35', '42', '45']
# 25 회차 : [4, 5, 14, 35, 42, 45] 저장 됨
# {26} 회차가 저장됩니다. ['4', '5', '7', '18', '20', '25']
# 26 회차 : [4, 5, 7, 18, 20, 25] 저장 됨
# {27} 회차가 저장됩니다. ['7', '16', '31', '36', '37', '38']
# 27 회차 : [7, 16, 31, 36, 37, 38] 저장 됨
# {28} 회차가 저장됩니다. ['9', '18', '23', '25', '35', '37']
# 28 회차 : [9, 18, 23, 25, 35, 37] 저장 됨
# {29} 회차가 저장됩니다. ['1', '3', '20', '25', '36', '45']
# 29 회차 : [1, 3, 20, 25, 36, 45] 저장 됨
# {30} 회차가 저장됩니다. ['8', '17', '20', '35', '36', '44']
# 30 회차 : [8, 17, 20, 35, 36, 44] 저장 됨
# {31} 회차가 저장됩니다. ['5', '8', '22', '28', '33', '42']
# 31 회차 : [5, 8, 22, 28, 33, 42] 저장 됨
# {32} 회차가 저장됩니다. ['6', '14', '19', '25', '34', '44']
# 32 회차 : [6, 14, 19, 25, 34, 44] 저장 됨
# {33} 회차가 저장됩니다. ['8', '17', '20', '35', '36', '44']
# 33 회차 : [8, 17, 20, 35, 36, 44] 저장 됨
# {34} 회차가 저장됩니다. ['5', '13', '14', '20', '24', '25']
# 34 회차 : [5, 13, 14, 20, 24, 25] 저장 됨
# {35} 회차가 저장됩니다. ['2', '3', '11', '26', '37', '43']
# 35 회차 : [2, 3, 11, 26, 37, 43] 저장 됨
# {36} 회차가 저장됩니다. ['17', '20', '35', '36', '41', '43']
# 36 회차 : [17, 20, 35, 36, 41, 43] 저장 됨
# {37} 회차가 저장됩니다. ['7', '27', '30', '33', '35', '37']
# 37 회차 : [7, 27, 30, 33, 35, 37] 저장 됨
# {38} 회차가 저장됩니다. ['7', '16', '18', '20', '23', '26']
# 38 회차 : [7, 16, 18, 20, 23, 26] 저장 됨
# {39} 회차가 저장됩니다. ['6', '7', '13', '15', '21', '43']
# 39 회차 : [6, 7, 13, 15, 21, 43] 저장 됨
# {40} 회차가 저장됩니다. ['6', '9', '21', '31', '32', '40']
# 40 회차 : [6, 9, 21, 31, 32, 40] 저장 됨
# {41} 회차가 저장됩니다. ['13', '20', '23', '35', '38', '43']
# 41 회차 : [13, 20, 23, 35, 38, 43] 저장 됨
# {42} 회차가 저장됩니다. ['3', '23', '28', '34', '39', '42']
# 42 회차 : [3, 23, 28, 34, 39, 42] 저장 됨
# {43} 회차가 저장됩니다. ['6', '31', '35', '38', '39', '44']
# 43 회차 : [6, 31, 35, 38, 39, 44] 저장 됨
# {44} 회차가 저장됩니다. ['13', '20', '23', '35', '38', '43']
# 44 회차 : [13, 20, 23, 35, 38, 43] 저장 됨
# {45} 회차가 저장됩니다. ['4', '6', '10', '14', '25', '40']
# 45 회차 : [4, 6, 10, 14, 25, 40] 저장 됨
# {46} 회차가 저장됩니다. ['8', '13', '15', '23', '31', '38']
# 46 회차 : [8, 13, 15, 23, 31, 38] 저장 됨
# {47} 회차가 저장됩니다. ['8', '23', '25', '27', '35', '44']
# 47 회차 : [8, 23, 25, 27, 35, 44] 저장 됨
# {48} 회차가 저장됩니다. ['6', '10', '18', '26', '37', '38']
# 48 회차 : [6, 10, 18, 26, 37, 38] 저장 됨
# {49} 회차가 저장됩니다. ['5', '20', '23', '27', '35', '40']
# 49 회차 : [5, 20, 23, 27, 35, 40] 저장 됨
# {50} 회차가 저장됩니다. ['2', '10', '12', '15', '22', '44']
# 50 회차 : [2, 10, 12, 15, 22, 44] 저장 됨
# {51} 회차가 저장됩니다. ['6', '8', '13', '16', '30', '43']
# 51 회차 : [6, 8, 13, 16, 30, 43] 저장 됨
# {52} 회차가 저장됩니다. ['2', '4', '15', '16', '20', '29']
# 52 회차 : [2, 4, 15, 16, 20, 29] 저장 됨
# {53} 회차가 저장됩니다. ['3', '19', '22', '31', '42', '43']
# 53 회차 : [3, 19, 22, 31, 42, 43] 저장 됨
# {54} 회차가 저장됩니다. ['1', '8', '21', '27', '36', '39']
# 54 회차 : [1, 8, 21, 27, 36, 39] 저장 됨
# {55} 회차가 저장됩니다. ['2', '4', '15', '16', '20', '29']
# 55 회차 : [2, 4, 15, 16, 20, 29] 저장 됨
# {56} 회차가 저장됩니다. ['3', '6', '13', '23', '24', '35']
# 56 회차 : [3, 6, 13, 23, 24, 35] 저장 됨
# {57} 회차가 저장됩니다. ['7', '10', '16', '25', '29', '44']
# 57 회차 : [7, 10, 16, 25, 29, 44] 저장 됨
# {58} 회차가 저장됩니다. ['6', '8', '28', '33', '38', '39']
# 58 회차 : [6, 8, 28, 33, 38, 39] 저장 됨
# {59} 회차가 저장됩니다. ['6', '29', '36', '39', '41', '45']
# 59 회차 : [6, 29, 36, 39, 41, 45] 저장 됨
# {60} 회차가 저장됩니다. ['4', '8', '27', '34', '39', '40']
# 60 회차 : [4, 8, 27, 34, 39, 40] 저장 됨
# {61} 회차가 저장됩니다. ['14', '15', '19', '30', '38', '43']
# 61 회차 : [14, 15, 19, 30, 38, 43] 저장 됨
# {62} 회차가 저장됩니다. ['19', '28', '31', '38', '43', '44']
# 62 회차 : [19, 28, 31, 38, 43, 44] 저장 됨
# {63} 회차가 저장됩니다. ['3', '20', '23', '36', '38', '40']
# 63 회차 : [3, 20, 23, 36, 38, 40] 저장 됨
# {64} 회차가 저장됩니다. ['3', '21', '22', '33', '41', '42']
# 64 회차 : [3, 21, 22, 33, 41, 42] 저장 됨
# {65} 회차가 저장됩니다. ['4', '25', '33', '36', '40', '43']
# 65 회차 : [4, 25, 33, 36, 40, 43] 저장 됨
# {66} 회차가 저장됩니다. ['3', '20', '23', '36', '38', '40']
# 66 회차 : [3, 20, 23, 36, 38, 40] 저장 됨
# {67} 회차가 저장됩니다. ['3', '5', '7', '14', '26', '34']
# 67 회차 : [3, 5, 7, 14, 26, 34] 저장 됨
# {68} 회차가 저장됩니다. ['10', '12', '15', '16', '26', '39']
# 68 회차 : [10, 12, 15, 16, 26, 39] 저장 됨
# {69} 회차가 저장됩니다. ['4', '5', '8', '16', '21', '29']
# 69 회차 : [4, 5, 8, 16, 21, 29] 저장 됨
# {70} 회차가 저장됩니다. ['5', '19', '22', '25', '28', '43']
# 70 회차 : [5, 19, 22, 25, 28, 43] 저장 됨
# {71} 회차가 저장됩니다. ['4', '8', '13', '19', '20', '43']
# 71 회차 : [4, 8, 13, 19, 20, 43] 저장 됨
# {72} 회차가 저장됩니다. ['2', '4', '11', '17', '26', '27']
# 72 회차 : [2, 4, 11, 17, 26, 27] 저장 됨
# {73} 회차가 저장됩니다. ['7', '22', '29', '33', '34', '35']
# 73 회차 : [7, 22, 29, 33, 34, 35] 저장 됨
# {74} 회차가 저장됩니다. ['6', '15', '17', '18', '35', '40']
# 74 회차 : [6, 15, 17, 18, 35, 40] 저장 됨
# {75} 회차가 저장됩니다. ['9', '33', '36', '40', '42', '43']
# 75 회차 : [9, 33, 36, 40, 42, 43] 저장 됨
# {76} 회차가 저장됩니다. ['1', '3', '15', '22', '25', '37']
# 76 회차 : [1, 3, 15, 22, 25, 37] 저장 됨
# {77} 회차가 저장됩니다. ['6', '15', '17', '18', '35', '40']
# 77 회차 : [6, 15, 17, 18, 35, 40] 저장 됨
# {78} 회차가 저장됩니다. ['2', '6', '7', '12', '19', '45']
# 78 회차 : [2, 6, 7, 12, 19, 45] 저장 됨
# {79} 회차가 저장됩니다. ['3', '12', '24', '27', '30', '32']
# 79 회차 : [3, 12, 24, 27, 30, 32] 저장 됨
# {80} 회차가 저장됩니다. ['6', '11', '15', '17', '23', '40']
# 80 회차 : [6, 11, 15, 17, 23, 40] 저장 됨
# {81} 회차가 저장됩니다. ['5', '7', '11', '13', '20', '33']
# 81 회차 : [5, 7, 11, 13, 20, 33] 저장 됨
# {82} 회차가 저장됩니다. ['4', '5', '31', '35', '43', '45']
# 82 회차 : [4, 5, 31, 35, 43, 45] 저장 됨
# {83} 회차가 저장됩니다. ['6', '10', '15', '17', '19', '34']
# 83 회차 : [6, 10, 15, 17, 19, 34] 저장 됨
# {84} 회차가 저장됩니다. ['5', '13', '17', '29', '34', '39']
# 84 회차 : [5, 13, 17, 29, 34, 39] 저장 됨
# {85} 회차가 저장됩니다. ['6', '8', '13', '23', '31', '36']
# 85 회차 : [6, 8, 13, 23, 31, 36] 저장 됨
# {86} 회차가 저장됩니다. ['2', '6', '20', '27', '37', '39']
# 86 회차 : [2, 6, 20, 27, 37, 39] 저장 됨
# {87} 회차가 저장됩니다. ['4', '12', '16', '23', '34', '43']
# 87 회차 : [4, 12, 16, 23, 34, 43] 저장 됨
# {88} 회차가 저장됩니다. ['6', '8', '13', '23', '31', '36']
# 88 회차 : [6, 8, 13, 23, 31, 36] 저장 됨
# {89} 회차가 저장됩니다. ['8', '19', '20', '21', '33', '39']
# 89 회차 : [8, 19, 20, 21, 33, 39] 저장 됨
# {90} 회차가 저장됩니다. ['17', '20', '29', '35', '38', '44']
# 90 회차 : [17, 20, 29, 35, 38, 44] 저장 됨
# {91} 회차가 저장됩니다. ['9', '14', '17', '18', '42', '44']
# 91 회차 : [9, 14, 17, 18, 42, 44] 저장 됨
# {92} 회차가 저장됩니다. ['3', '14', '24', '33', '35', '36']
# 92 회차 : [3, 14, 24, 33, 35, 36] 저장 됨
# {93} 회차가 저장됩니다. ['4', '11', '28', '39', '42', '45']
# 93 회차 : [4, 11, 28, 39, 42, 45] 저장 됨
# {94} 회차가 저장됩니다. ['5', '32', '34', '40', '41', '45']
# 94 회차 : [5, 32, 34, 40, 41, 45] 저장 됨
# {95} 회차가 저장됩니다. ['1', '14', '15', '24', '40', '41']
# 95 회차 : [1, 14, 15, 24, 40, 41] 저장 됨
# {96} 회차가 저장됩니다. ['1', '3', '8', '21', '22', '31']
# 96 회차 : [1, 3, 8, 21, 22, 31] 저장 됨
# {97} 회차가 저장됩니다. ['7', '11', '16', '21', '27', '33']
# 97 회차 : [7, 11, 16, 21, 27, 33] 저장 됨
# {98} 회차가 저장됩니다. ['6', '9', '16', '23', '24', '32']
# 98 회차 : [6, 9, 16, 23, 24, 32] 저장 됨
# {99} 회차가 저장됩니다. ['1', '3', '8', '21', '22', '31']
# 99 회차 : [1, 3, 8, 21, 22, 31] 저장 됨
# {100} 회차가 저장됩니다. ['15', '23', '29', '34', '40', '44']
# 100 회차 : [15, 23, 29, 34, 40, 44] 저장 됨
# {101} 회차가 저장됩니다. ['1', '3', '17', '32', '35', '45']
# 101 회차 : [1, 3, 17, 32, 35, 45] 저장 됨
# {102} 회차가 저장됩니다. ['9', '18', '20', '22', '38', '44']
# 102 회차 : [9, 18, 20, 22, 38, 44] 저장 됨
# {103} 회차가 저장됩니다. ['5', '14', '15', '27', '30', '45']
# 103 회차 : [5, 14, 15, 27, 30, 45] 저장 됨
# {104} 회차가 저장됩니다. ['17', '32', '33', '34', '42', '44']
# 104 회차 : [17, 32, 33, 34, 42, 44] 저장 됨
# {105} 회차가 저장됩니다. ['8', '10', '20', '34', '41', '45']
# 105 회차 : [8, 10, 20, 34, 41, 45] 저장 됨
# {106} 회차가 저장됩니다. ['4', '10', '12', '22', '24', '33']
# 106 회차 : [4, 10, 12, 22, 24, 33] 저장 됨
# {107} 회차가 저장됩니다. ['1', '4', '5', '6', '9', '31']
# 107 회차 : [1, 4, 5, 6, 9, 31] 저장 됨
# {108} 회차가 저장됩니다. ['7', '18', '22', '23', '29', '44']
# 108 회차 : [7, 18, 22, 23, 29, 44] 저장 됨
# {109} 회차가 저장됩니다. ['1', '5', '34', '36', '42', '44']
# 109 회차 : [1, 5, 34, 36, 42, 44] 저장 됨
# {110} 회차가 저장됩니다. ['7', '20', '22', '23', '29', '43']
# 110 회차 : [7, 20, 22, 23, 29, 43] 저장 됨
# {111} 회차가 저장됩니다. ['1', '4', '5', '6', '9', '31']
# 111 회차 : [1, 4, 5, 6, 9, 31] 저장 됨
# {112} 회차가 저장됩니다. ['26', '29', '30', '33', '41', '42']
# 112 회차 : [26, 29, 30, 33, 41, 42] 저장 됨
# {113} 회차가 저장됩니다. ['4', '9', '28', '33', '36', '45']
# 113 회차 : [4, 9, 28, 33, 36, 45] 저장 됨
# {114} 회차가 저장됩니다. ['11', '14', '19', '26', '28', '41']
# 114 회차 : [11, 14, 19, 26, 28, 41] 저장 됨
# {115} 회차가 저장됩니다. ['1', '2', '6', '9', '25', '28']
# 115 회차 : [1, 2, 6, 9, 25, 28] 저장 됨
# {116} 회차가 저장됩니다. ['2', '4', '25', '31', '34', '37']
# 116 회차 : [2, 4, 25, 31, 34, 37] 저장 됨
# {117} 회차가 저장됩니다. ['5', '10', '22', '34', '36', '44']
# 117 회차 : [5, 10, 22, 34, 36, 44] 저장 됨
# {118} 회차가 저장됩니다. ['3', '4', '10', '17', '19', '22']
# 118 회차 : [3, 4, 10, 17, 19, 22] 저장 됨
# {119} 회차가 저장됩니다. ['3', '11', '13', '14', '17', '21']
# 119 회차 : [3, 11, 13, 14, 17, 21] 저장 됨
# {120} 회차가 저장됩니다. ['4', '6', '10', '11', '32', '37']
# 120 회차 : [4, 6, 10, 11, 32, 37] 저장 됨
# {121} 회차가 저장됩니다. ['12', '28', '30', '34', '38', '43']
# 121 회차 : [12, 28, 30, 34, 38, 43] 저장 됨
# {122} 회차가 저장됩니다. ['1', '11', '16', '17', '36', '40']
# 122 회차 : [1, 11, 16, 17, 36, 40] 저장 됨
# {123} 회차가 저장됩니다. ['7', '17', '18', '28', '30', '45']
# 123 회차 : [7, 17, 18, 28, 30, 45] 저장 됨
# {124} 회차가 저장됩니다. ['4', '16', '23', '25', '29', '42']
# 124 회차 : [4, 16, 23, 25, 29, 42] 저장 됨
# {125} 회차가 저장됩니다. ['2', '8', '32', '33', '35', '36']
# 125 회차 : [2, 8, 32, 33, 35, 36] 저장 됨
# {126} 회차가 저장됩니다. ['7', '20', '22', '27', '40', '43']
# 126 회차 : [7, 20, 22, 27, 40, 43] 저장 됨
# {127} 회차가 저장됩니다. ['3', '5', '10', '29', '32', '43']
# 127 회차 : [3, 5, 10, 29, 32, 43] 저장 됨
# {128} 회차가 저장됩니다. ['12', '30', '34', '36', '37', '45']
# 128 회차 : [12, 30, 34, 36, 37, 45] 저장 됨
# {129} 회차가 저장됩니다. ['19', '23', '25', '28', '38', '42']
# 129 회차 : [19, 23, 25, 28, 38, 42] 저장 됨
# {130} 회차가 저장됩니다. ['7', '19', '24', '27', '42', '45']
# 130 회차 : [7, 19, 24, 27, 42, 45] 저장 됨
# {131} 회차가 저장됩니다. ['8', '10', '11', '14', '15', '21']
# 131 회차 : [8, 10, 11, 14, 15, 21] 저장 됨
# {132} 회차가 저장됩니다. ['3', '17', '23', '34', '41', '45']
# 132 회차 : [3, 17, 23, 34, 41, 45] 저장 됨
# {133} 회차가 저장됩니다. ['4', '7', '15', '18', '23', '26']
# 133 회차 : [4, 7, 15, 18, 23, 26] 저장 됨
# {134} 회차가 저장됩니다. ['3', '12', '20', '23', '31', '35']
# 134 회차 : [3, 12, 20, 23, 31, 35] 저장 됨
# {135} 회차가 저장됩니다. ['6', '14', '22', '28', '35', '39']
# 135 회차 : [6, 14, 22, 28, 35, 39] 저장 됨
# {136} 회차가 저장됩니다. ['2', '16', '30', '36', '41', '42']
# 136 회차 : [2, 16, 30, 36, 41, 42] 저장 됨
# {137} 회차가 저장됩니다. ['7', '9', '20', '25', '36', '39']
# 137 회차 : [7, 9, 20, 25, 36, 39] 저장 됨
# {138} 회차가 저장됩니다. ['10', '11', '27', '28', '37', '39']
# 138 회차 : [10, 11, 27, 28, 37, 39] 저장 됨
# {139} 회차가 저장됩니다. ['9', '11', '15', '20', '28', '43']
# 139 회차 : [9, 11, 15, 20, 28, 43] 저장 됨
# {140} 회차가 저장됩니다. ['3', '13', '17', '18', '19', '28']
# 140 회차 : [3, 13, 17, 18, 19, 28] 저장 됨
# {141} 회차가 저장됩니다. ['8', '12', '29', '31', '42', '43']
# 141 회차 : [8, 12, 29, 31, 42, 43] 저장 됨
# {142} 회차가 저장됩니다. ['12', '16', '30', '34', '40', '44']
# 142 회차 : [12, 16, 30, 34, 40, 44] 저장 됨
# {143} 회차가 저장됩니다. ['26', '27', '28', '42', '43', '45']
# 143 회차 : [26, 27, 28, 42, 43, 45] 저장 됨
# {144} 회차가 저장됩니다. ['4', '15', '17', '26', '36', '37']
# 144 회차 : [4, 15, 17, 26, 36, 37] 저장 됨
# {145} 회차가 저장됩니다. ['2', '3', '13', '20', '27', '44']
# 145 회차 : [2, 3, 13, 20, 27, 44] 저장 됨
# {146} 회차가 저장됩니다. ['2', '19', '27', '35', '41', '42']
# 146 회차 : [2, 19, 27, 35, 41, 42] 저장 됨
# {147} 회차가 저장됩니다. ['4', '6', '13', '21', '40', '42']
# 147 회차 : [4, 6, 13, 21, 40, 42] 저장 됨
# {148} 회차가 저장됩니다. ['21', '25', '33', '34', '35', '36']
# 148 회차 : [21, 25, 33, 34, 35, 36] 저장 됨
# {149} 회차가 저장됩니다. ['2', '11', '21', '34', '41', '42']
# 149 회차 : [2, 11, 21, 34, 41, 42] 저장 됨
# {150} 회차가 저장됩니다. ['2', '18', '25', '28', '37', '39']
# 150 회차 : [2, 18, 25, 28, 37, 39] 저장 됨
# {151} 회차가 저장됩니다. ['1', '2', '10', '13', '18', '19']
# 151 회차 : [1, 2, 10, 13, 18, 19] 저장 됨
# {152} 회차가 저장됩니다. ['1', '5', '13', '26', '29', '34']
# 152 회차 : [1, 5, 13, 26, 29, 34] 저장 됨
# {153} 회차가 저장됩니다. ['3', '8', '11', '12', '13', '36']
# 153 회차 : [3, 8, 11, 12, 13, 36] 저장 됨
# {154} 회차가 저장됩니다. ['6', '19', '21', '35', '40', '45']
# 154 회차 : [6, 19, 21, 35, 40, 45] 저장 됨
# {155} 회차가 저장됩니다. ['16', '19', '20', '32', '33', '41']
# 155 회차 : [16, 19, 20, 32, 33, 41] 저장 됨
# {156} 회차가 저장됩니다. ['5', '18', '28', '30', '42', '45']
# 156 회차 : [5, 18, 28, 30, 42, 45] 저장 됨
# {157} 회차가 저장됩니다. ['19', '26', '30', '33', '35', '39']
# 157 회차 : [19, 26, 30, 33, 35, 39] 저장 됨
# {158} 회차가 저장됩니다. ['4', '9', '13', '18', '21', '34']
# 158 회차 : [4, 9, 13, 18, 21, 34] 저장 됨
# {159} 회차가 저장됩니다. ['1', '18', '30', '41', '42', '43']
# 159 회차 : [1, 18, 30, 41, 42, 43] 저장 됨
# {160} 회차가 저장됩니다. ['3', '7', '8', '34', '39', '41']
# 160 회차 : [3, 7, 8, 34, 39, 41] 저장 됨
# {161} 회차가 저장됩니다. ['22', '34', '36', '40', '42', '45']
# 161 회차 : [22, 34, 36, 40, 42, 45] 저장 됨
# {162} 회차가 저장됩니다. ['1', '5', '21', '25', '38', '41']
# 162 회차 : [1, 5, 21, 25, 38, 41] 저장 됨
# {163} 회차가 저장됩니다. ['7', '11', '26', '28', '29', '44']
# 163 회차 : [7, 11, 26, 28, 29, 44] 저장 됨
# {164} 회차가 저장됩니다. ['6', '9', '10', '11', '39', '41']
# 164 회차 : [6, 9, 10, 11, 39, 41] 저장 됨
# {165} 회차가 저장됩니다. ['5', '13', '18', '19', '22', '42']
# 165 회차 : [5, 13, 18, 19, 22, 42] 저장 됨
# {166} 회차가 저장됩니다. ['9', '12', '27', '36', '39', '45']
# 166 회차 : [9, 12, 27, 36, 39, 45] 저장 됨
# {167} 회차가 저장됩니다. ['24', '27', '28', '30', '36', '39']
# 167 회차 : [24, 27, 28, 30, 36, 39] 저장 됨
# {168} 회차가 저장됩니다. ['3', '10', '31', '40', '42', '43']
# 168 회차 : [3, 10, 31, 40, 42, 43] 저장 됨
# {169} 회차가 저장됩니다. ['16', '27', '35', '37', '43', '45']
# 169 회차 : [16, 27, 35, 37, 43, 45] 저장 됨
# {170} 회차가 저장됩니다. ['2', '11', '13', '15', '31', '42']
# 170 회차 : [2, 11, 13, 15, 31, 42] 저장 됨
# {171} 회차가 저장됩니다. ['4', '16', '25', '29', '34', '35']
# 171 회차 : [4, 16, 25, 29, 34, 35] 저장 됨
# {172} 회차가 저장됩니다. ['4', '19', '21', '24', '26', '41']
# 172 회차 : [4, 19, 21, 24, 26, 41] 저장 됨
# {173} 회차가 저장됩니다. ['3', '9', '24', '30', '33', '34']
# 173 회차 : [3, 9, 24, 30, 33, 34] 저장 됨
# {174} 회차가 저장됩니다. ['13', '14', '18', '22', '35', '39']
# 174 회차 : [13, 14, 18, 22, 35, 39] 저장 됨
# {175} 회차가 저장됩니다. ['19', '26', '28', '31', '33', '36']
# 175 회차 : [19, 26, 28, 31, 33, 36] 저장 됨
# {176} 회차가 저장됩니다. ['4', '17', '30', '32', '33', '34']
# 176 회차 : [4, 17, 30, 32, 33, 34] 저장 됨
# {177} 회차가 저장됩니다. ['1', '10', '13', '16', '37', '43']
# 177 회차 : [1, 10, 13, 16, 37, 43] 저장 됨
# {178} 회차가 저장됩니다. ['1', '5', '11', '12', '18', '23']
# 178 회차 : [1, 5, 11, 12, 18, 23] 저장 됨
# {179} 회차가 저장됩니다. ['5', '9', '17', '25', '39', '43']
# 179 회차 : [5, 9, 17, 25, 39, 43] 저장 됨
# {180} 회차가 저장됩니다. ['2', '15', '20', '21', '29', '34']
# 180 회차 : [2, 15, 20, 21, 29, 34] 저장 됨
# {181} 회차가 저장됩니다. ['14', '21', '23', '32', '40', '45']
# 181 회차 : [14, 21, 23, 32, 40, 45] 저장 됨
# {182} 회차가 저장됩니다. ['13', '15', '27', '29', '34', '40']
# 182 회차 : [13, 15, 27, 29, 34, 40] 저장 됨
# {183} 회차가 저장됩니다. ['2', '18', '24', '34', '40', '42']
# 183 회차 : [2, 18, 24, 34, 40, 42] 저장 됨
# {184} 회차가 저장됩니다. ['1', '2', '6', '16', '20', '33']
# 184 회차 : [1, 2, 6, 16, 20, 33] 저장 됨
# {185} 회차가 저장됩니다. ['1', '2', '4', '8', '19', '38']
# 185 회차 : [1, 2, 4, 8, 19, 38] 저장 됨
# {186} 회차가 저장됩니다. ['4', '10', '14', '19', '21', '45']
# 186 회차 : [4, 10, 14, 19, 21, 45] 저장 됨
# {187} 회차가 저장됩니다. ['1', '2', '8', '18', '29', '38']
# 187 회차 : [1, 2, 8, 18, 29, 38] 저장 됨
# {188} 회차가 저장됩니다. ['19', '24', '27', '30', '31', '34']
# 188 회차 : [19, 24, 27, 30, 31, 34] 저장 됨
# {189} 회차가 저장됩니다. ['8', '14', '32', '35', '37', '45']
# 189 회차 : [8, 14, 32, 35, 37, 45] 저장 됨
# {190} 회차가 저장됩니다. ['8', '14', '18', '30', '31', '44']
# 190 회차 : [8, 14, 18, 30, 31, 44] 저장 됨
# {191} 회차가 저장됩니다. ['5', '6', '24', '25', '32', '37']
# 191 회차 : [5, 6, 24, 25, 32, 37] 저장 됨
# {192} 회차가 저장됩니다. ['4', '8', '11', '18', '37', '45']
# 192 회차 : [4, 8, 11, 18, 37, 45] 저장 됨
# {193} 회차가 저장됩니다. ['6', '14', '18', '26', '36', '39']
# 193 회차 : [6, 14, 18, 26, 36, 39] 저장 됨
# {194} 회차가 저장됩니다. ['15', '20', '23', '26', '39', '44']
# 194 회차 : [15, 20, 23, 26, 39, 44] 저장 됨
# {195} 회차가 저장됩니다. ['7', '10', '19', '22', '35', '40']
# 195 회차 : [7, 10, 19, 22, 35, 40] 저장 됨
# {196} 회차가 저장됩니다. ['35', '36', '37', '41', '44', '45']
# 196 회차 : [35, 36, 37, 41, 44, 45] 저장 됨
# {197} 회차가 저장됩니다. ['7', '12', '16', '34', '42', '45']
# 197 회차 : [7, 12, 16, 34, 42, 45] 저장 됨
# {198} 회차가 저장됩니다. ['12', '19', '20', '25', '41', '45']
# 198 회차 : [12, 19, 20, 25, 41, 45] 저장 됨
# {199} 회차가 저장됩니다. ['14', '21', '22', '25', '30', '36']
# 199 회차 : [14, 21, 22, 25, 30, 36] 저장 됨
# {200} 회차가 저장됩니다. ['5', '6', '13', '14', '17', '20']
# 200 회차 : [5, 6, 13, 14, 17, 20] 저장 됨
# {201} 회차가 저장됩니다. ['3', '11', '24', '38', '39', '44']
# 201 회차 : [3, 11, 24, 38, 39, 44] 저장 됨
# {202} 회차가 저장됩니다. ['12', '14', '27', '33', '39', '44']
# 202 회차 : [12, 14, 27, 33, 39, 44] 저장 됨
# {203} 회차가 저장됩니다. ['1', '3', '11', '24', '30', '32']
# 203 회차 : [1, 3, 11, 24, 30, 32] 저장 됨
# {204} 회차가 저장됩니다. ['3', '12', '14', '35', '40', '45']
# 204 회차 : [3, 12, 14, 35, 40, 45] 저장 됨
# {205} 회차가 저장됩니다. ['1', '3', '21', '29', '35', '37']
# 205 회차 : [1, 3, 21, 29, 35, 37] 저장 됨
# {206} 회차가 저장됩니다. ['1', '2', '3', '15', '20', '25']
# 206 회차 : [1, 2, 3, 15, 20, 25] 저장 됨
# {207} 회차가 저장됩니다. ['3', '11', '14', '31', '32', '37']
# 207 회차 : [3, 11, 14, 31, 32, 37] 저장 됨
# {208} 회차가 저장됩니다. ['14', '25', '31', '34', '40', '44']
# 208 회차 : [14, 25, 31, 34, 40, 44] 저장 됨
# {209} 회차가 저장됩니다. ['2', '7', '18', '20', '24', '33']
# 209 회차 : [2, 7, 18, 20, 24, 33] 저장 됨
# {210} 회차가 저장됩니다. ['10', '19', '22', '23', '25', '37']
# 210 회차 : [10, 19, 22, 23, 25, 37] 저장 됨
# {211} 회차가 저장됩니다. ['12', '13', '17', '20', '33', '41']
# 211 회차 : [12, 13, 17, 20, 33, 41] 저장 됨
# {212} 회차가 저장됩니다. ['11', '12', '18', '21', '31', '38']
# 212 회차 : [11, 12, 18, 21, 31, 38] 저장 됨
# {213} 회차가 저장됩니다. ['2', '3', '4', '5', '20', '24']
# 213 회차 : [2, 3, 4, 5, 20, 24] 저장 됨
# {214} 회차가 저장됩니다. ['5', '7', '20', '25', '28', '37']
# 214 회차 : [5, 7, 20, 25, 28, 37] 저장 됨
# {215} 회차가 저장됩니다. ['2', '3', '7', '15', '43', '44']
# 215 회차 : [2, 3, 7, 15, 43, 44] 저장 됨
# {216} 회차가 저장됩니다. ['7', '16', '17', '33', '36', '40']
# 216 회차 : [7, 16, 17, 33, 36, 40] 저장 됨
# {217} 회차가 저장됩니다. ['16', '20', '27', '33', '35', '39']
# 217 회차 : [16, 20, 27, 33, 35, 39] 저장 됨
# {218} 회차가 저장됩니다. ['1', '8', '14', '18', '29', '44']
# 218 회차 : [1, 8, 14, 18, 29, 44] 저장 됨
# {219} 회차가 저장됩니다. ['4', '11', '20', '26', '35', '37']
# 219 회차 : [4, 11, 20, 26, 35, 37] 저장 됨
# {220} 회차가 저장됩니다. ['5', '11', '19', '21', '34', '43']
# 220 회차 : [5, 11, 19, 21, 34, 43] 저장 됨
# {221} 회차가 저장됩니다. ['2', '20', '33', '35', '37', '40']
# 221 회차 : [2, 20, 33, 35, 37, 40] 저장 됨
# {222} 회차가 저장됩니다. ['1', '8', '14', '18', '29', '44']
# 222 회차 : [1, 8, 14, 18, 29, 44] 저장 됨
# {223} 회차가 저장됩니다. ['1', '3', '18', '20', '26', '27']
# 223 회차 : [1, 3, 18, 20, 26, 27] 저장 됨
# {224} 회차가 저장됩니다. ['4', '19', '26', '27', '30', '42']
# 224 회차 : [4, 19, 26, 27, 30, 42] 저장 됨
# {225} 회차가 저장됩니다. ['5', '11', '13', '19', '31', '36']
# 225 회차 : [5, 11, 13, 19, 31, 36] 저장 됨
# {226} 회차가 저장됩니다. ['2', '6', '8', '14', '21', '22']
# 226 회차 : [2, 6, 8, 14, 21, 22] 저장 됨
# {227} 회차가 저장됩니다. ['4', '5', '15', '16', '22', '42']
# 227 회차 : [4, 5, 15, 16, 22, 42] 저장 됨
# {228} 회차가 저장됩니다. ['17', '25', '35', '36', '39', '44']
# 228 회차 : [17, 25, 35, 36, 39, 44] 저장 됨
# {229} 회차가 저장됩니다. ['4', '5', '9', '11', '23', '38']
# 229 회차 : [4, 5, 9, 11, 23, 38] 저장 됨
# {230} 회차가 저장됩니다. ['5', '11', '14', '29', '32', '33']
# 230 회차 : [5, 11, 14, 29, 32, 33] 저장 됨
# {231} 회차가 저장됩니다. ['5', '10', '19', '31', '44', '45']
# 231 회차 : [5, 10, 19, 31, 44, 45] 저장 됨
# {232} 회차가 저장됩니다. ['8', '9', '10', '12', '24', '44']
# 232 회차 : [8, 9, 10, 12, 24, 44] 저장 됨
# {233} 회차가 저장됩니다. ['4', '6', '13', '17', '28', '40']
# 233 회차 : [4, 6, 13, 17, 28, 40] 저장 됨
# {234} 회차가 저장됩니다. ['13', '21', '22', '24', '26', '37']
# 234 회차 : [13, 21, 22, 24, 26, 37] 저장 됨
# {235} 회차가 저장됩니다. ['21', '22', '26', '27', '31', '37']
# 235 회차 : [21, 22, 26, 27, 31, 37] 저장 됨
# {236} 회차가 저장됩니다. ['1', '4', '8', '13', '37', '39']
# 236 회차 : [1, 4, 8, 13, 37, 39] 저장 됨
# {237} 회차가 저장됩니다. ['1', '11', '17', '21', '24', '44']
# 237 회차 : [1, 11, 17, 21, 24, 44] 저장 됨
# {238} 회차가 저장됩니다. ['2', '4', '15', '28', '31', '34']
# 238 회차 : [2, 4, 15, 28, 31, 34] 저장 됨
# {239} 회차가 저장됩니다. ['11', '15', '24', '39', '41', '44']
# 239 회차 : [11, 15, 24, 39, 41, 44] 저장 됨
# {240} 회차가 저장됩니다. ['6', '10', '16', '40', '41', '43']
# 240 회차 : [6, 10, 16, 40, 41, 43] 저장 됨
# {241} 회차가 저장됩니다. ['2', '16', '24', '27', '28', '35']
# 241 회차 : [2, 16, 24, 27, 28, 35] 저장 됨
# {242} 회차가 저장됩니다. ['4', '19', '20', '21', '32', '34']
# 242 회차 : [4, 19, 20, 21, 32, 34] 저장 됨
# {243} 회차가 저장됩니다. ['2', '12', '17', '19', '28', '42']
# 243 회차 : [2, 12, 17, 19, 28, 42] 저장 됨
# {244} 회차가 저장됩니다. ['13', '16', '25', '36', '37', '38']
# 244 회차 : [13, 16, 25, 36, 37, 38] 저장 됨
# {245} 회차가 저장됩니다. ['9', '11', '27', '31', '32', '38']
# 245 회차 : [9, 11, 27, 31, 32, 38] 저장 됨
# {246} 회차가 저장됩니다. ['13', '18', '21', '23', '26', '39']
# 246 회차 : [13, 18, 21, 23, 26, 39] 저장 됨
# {247} 회차가 저장됩니다. ['12', '15', '28', '36', '39', '40']
# 247 회차 : [12, 15, 28, 36, 39, 40] 저장 됨
# {248} 회차가 저장됩니다. ['3', '8', '17', '23', '38', '45']
# 248 회차 : [3, 8, 17, 23, 38, 45] 저장 됨
# {249} 회차가 저장됩니다. ['3', '8', '27', '31', '41', '44']
# 249 회차 : [3, 8, 27, 31, 41, 44] 저장 됨
# {250} 회차가 저장됩니다. ['19', '23', '30', '37', '43', '45']
# 250 회차 : [19, 23, 30, 37, 43, 45] 저장 됨
# {251} 회차가 저장됩니다. ['6', '7', '19', '25', '28', '38']
# 251 회차 : [6, 7, 19, 25, 28, 38] 저장 됨
# {252} 회차가 저장됩니다. ['14', '23', '26', '31', '39', '45']
# 252 회차 : [14, 23, 26, 31, 39, 45] 저장 됨
# {253} 회차가 저장됩니다. ['8', '19', '25', '31', '34', '36']
# 253 회차 : [8, 19, 25, 31, 34, 36] 저장 됨
# {254} 회차가 저장됩니다. ['1', '5', '19', '20', '24', '30']
# 254 회차 : [1, 5, 19, 20, 24, 30] 저장 됨
# {255} 회차가 저장됩니다. ['1', '5', '6', '24', '27', '42']
# 255 회차 : [1, 5, 6, 24, 27, 42] 저장 됨
# {256} 회차가 저장됩니다. ['4', '11', '14', '21', '23', '43']
# 256 회차 : [4, 11, 14, 21, 23, 43] 저장 됨
# {257} 회차가 저장됩니다. ['6', '13', '27', '31', '32', '37']
# 257 회차 : [6, 13, 27, 31, 32, 37] 저장 됨
# {258} 회차가 저장됩니다. ['14', '27', '30', '31', '38', '40']
# 258 회차 : [14, 27, 30, 31, 38, 40] 저장 됨
# {259} 회차가 저장됩니다. ['4', '5', '14', '35', '42', '45']
# 259 회차 : [4, 5, 14, 35, 42, 45] 저장 됨
# {260} 회차가 저장됩니다. ['7', '12', '15', '24', '37', '40']
# 260 회차 : [7, 12, 15, 24, 37, 40] 저장 됨
# {261} 회차가 저장됩니다. ['6', '11', '16', '18', '31', '43']
# 261 회차 : [6, 11, 16, 18, 31, 43] 저장 됨
# {262} 회차가 저장됩니다. ['9', '12', '24', '25', '29', '31']
# 262 회차 : [9, 12, 24, 25, 29, 31] 저장 됨
# {263} 회차가 저장됩니다. ['1', '27', '28', '32', '37', '40']
# 263 회차 : [1, 27, 28, 32, 37, 40] 저장 됨
# {264} 회차가 저장됩니다. ['9', '16', '27', '36', '41', '44']
# 264 회차 : [9, 16, 27, 36, 41, 44] 저장 됨
# {265} 회차가 저장됩니다. ['5', '9', '34', '37', '38', '39']
# 265 회차 : [5, 9, 34, 37, 38, 39] 저장 됨
# {266} 회차가 저장됩니다. ['3', '4', '9', '11', '22', '42']
# 266 회차 : [3, 4, 9, 11, 22, 42] 저장 됨
# {267} 회차가 저장됩니다. ['7', '8', '24', '34', '36', '41']
# 267 회차 : [7, 8, 24, 34, 36, 41] 저장 됨
# {268} 회차가 저장됩니다. ['3', '10', '19', '24', '32', '45']
# 268 회차 : [3, 10, 19, 24, 32, 45] 저장 됨
# {269} 회차가 저장됩니다. ['5', '18', '20', '36', '42', '43']
# 269 회차 : [5, 18, 20, 36, 42, 43] 저장 됨
# {270} 회차가 저장됩니다. ['5', '9', '12', '20', '21', '26']
# 270 회차 : [5, 9, 12, 20, 21, 26] 저장 됨
# {271} 회차가 저장됩니다. ['3', '8', '9', '27', '29', '40']
# 271 회차 : [3, 8, 9, 27, 29, 40] 저장 됨
# {272} 회차가 저장됩니다. ['7', '9', '12', '27', '39', '43']
# 272 회차 : [7, 9, 12, 27, 39, 43] 저장 됨
# {273} 회차가 저장됩니다. ['1', '8', '24', '31', '34', '44']
# 273 회차 : [1, 8, 24, 31, 34, 44] 저장 됨
# {274} 회차가 저장됩니다. ['13', '14', '15', '26', '35', '39']
# 274 회차 : [13, 14, 15, 26, 35, 39] 저장 됨
# {275} 회차가 저장됩니다. ['14', '19', '20', '35', '38', '40']
# 275 회차 : [14, 19, 20, 35, 38, 40] 저장 됨
# {276} 회차가 저장됩니다. ['4', '15', '21', '33', '39', '41']
# 276 회차 : [4, 15, 21, 33, 39, 41] 저장 됨
# {277} 회차가 저장됩니다. ['10', '12', '13', '15', '25', '29']
# 277 회차 : [10, 12, 13, 15, 25, 29] 저장 됨
# {278} 회차가 저장됩니다. ['3', '11', '37', '39', '41', '43']
# 278 회차 : [3, 11, 37, 39, 41, 43] 저장 됨
# {279} 회차가 저장됩니다. ['7', '16', '31', '36', '37', '38']
# 279 회차 : [7, 16, 31, 36, 37, 38] 저장 됨
# {280} 회차가 저장됩니다. ['10', '11', '23', '24', '36', '37']
# 280 회차 : [10, 11, 23, 24, 36, 37] 저장 됨
# {281} 회차가 저장됩니다. ['1', '3', '4', '6', '14', '41']
# 281 회차 : [1, 3, 4, 6, 14, 41] 저장 됨
# {282} 회차가 저장됩니다. ['2', '5', '10', '18', '31', '32']
# 282 회차 : [2, 5, 10, 18, 31, 32] 저장 됨
# {283} 회차가 저장됩니다. ['6', '8', '18', '31', '38', '45']
# 283 회차 : [6, 8, 18, 31, 38, 45] 저장 됨
# {284} 회차가 저장됩니다. ['2', '7', '15', '24', '30', '45']
# 284 회차 : [2, 7, 15, 24, 30, 45] 저장 됨
# {285} 회차가 저장됩니다. ['13', '33', '37', '40', '41', '45']
# 285 회차 : [13, 33, 37, 40, 41, 45] 저장 됨
# {286} 회차가 저장됩니다. ['1', '15', '19', '40', '42', '44']
# 286 회차 : [1, 15, 19, 40, 42, 44] 저장 됨
# {287} 회차가 저장됩니다. ['6', '12', '24', '27', '35', '37']
# 287 회차 : [6, 12, 24, 27, 35, 37] 저장 됨
# {288} 회차가 저장됩니다. ['1', '12', '17', '28', '35', '41']
# 288 회차 : [1, 12, 17, 28, 35, 41] 저장 됨
# {289} 회차가 저장됩니다. ['3', '14', '33', '37', '38', '42']
# 289 회차 : [3, 14, 33, 37, 38, 42] 저장 됨
# {290} 회차가 저장됩니다. ['8', '13', '18', '32', '39', '45']
# 290 회차 : [8, 13, 18, 32, 39, 45] 저장 됨
# {291} 회차가 저장됩니다. ['3', '7', '8', '18', '20', '42']
# 291 회차 : [3, 7, 8, 18, 20, 42] 저장 됨
# {292} 회차가 저장됩니다. ['17', '18', '31', '32', '33', '34']
# 292 회차 : [17, 18, 31, 32, 33, 34] 저장 됨
# {293} 회차가 저장됩니다. ['1', '9', '17', '21', '29', '33']
# 293 회차 : [1, 9, 17, 21, 29, 33] 저장 됨
# {294} 회차가 저장됩니다. ['6', '10', '17', '30', '37', '38']
# 294 회차 : [6, 10, 17, 30, 37, 38] 저장 됨
# {295} 회차가 저장됩니다. ['1', '4', '12', '16', '18', '38']
# 295 회차 : [1, 4, 12, 16, 18, 38] 저장 됨
# {296} 회차가 저장됩니다. ['3', '8', '15', '27', '30', '45']
# 296 회차 : [3, 8, 15, 27, 30, 45] 저장 됨
# {297} 회차가 저장됩니다. ['6', '11', '19', '20', '28', '32']
# 297 회차 : [6, 11, 19, 20, 28, 32] 저장 됨
# {298} 회차가 저장됩니다. ['5', '9', '27', '29', '37', '40']
# 298 회차 : [5, 9, 27, 29, 37, 40] 저장 됨
# {299} 회차가 저장됩니다. ['1', '3', '20', '25', '36', '45']
# 299 회차 : [1, 3, 20, 25, 36, 45] 저장 됨
# {300} 회차가 저장됩니다. ['7', '9', '10', '12', '26', '38']
# 300 회차 : [7, 9, 10, 12, 26, 38] 저장 됨
# {301} 회차가 저장됩니다. ['7', '11', '13', '33', '37', '43']
# 301 회차 : [7, 11, 13, 33, 37, 43] 저장 됨
# {302} 회차가 저장됩니다. ['13', '19', '20', '32', '38', '42']
# 302 회차 : [13, 19, 20, 32, 38, 42] 저장 됨
# {303} 회차가 저장됩니다. ['2', '14', '17', '30', '38', '45']
# 303 회차 : [2, 14, 17, 30, 38, 45] 저장 됨
# {304} 회차가 저장됩니다. ['4', '10', '16', '26', '33', '41']
# 304 회차 : [4, 10, 16, 26, 33, 41] 저장 됨
# {305} 회차가 저장됩니다. ['7', '8', '18', '21', '23', '39']
# 305 회차 : [7, 8, 18, 21, 23, 39] 저장 됨
# {306} 회차가 저장됩니다. ['4', '18', '23', '30', '34', '41']
# 306 회차 : [4, 18, 23, 30, 34, 41] 저장 됨
# {307} 회차가 저장됩니다. ['5', '15', '21', '23', '25', '45']
# 307 회차 : [5, 15, 21, 23, 25, 45] 저장 됨
# {308} 회차가 저장됩니다. ['14', '15', '17', '19', '37', '45']
# 308 회차 : [14, 15, 17, 19, 37, 45] 저장 됨
# {309} 회차가 저장됩니다. ['1', '2', '5', '11', '18', '36']
# 309 회차 : [1, 2, 5, 11, 18, 36] 저장 됨
# {310} 회차가 저장됩니다. ['1', '5', '19', '28', '34', '41']
# 310 회차 : [1, 5, 19, 28, 34, 41] 저장 됨
# {311} 회차가 저장됩니다. ['4', '12', '24', '27', '28', '32']
# 311 회차 : [4, 12, 24, 27, 28, 32] 저장 됨
# {312} 회차가 저장됩니다. ['2', '3', '5', '6', '12', '20']
# 312 회차 : [2, 3, 5, 6, 12, 20] 저장 됨
# {313} 회차가 저장됩니다. ['9', '17', '34', '35', '43', '45']
# 313 회차 : [9, 17, 34, 35, 43, 45] 저장 됨
# {314} 회차가 저장됩니다. ['15', '17', '19', '34', '38', '41']
# 314 회차 : [15, 17, 19, 34, 38, 41] 저장 됨
# {315} 회차가 저장됩니다. ['1', '13', '33', '35', '43', '45']
# 315 회차 : [1, 13, 33, 35, 43, 45] 저장 됨
# {316} 회차가 저장됩니다. ['10', '11', '21', '27', '31', '39']
# 316 회차 : [10, 11, 21, 27, 31, 39] 저장 됨
# {317} 회차가 저장됩니다. ['3', '10', '11', '22', '36', '39']
# 317 회차 : [3, 10, 11, 22, 36, 39] 저장 됨
# {318} 회차가 저장됩니다. ['2', '17', '19', '20', '34', '45']
# 318 회차 : [2, 17, 19, 20, 34, 45] 저장 됨
# {319} 회차가 저장됩니다. ['5', '8', '22', '28', '33', '42']
# 319 회차 : [5, 8, 22, 28, 33, 42] 저장 됨
# {320} 회차가 저장됩니다. ['16', '19', '23', '25', '41', '45']
# 320 회차 : [16, 19, 23, 25, 41, 45] 저장 됨
# {321} 회차가 저장됩니다. ['12', '18', '20', '21', '25', '34']
# 321 회차 : [12, 18, 20, 21, 25, 34] 저장 됨
# {322} 회차가 저장됩니다. ['9', '18', '29', '32', '38', '43']
# 322 회차 : [9, 18, 29, 32, 38, 43] 저장 됨
# {323} 회차가 저장됩니다. ['10', '14', '15', '32', '36', '42']
# 323 회차 : [10, 14, 15, 32, 36, 42] 저장 됨
# {324} 회차가 저장됩니다. ['2', '4', '21', '25', '33', '36']
# 324 회차 : [2, 4, 21, 25, 33, 36] 저장 됨
# {325} 회차가 저장됩니다. ['7', '17', '20', '32', '44', '45']
# 325 회차 : [7, 17, 20, 32, 44, 45] 저장 됨
# {326} 회차가 저장됩니다. ['16', '23', '25', '33', '36', '39']
# 326 회차 : [16, 23, 25, 33, 36, 39] 저장 됨
# {327} 회차가 저장됩니다. ['6', '12', '13', '17', '32', '44']
# 327 회차 : [6, 12, 13, 17, 32, 44] 저장 됨
# {328} 회차가 저장됩니다. ['1', '6', '9', '16', '17', '28']
# 328 회차 : [1, 6, 9, 16, 17, 28] 저장 됨
# {329} 회차가 저장됩니다. ['9', '17', '19', '30', '35', '42']
# 329 회차 : [9, 17, 19, 30, 35, 42] 저장 됨
# {330} 회차가 저장됩니다. ['3', '4', '16', '17', '19', '20']
# 330 회차 : [3, 4, 16, 17, 19, 20] 저장 됨
# {331} 회차가 저장됩니다. ['4', '9', '14', '26', '31', '44']
# 331 회차 : [4, 9, 14, 26, 31, 44] 저장 됨
# {332} 회차가 저장됩니다. ['16', '17', '34', '36', '42', '45']
# 332 회차 : [16, 17, 34, 36, 42, 45] 저장 됨
# {333} 회차가 저장됩니다. ['9', '17', '19', '30', '35', '42']
# 333 회차 : [9, 17, 19, 30, 35, 42] 저장 됨
# {334} 회차가 저장됩니다. ['13', '15', '21', '29', '39', '43']
# 334 회차 : [13, 15, 21, 29, 39, 43] 저장 됨
# {335} 회차가 저장됩니다. ['5', '9', '16', '23', '26', '45']
# 335 회차 : [5, 9, 16, 23, 26, 45] 저장 됨
# {336} 회차가 저장됩니다. ['3', '5', '20', '34', '35', '44']
# 336 회차 : [3, 5, 20, 34, 35, 44] 저장 됨
# {337} 회차가 저장됩니다. ['1', '5', '14', '18', '32', '37']
# 337 회차 : [1, 5, 14, 18, 32, 37] 저장 됨
# {338} 회차가 저장됩니다. ['2', '13', '34', '38', '42', '45']
# 338 회차 : [2, 13, 34, 38, 42, 45] 저장 됨
# {339} 회차가 저장됩니다. ['6', '8', '14', '21', '30', '37']
# 339 회차 : [6, 8, 14, 21, 30, 37] 저장 됨
# {340} 회차가 저장됩니다. ['18', '24', '26', '29', '34', '38']
# 340 회차 : [18, 24, 26, 29, 34, 38] 저장 됨
# {341} 회차가 저장됩니다. ['1', '8', '19', '34', '39', '43']
# 341 회차 : [1, 8, 19, 34, 39, 43] 저장 됨
# {342} 회차가 저장됩니다. ['1', '13', '14', '33', '34', '43']
# 342 회차 : [1, 13, 14, 33, 34, 43] 저장 됨
# {343} 회차가 저장됩니다. ['1', '10', '17', '29', '31', '43']
# 343 회차 : [1, 10, 17, 29, 31, 43] 저장 됨
# {344} 회차가 저장됩니다. ['1', '2', '15', '28', '34', '45']
# 344 회차 : [1, 2, 15, 28, 34, 45] 저장 됨
# {345} 회차가 저장됩니다. ['15', '20', '23', '29', '39', '42']
# 345 회차 : [15, 20, 23, 29, 39, 42] 저장 됨
# {346} 회차가 저장됩니다. ['5', '13', '14', '22', '44', '45']
# 346 회차 : [5, 13, 14, 22, 44, 45] 저장 됨
# {347} 회차가 저장됩니다. ['3', '8', '13', '27', '32', '42']
# 347 회차 : [3, 8, 13, 27, 32, 42] 저장 됨
# {348} 회차가 저장됩니다. ['3', '14', '17', '20', '24', '31']
# 348 회차 : [3, 14, 17, 20, 24, 31] 저장 됨
# {349} 회차가 저장됩니다. ['5', '13', '14', '20', '24', '25']
# 349 회차 : [5, 13, 14, 20, 24, 25] 저장 됨
# {350} 회차가 저장됩니다. ['1', '8', '18', '24', '29', '33']
# 350 회차 : [1, 8, 18, 24, 29, 33] 저장 됨
# {351} 회차가 저장됩니다. ['5', '25', '27', '29', '34', '36']
# 351 회차 : [5, 25, 27, 29, 34, 36] 저장 됨
# {352} 회차가 저장됩니다. ['5', '16', '17', '20', '26', '41']
# 352 회차 : [5, 16, 17, 20, 26, 41] 저장 됨
# {353} 회차가 저장됩니다. ['11', '16', '19', '22', '29', '36']
# 353 회차 : [11, 16, 19, 22, 29, 36] 저장 됨
# {354} 회차가 저장됩니다. ['14', '19', '36', '43', '44', '45']
# 354 회차 : [14, 19, 36, 43, 44, 45] 저장 됨
# {355} 회차가 저장됩니다. ['5', '8', '29', '30', '35', '44']
# 355 회차 : [5, 8, 29, 30, 35, 44] 저장 됨
# {356} 회차가 저장됩니다. ['2', '8', '14', '25', '29', '45']
# 356 회차 : [2, 8, 14, 25, 29, 45] 저장 됨
# {357} 회차가 저장됩니다. ['10', '14', '18', '21', '36', '37']
# 357 회차 : [10, 14, 18, 21, 36, 37] 저장 됨
# {358} 회차가 저장됩니다. ['1', '9', '10', '12', '21', '40']
# 358 회차 : [1, 9, 10, 12, 21, 40] 저장 됨
# {359} 회차가 저장됩니다. ['1', '10', '19', '20', '24', '40']
# 359 회차 : [1, 10, 19, 20, 24, 40] 저장 됨
# {360} 회차가 저장됩니다. ['4', '16', '23', '25', '35', '40']
# 360 회차 : [4, 16, 23, 25, 35, 40] 저장 됨
# {361} 회차가 저장됩니다. ['5', '10', '16', '24', '27', '35']
# 361 회차 : [5, 10, 16, 24, 27, 35] 저장 됨
# {362} 회차가 저장됩니다. ['2', '3', '22', '27', '30', '40']
# 362 회차 : [2, 3, 22, 27, 30, 40] 저장 됨
# {363} 회차가 저장됩니다. ['11', '12', '14', '21', '32', '38']
# 363 회차 : [11, 12, 14, 21, 32, 38] 저장 됨
# {364} 회차가 저장됩니다. ['2', '5', '7', '14', '16', '40']
# 364 회차 : [2, 5, 7, 14, 16, 40] 저장 됨
# {365} 회차가 저장됩니다. ['5', '15', '21', '25', '26', '30']
# 365 회차 : [5, 15, 21, 25, 26, 30] 저장 됨
# {366} 회차가 저장됩니다. ['5', '12', '19', '26', '27', '44']
# 366 회차 : [5, 12, 19, 26, 27, 44] 저장 됨
# {367} 회차가 저장됩니다. ['3', '22', '25', '29', '32', '44']
# 367 회차 : [3, 22, 25, 29, 32, 44] 저장 됨
# {368} 회차가 저장됩니다. ['11', '21', '24', '30', '39', '45']
# 368 회차 : [11, 21, 24, 30, 39, 45] 저장 됨
# {369} 회차가 저장됩니다. ['17', '20', '35', '36', '41', '43']
# 369 회차 : [17, 20, 35, 36, 41, 43] 저장 됨
# {370} 회차가 저장됩니다. ['16', '18', '24', '42', '44', '45']
# 370 회차 : [16, 18, 24, 42, 44, 45] 저장 됨
# {371} 회차가 저장됩니다. ['7', '9', '15', '26', '27', '42']
# 371 회차 : [7, 9, 15, 26, 27, 42] 저장 됨
# {372} 회차가 저장됩니다. ['8', '11', '14', '16', '18', '21']
# 372 회차 : [8, 11, 14, 16, 18, 21] 저장 됨
# {373} 회차가 저장됩니다. ['15', '26', '37', '42', '43', '45']
# 373 회차 : [15, 26, 37, 42, 43, 45] 저장 됨
# {374} 회차가 저장됩니다. ['11', '13', '15', '17', '25', '34']
# 374 회차 : [11, 13, 15, 17, 25, 34] 저장 됨
# {375} 회차가 저장됩니다. ['4', '8', '19', '25', '27', '45']
# 375 회차 : [4, 8, 19, 25, 27, 45] 저장 됨
# {376} 회차가 저장됩니다. ['1', '11', '13', '24', '28', '40']
# 376 회차 : [1, 11, 13, 24, 28, 40] 저장 됨
# {377} 회차가 저장됩니다. ['6', '22', '29', '37', '43', '45']
# 377 회차 : [6, 22, 29, 37, 43, 45] 저장 됨
# {378} 회차가 저장됩니다. ['5', '22', '29', '31', '34', '39']
# 378 회차 : [5, 22, 29, 31, 34, 39] 저장 됨
# {379} 회차가 저장됩니다. ['6', '10', '22', '31', '35', '40']
# 379 회차 : [6, 10, 22, 31, 35, 40] 저장 됨
# {380} 회차가 저장됩니다. ['1', '2', '8', '17', '26', '37']
# 380 회차 : [1, 2, 8, 17, 26, 37] 저장 됨
# {381} 회차가 저장됩니다. ['1', '5', '10', '12', '16', '20']
# 381 회차 : [1, 5, 10, 12, 16, 20] 저장 됨
# {382} 회차가 저장됩니다. ['10', '15', '22', '24', '27', '42']
# 382 회차 : [10, 15, 22, 24, 27, 42] 저장 됨
# {383} 회차가 저장됩니다. ['4', '15', '28', '33', '37', '40']
# 383 회차 : [4, 15, 28, 33, 37, 40] 저장 됨
# {384} 회차가 저장됩니다. ['11', '22', '24', '32', '36', '38']
# 384 회차 : [11, 22, 24, 32, 36, 38] 저장 됨
# {385} 회차가 저장됩니다. ['7', '12', '19', '21', '29', '32']
# 385 회차 : [7, 12, 19, 21, 29, 32] 저장 됨
# {386} 회차가 저장됩니다. ['4', '7', '10', '19', '31', '40']
# 386 회차 : [4, 7, 10, 19, 31, 40] 저장 됨
# {387} 회차가 저장됩니다. ['1', '26', '31', '34', '40', '43']
# 387 회차 : [1, 26, 31, 34, 40, 43] 저장 됨
# {388} 회차가 저장됩니다. ['1', '8', '9', '17', '29', '32']
# 388 회차 : [1, 8, 9, 17, 29, 32] 저장 됨
# {389} 회차가 저장됩니다. ['7', '16', '18', '20', '23', '26']
# 389 회차 : [7, 16, 18, 20, 23, 26] 저장 됨
# {390} 회차가 저장됩니다. ['16', '17', '28', '37', '39', '40']
# 390 회차 : [16, 17, 28, 37, 39, 40] 저장 됨
# {391} 회차가 저장됩니다. ['10', '11', '18', '22', '28', '39']
# 391 회차 : [10, 11, 18, 22, 28, 39] 저장 됨
# {392} 회차가 저장됩니다. ['1', '3', '7', '8', '24', '42']
# 392 회차 : [1, 3, 7, 8, 24, 42] 저장 됨
# {393} 회차가 저장됩니다. ['9', '16', '28', '40', '41', '43']
# 393 회차 : [9, 16, 28, 40, 41, 43] 저장 됨
# {394} 회차가 저장됩니다. ['1', '13', '20', '22', '25', '28']
# 394 회차 : [1, 13, 20, 22, 25, 28] 저장 됨
# {395} 회차가 저장됩니다. ['11', '15', '20', '26', '31', '35']
# 395 회차 : [11, 15, 20, 26, 31, 35] 저장 됨
# {396} 회차가 저장됩니다. ['18', '20', '31', '34', '40', '45']
# 396 회차 : [18, 20, 31, 34, 40, 45] 저장 됨
# {397} 회차가 저장됩니다. ['12', '13', '17', '22', '25', '33']
# 397 회차 : [12, 13, 17, 22, 25, 33] 저장 됨
# {398} 회차가 저장됩니다. ['10', '15', '20', '23', '42', '44']
# 398 회차 : [10, 15, 20, 23, 42, 44] 저장 됨
# {399} 회차가 저장됩니다. ['1', '2', '9', '17', '19', '42']
# 399 회차 : [1, 2, 9, 17, 19, 42] 저장 됨
# {400} 회차가 저장됩니다. ['9', '21', '27', '34', '41', '43']
# 400 회차 : [9, 21, 27, 34, 41, 43] 저장 됨
# {401} 회차가 저장됩니다. ['6', '12', '18', '31', '38', '43']
# 401 회차 : [6, 12, 18, 31, 38, 43] 저장 됨
# {402} 회차가 저장됩니다. ['5', '9', '15', '19', '22', '36']
# 402 회차 : [5, 9, 15, 19, 22, 36] 저장 됨
# {403} 회차가 저장됩니다. ['10', '14', '22', '24', '28', '37']
# 403 회차 : [10, 14, 22, 24, 28, 37] 저장 됨
# {404} 회차가 저장됩니다. ['5', '20', '21', '24', '33', '40']
# 404 회차 : [5, 20, 21, 24, 33, 40] 저장 됨
# {405} 회차가 저장됩니다. ['1', '2', '10', '25', '26', '44']
# 405 회차 : [1, 2, 10, 25, 26, 44] 저장 됨
# {406} 회차가 저장됩니다. ['7', '12', '21', '24', '27', '36']
# 406 회차 : [7, 12, 21, 24, 27, 36] 저장 됨
# {407} 회차가 저장됩니다. ['6', '7', '13', '16', '24', '25']
# 407 회차 : [6, 7, 13, 16, 24, 25] 저장 됨
# {408} 회차가 저장됩니다. ['9', '20', '21', '22', '30', '37']
# 408 회차 : [9, 20, 21, 22, 30, 37] 저장 됨
# {409} 회차가 저장됩니다. ['6', '9', '21', '31', '32', '40']
# 409 회차 : [6, 9, 21, 31, 32, 40] 저장 됨
# {410} 회차가 저장됩니다. ['1', '3', '18', '32', '40', '41']
# 410 회차 : [1, 3, 18, 32, 40, 41] 저장 됨
# {411} 회차가 저장됩니다. ['11', '14', '22', '35', '37', '39']
# 411 회차 : [11, 14, 22, 35, 37, 39] 저장 됨
# {412} 회차가 저장됩니다. ['4', '7', '39', '41', '42', '45']
# 412 회차 : [4, 7, 39, 41, 42, 45] 저장 됨
# {413} 회차가 저장됩니다. ['2', '9', '15', '23', '34', '40']
# 413 회차 : [2, 9, 15, 23, 34, 40] 저장 됨
# {414} 회차가 저장됩니다. ['2', '14', '15', '22', '23', '44']
# 414 회차 : [2, 14, 15, 22, 23, 44] 저장 됨
# {415} 회차가 저장됩니다. ['7', '17', '20', '26', '30', '40']
# 415 회차 : [7, 17, 20, 26, 30, 40] 저장 됨
# {416} 회차가 저장됩니다. ['5', '6', '8', '11', '22', '26']
# 416 회차 : [5, 6, 8, 11, 22, 26] 저장 됨
# {417} 회차가 저장됩니다. ['4', '5', '14', '20', '22', '43']
# 417 회차 : [4, 5, 14, 20, 22, 43] 저장 됨
# {418} 회차가 저장됩니다. ['11', '13', '15', '26', '28', '34']
# 418 회차 : [11, 13, 15, 26, 28, 34] 저장 됨
# {419} 회차가 저장됩니다. ['2', '11', '13', '14', '28', '30']
# 419 회차 : [2, 11, 13, 14, 28, 30] 저장 됨
# {420} 회차가 저장됩니다. ['4', '9', '10', '29', '31', '34']
# 420 회차 : [4, 9, 10, 29, 31, 34] 저장 됨
# {421} 회차가 저장됩니다. ['6', '11', '26', '27', '28', '44']
# 421 회차 : [6, 11, 26, 27, 28, 44] 저장 됨
# {422} 회차가 저장됩니다. ['8', '15', '19', '21', '34', '44']
# 422 회차 : [8, 15, 19, 21, 34, 44] 저장 됨
# {423} 회차가 저장됩니다. ['1', '17', '27', '28', '29', '40']
# 423 회차 : [1, 17, 27, 28, 29, 40] 저장 됨
# {424} 회차가 저장됩니다. ['10', '11', '26', '31', '34', '44']
# 424 회차 : [10, 11, 26, 31, 34, 44] 저장 됨
# {425} 회차가 저장됩니다. ['8', '10', '14', '27', '33', '38']
# 425 회차 : [8, 10, 14, 27, 33, 38] 저장 됨
# {426} 회차가 저장됩니다. ['4', '17', '18', '27', '39', '43']
# 426 회차 : [4, 17, 18, 27, 39, 43] 저장 됨
# {427} 회차가 저장됩니다. ['6', '7', '15', '24', '28', '30']
# 427 회차 : [6, 7, 15, 24, 28, 30] 저장 됨
# {428} 회차가 저장됩니다. ['12', '16', '19', '22', '37', '40']
# 428 회차 : [12, 16, 19, 22, 37, 40] 저장 됨
# {429} 회차가 저장됩니다. ['3', '23', '28', '34', '39', '42']
# 429 회차 : [3, 23, 28, 34, 39, 42] 저장 됨
# {430} 회차가 저장됩니다. ['1', '3', '16', '18', '30', '34']
# 430 회차 : [1, 3, 16, 18, 30, 34] 저장 됨
# {431} 회차가 저장됩니다. ['18', '22', '25', '31', '38', '45']
# 431 회차 : [18, 22, 25, 31, 38, 45] 저장 됨
# {432} 회차가 저장됩니다. ['2', '3', '5', '11', '27', '39']
# 432 회차 : [2, 3, 5, 11, 27, 39] 저장 됨
# {433} 회차가 저장됩니다. ['19', '23', '29', '33', '35', '43']
# 433 회차 : [19, 23, 29, 33, 35, 43] 저장 됨
# {434} 회차가 저장됩니다. ['3', '13', '20', '24', '33', '37']
# 434 회차 : [3, 13, 20, 24, 33, 37] 저장 됨
# {435} 회차가 저장됩니다. ['8', '16', '26', '30', '38', '45']
# 435 회차 : [8, 16, 26, 30, 38, 45] 저장 됨
# {436} 회차가 저장됩니다. ['9', '14', '20', '22', '33', '34']
# 436 회차 : [9, 14, 20, 22, 33, 34] 저장 됨
# {437} 회차가 저장됩니다. ['11', '16', '29', '38', '41', '44']
# 437 회차 : [11, 16, 29, 38, 41, 44] 저장 됨
# {438} 회차가 저장됩니다. ['6', '12', '20', '26', '29', '38']
# 438 회차 : [6, 12, 20, 26, 29, 38] 저장 됨
# {439} 회차가 저장됩니다. ['17', '20', '30', '31', '37', '40']
# 439 회차 : [17, 20, 30, 31, 37, 40] 저장 됨
# {440} 회차가 저장됩니다. ['10', '22', '28', '34', '36', '44']
# 440 회차 : [10, 22, 28, 34, 36, 44] 저장 됨
# {441} 회차가 저장됩니다. ['1', '23', '28', '30', '34', '35']
# 441 회차 : [1, 23, 28, 30, 34, 35] 저장 됨
# {442} 회차가 저장됩니다. ['25', '27', '29', '36', '38', '40']
# 442 회차 : [25, 27, 29, 36, 38, 40] 저장 됨
# {443} 회차가 저장됩니다. ['4', '6', '10', '19', '20', '44']
# 443 회차 : [4, 6, 10, 19, 20, 44] 저장 됨
# {444} 회차가 저장됩니다. ['10', '22', '28', '34', '36', '44']
# 444 회차 : [10, 22, 28, 34, 36, 44] 저장 됨
# {445} 회차가 저장됩니다. ['13', '20', '21', '30', '39', '45']
# 445 회차 : [13, 20, 21, 30, 39, 45] 저장 됨
# {446} 회차가 저장됩니다. ['1', '11', '12', '14', '26', '35']
# 446 회차 : [1, 11, 12, 14, 26, 35] 저장 됨
# {447} 회차가 저장됩니다. ['2', '7', '8', '9', '17', '33']
# 447 회차 : [2, 7, 8, 9, 17, 33] 저장 됨
# {448} 회차가 저장됩니다. ['3', '7', '13', '27', '40', '41']
# 448 회차 : [3, 7, 13, 27, 40, 41] 저장 됨
# {449} 회차가 저장됩니다. ['3', '10', '20', '26', '35', '43']
# 449 회차 : [3, 10, 20, 26, 35, 43] 저장 됨
# {450} 회차가 저장됩니다. ['6', '14', '19', '21', '23', '31']
# 450 회차 : [6, 14, 19, 21, 23, 31] 저장 됨
# {451} 회차가 저장됩니다. ['12', '15', '20', '24', '30', '38']
# 451 회차 : [12, 15, 20, 24, 30, 38] 저장 됨
# {452} 회차가 저장됩니다. ['8', '10', '18', '30', '32', '34']
# 452 회차 : [8, 10, 18, 30, 32, 34] 저장 됨
# {453} 회차가 저장됩니다. ['12', '24', '33', '38', '40', '42']
# 453 회차 : [12, 24, 33, 38, 40, 42] 저장 됨
# {454} 회차가 저장됩니다. ['13', '25', '27', '34', '38', '41']
# 454 회차 : [13, 25, 27, 34, 38, 41] 저장 됨
# {455} 회차가 저장됩니다. ['4', '19', '20', '26', '30', '35']
# 455 회차 : [4, 19, 20, 26, 30, 35] 저장 됨
# {456} 회차가 저장됩니다. ['1', '7', '12', '18', '23', '27']
# 456 회차 : [1, 7, 12, 18, 23, 27] 저장 됨
# {457} 회차가 저장됩니다. ['8', '10', '18', '23', '27', '40']
# 457 회차 : [8, 10, 18, 23, 27, 40] 저장 됨
# {458} 회차가 저장됩니다. ['4', '9', '10', '32', '36', '40']
# 458 회차 : [4, 9, 10, 32, 36, 40] 저장 됨
# {459} 회차가 저장됩니다. ['4', '6', '10', '14', '25', '40']
# 459 회차 : [4, 6, 10, 14, 25, 40] 저장 됨
# {460} 회차가 저장됩니다. ['8', '11', '28', '30', '43', '45']
# 460 회차 : [8, 11, 28, 30, 43, 45] 저장 됨
# {461} 회차가 저장됩니다. ['11', '18', '26', '31', '37', '40']
# 461 회차 : [11, 18, 26, 31, 37, 40] 저장 됨
# {462} 회차가 저장됩니다. ['3', '20', '24', '32', '37', '45']
# 462 회차 : [3, 20, 24, 32, 37, 45] 저장 됨
# {463} 회차가 저장됩니다. ['23', '29', '31', '33', '34', '44']
# 463 회차 : [23, 29, 31, 33, 34, 44] 저장 됨
# {464} 회차가 저장됩니다. ['6', '12', '15', '34', '42', '44']
# 464 회차 : [6, 12, 15, 34, 42, 44] 저장 됨
# {465} 회차가 저장됩니다. ['1', '8', '11', '13', '22', '38']
# 465 회차 : [1, 8, 11, 13, 22, 38] 저장 됨
# {466} 회차가 저장됩니다. ['4', '10', '13', '23', '32', '44']
# 466 회차 : [4, 10, 13, 23, 32, 44] 저장 됨
# {467} 회차가 저장됩니다. ['2', '12', '14', '17', '24', '40']
# 467 회차 : [2, 12, 14, 17, 24, 40] 저장 됨
# {468} 회차가 저장됩니다. ['8', '13', '15', '28', '37', '43']
# 468 회차 : [8, 13, 15, 28, 37, 43] 저장 됨
# {469} 회차가 저장됩니다. ['4', '21', '22', '34', '37', '38']
# 469 회차 : [4, 21, 22, 34, 37, 38] 저장 됨
# {470} 회차가 저장됩니다. ['10', '16', '20', '39', '41', '42']
# 470 회차 : [10, 16, 20, 39, 41, 42] 저장 됨
# {471} 회차가 저장됩니다. ['6', '13', '29', '37', '39', '41']
# 471 회차 : [6, 13, 29, 37, 39, 41] 저장 됨
# {472} 회차가 저장됩니다. ['16', '25', '26', '31', '36', '43']
# 472 회차 : [16, 25, 26, 31, 36, 43] 저장 됨
# {473} 회차가 저장됩니다. ['8', '13', '20', '22', '23', '36']
# 473 회차 : [8, 13, 20, 22, 23, 36] 저장 됨
# {474} 회차가 저장됩니다. ['4', '13', '18', '31', '33', '45']
# 474 회차 : [4, 13, 18, 31, 33, 45] 저장 됨
# {475} 회차가 저장됩니다. ['1', '9', '14', '16', '21', '29']
# 475 회차 : [1, 9, 14, 16, 21, 29] 저장 됨
# {476} 회차가 저장됩니다. ['9', '12', '13', '15', '37', '38']
# 476 회차 : [9, 12, 13, 15, 37, 38] 저장 됨
# {477} 회차가 저장됩니다. ['14', '25', '29', '32', '33', '45']
# 477 회차 : [14, 25, 29, 32, 33, 45] 저장 됨
# {478} 회차가 저장됩니다. ['18', '29', '30', '37', '39', '43']
# 478 회차 : [18, 29, 30, 37, 39, 43] 저장 됨
# {479} 회차가 저장됩니다. ['8', '23', '25', '27', '35', '44']
# 479 회차 : [8, 23, 25, 27, 35, 44] 저장 됨
# {480} 회차가 저장됩니다. ['3', '5', '10', '17', '30', '31']
# 480 회차 : [3, 5, 10, 17, 30, 31] 저장 됨
# {481} 회차가 저장됩니다. ['3', '4', '23', '29', '40', '41']
# 481 회차 : [3, 4, 23, 29, 40, 41] 저장 됨
# {482} 회차가 저장됩니다. ['1', '10', '16', '24', '25', '35']
# 482 회차 : [1, 10, 16, 24, 25, 35] 저장 됨
# {483} 회차가 저장됩니다. ['12', '15', '19', '22', '28', '34']
# 483 회차 : [12, 15, 19, 22, 28, 34] 저장 됨
# {484} 회차가 저장됩니다. ['1', '3', '27', '28', '32', '45']
# 484 회차 : [1, 3, 27, 28, 32, 45] 저장 됨
# {485} 회차가 저장됩니다. ['17', '22', '26', '27', '36', '39']
# 485 회차 : [17, 22, 26, 27, 36, 39] 저장 됨
# {486} 회차가 저장됩니다. ['1', '2', '23', '25', '38', '40']
# 486 회차 : [1, 2, 23, 25, 38, 40] 저장 됨
# {487} 회차가 저장됩니다. ['4', '8', '25', '27', '37', '41']
# 487 회차 : [4, 8, 25, 27, 37, 41] 저장 됨
# {488} 회차가 저장됩니다. ['2', '8', '17', '30', '31', '38']
# 488 회차 : [2, 8, 17, 30, 31, 38] 저장 됨
# {489} 회차가 저장됩니다. ['2', '4', '8', '15', '20', '27']
# 489 회차 : [2, 4, 8, 15, 20, 27] 저장 됨
# {490} 회차가 저장됩니다. ['2', '7', '26', '29', '40', '43']
# 490 회차 : [2, 7, 26, 29, 40, 43] 저장 됨
# {491} 회차가 저장됩니다. ['8', '17', '35', '36', '39', '42']
# 491 회차 : [8, 17, 35, 36, 39, 42] 저장 됨
# {492} 회차가 저장됩니다. ['22', '27', '31', '35', '37', '40']
# 492 회차 : [22, 27, 31, 35, 37, 40] 저장 됨
# {493} 회차가 저장됩니다. ['20', '22', '26', '33', '36', '37']
# 493 회차 : [20, 22, 26, 33, 36, 37] 저장 됨
# {494} 회차가 저장됩니다. ['5', '7', '8', '15', '30', '43']
# 494 회차 : [5, 7, 8, 15, 30, 43] 저장 됨
# {495} 회차가 저장됩니다. ['4', '13', '22', '27', '34', '44']
# 495 회차 : [4, 13, 22, 27, 34, 44] 저장 됨
# {496} 회차가 저장됩니다. ['4', '13', '20', '29', '36', '41']
# 496 회차 : [4, 13, 20, 29, 36, 41] 저장 됨
# {497} 회차가 저장됩니다. ['19', '20', '23', '24', '43', '44']
# 497 회차 : [19, 20, 23, 24, 43, 44] 저장 됨
# {498} 회차가 저장됩니다. ['13', '14', '24', '32', '39', '41']
# 498 회차 : [13, 14, 24, 32, 39, 41] 저장 됨
# {499} 회차가 저장됩니다. ['5', '20', '23', '27', '35', '40']
# 499 회차 : [5, 20, 23, 27, 35, 40] 저장 됨
# {500} 회차가 저장됩니다. ['3', '4', '12', '20', '24', '34']
# 500 회차 : [3, 4, 12, 20, 24, 34] 저장 됨
# {501} 회차가 저장됩니다. ['1', '4', '10', '17', '31', '42']
# 501 회차 : [1, 4, 10, 17, 31, 42] 저장 됨
# {502} 회차가 저장됩니다. ['6', '22', '28', '32', '34', '40']
# 502 회차 : [6, 22, 28, 32, 34, 40] 저장 됨
# {503} 회차가 저장됩니다. ['1', '5', '27', '30', '34', '36']
# 503 회차 : [1, 5, 27, 30, 34, 36] 저장 됨
# {504} 회차가 저장됩니다. ['6', '14', '22', '26', '43', '44']
# 504 회차 : [6, 14, 22, 26, 43, 44] 저장 됨
# {505} 회차가 저장됩니다. ['7', '20', '22', '25', '38', '40']
# 505 회차 : [7, 20, 22, 25, 38, 40] 저장 됨
# {506} 회차가 저장됩니다. ['6', '9', '11', '22', '24', '30']
# 506 회차 : [6, 9, 11, 22, 24, 30] 저장 됨
# {507} 회차가 저장됩니다. ['12', '13', '32', '33', '40', '41']
# 507 회차 : [12, 13, 32, 33, 40, 41] 저장 됨
# {508} 회차가 저장됩니다. ['5', '27', '31', '34', '35', '43']
# 508 회차 : [5, 27, 31, 34, 35, 43] 저장 됨
# {509} 회차가 저장됩니다. ['12', '25', '29', '35', '42', '43']
# 509 회차 : [12, 25, 29, 35, 42, 43] 저장 됨
# {510} 회차가 저장됩니다. ['12', '29', '32', '33', '39', '40']
# 510 회차 : [12, 29, 32, 33, 39, 40] 저장 됨
# {511} 회차가 저장됩니다. ['3', '7', '14', '23', '26', '42']
# 511 회차 : [3, 7, 14, 23, 26, 42] 저장 됨
# {512} 회차가 저장됩니다. ['4', '5', '9', '13', '26', '27']
# 512 회차 : [4, 5, 9, 13, 26, 27] 저장 됨
# {513} 회차가 저장됩니다. ['5', '8', '21', '23', '27', '33']
# 513 회차 : [5, 8, 21, 23, 27, 33] 저장 됨
# {514} 회차가 저장됩니다. ['1', '15', '20', '26', '35', '42']
# 514 회차 : [1, 15, 20, 26, 35, 42] 저장 됨
# {515} 회차가 저장됩니다. ['2', '11', '12', '15', '23', '37']
# 515 회차 : [2, 11, 12, 15, 23, 37] 저장 됨
# {516} 회차가 저장됩니다. ['2', '8', '23', '41', '43', '44']
# 516 회차 : [2, 8, 23, 41, 43, 44] 저장 됨
# {517} 회차가 저장됩니다. ['1', '9', '12', '28', '36', '41']
# 517 회차 : [1, 9, 12, 28, 36, 41] 저장 됨
# {518} 회차가 저장됩니다. ['14', '23', '30', '32', '34', '38']
# 518 회차 : [14, 23, 30, 32, 34, 38] 저장 됨
# {519} 회차가 저장됩니다. ['6', '8', '13', '16', '30', '43']
# 519 회차 : [6, 8, 13, 16, 30, 43] 저장 됨
# {520} 회차가 저장됩니다. ['4', '22', '27', '28', '38', '40']
# 520 회차 : [4, 22, 27, 28, 38, 40] 저장 됨
# {521} 회차가 저장됩니다. ['3', '7', '18', '29', '32', '36']
# 521 회차 : [3, 7, 18, 29, 32, 36] 저장 됨
# {522} 회차가 저장됩니다. ['4', '5', '13', '14', '37', '41']
# 522 회차 : [4, 5, 13, 14, 37, 41] 저장 됨
# {523} 회차가 저장됩니다. ['1', '4', '37', '38', '40', '45']
# 523 회차 : [1, 4, 37, 38, 40, 45] 저장 됨
# {524} 회차가 저장됩니다. ['10', '11', '29', '38', '41', '45']
# 524 회차 : [10, 11, 29, 38, 41, 45] 저장 됨
# {525} 회차가 저장됩니다. ['11', '23', '26', '29', '39', '44']
# 525 회차 : [11, 23, 26, 29, 39, 44] 저장 됨
# {526} 회차가 저장됩니다. ['7', '14', '17', '20', '35', '39']
# 526 회차 : [7, 14, 17, 20, 35, 39] 저장 됨
# {527} 회차가 저장됩니다. ['1', '12', '22', '32', '33', '42']
# 527 회차 : [1, 12, 22, 32, 33, 42] 저장 됨
# {528} 회차가 저장됩니다. ['5', '17', '25', '31', '39', '40']
# 528 회차 : [5, 17, 25, 31, 39, 40] 저장 됨
# {529} 회차가 저장됩니다. ['18', '20', '24', '27', '31', '42']
# 529 회차 : [18, 20, 24, 27, 31, 42] 저장 됨
# {530} 회차가 저장됩니다. ['16', '23', '27', '29', '33', '41']
# 530 회차 : [16, 23, 27, 29, 33, 41] 저장 됨
# {531} 회차가 저장됩니다. ['1', '5', '9', '21', '27', '35']
# 531 회차 : [1, 5, 9, 21, 27, 35] 저장 됨
# {532} 회차가 저장됩니다. ['16', '17', '23', '24', '29', '44']
# ...
# 849 회차 : [5, 13, 17, 29, 34, 39] 저장 됨
# {850} 회차가 저장됩니다. ['16', '20', '24', '28', '36', '39']
# 850 회차 : [16, 20, 24, 28, 36, 39] 저장 됨
# {851} 회차가 저장됩니다. ['14', '18', '22', '26', '31', '44']
# 851 회차 : [14, 18, 22, 26, 31, 44] 저장 됨
# {852} 회차가 저장됩니다. ['11', '17', '28', '30', '33', '35']
# 852 회차 : [11, 17, 28, 30, 33, 35] 저장 됨
# {853} 회차가 저장됩니다. ['2', '8', '23', '26', '27', '44']
# 853 회차 : [2, 8, 23, 26, 27, 44] 저장 됨
# {854} 회차가 저장됩니다. ['20', '25', '31', '32', '36', '43']
# 854 회차 : [20, 25, 31, 32, 36, 43] 저장 됨
# {855} 회차가 저장됩니다. ['8', '15', '17', '19', '43', '44']
# 855 회차 : [8, 15, 17, 19, 43, 44] 저장 됨
# {856} 회차가 저장됩니다. ['10', '24', '40', '41', '43', '44']
# 856 회차 : [10, 24, 40, 41, 43, 44] 저장 됨
# {857} 회차가 저장됩니다. ['6', '10', '16', '28', '34', '38']
# 857 회차 : [6, 10, 16, 28, 34, 38] 저장 됨
# {858} 회차가 저장됩니다. ['9', '13', '32', '38', '39', '43']
# 858 회차 : [9, 13, 32, 38, 39, 43] 저장 됨
# {859} 회차가 저장됩니다. ['8', '22', '35', '38', '39', '41']
# 859 회차 : [8, 22, 35, 38, 39, 41] 저장 됨
# {860} 회차가 저장됩니다. ['4', '8', '18', '25', '27', '32']
# 860 회차 : [4, 8, 18, 25, 27, 32] 저장 됨
# {861} 회차가 저장됩니다. ['11', '17', '19', '21', '22', '25']
# 861 회차 : [11, 17, 19, 21, 22, 25] 저장 됨
# {862} 회차가 저장됩니다. ['10', '34', '38', '40', '42', '43']
# 862 회차 : [10, 34, 38, 40, 42, 43] 저장 됨
# {863} 회차가 저장됩니다. ['16', '21', '28', '35', '39', '43']
# 863 회차 : [16, 21, 28, 35, 39, 43] 저장 됨
# {864} 회차가 저장됩니다. ['3', '7', '10', '13', '25', '36']
# 864 회차 : [3, 7, 10, 13, 25, 36] 저장 됨
# {865} 회차가 저장됩니다. ['3', '15', '22', '32', '33', '45']
# 865 회차 : [3, 15, 22, 32, 33, 45] 저장 됨
# {866} 회차가 저장됩니다. ['9', '15', '29', '34', '37', '39']
# 866 회차 : [9, 15, 29, 34, 37, 39] 저장 됨
# {867} 회차가 저장됩니다. ['14', '17', '19', '22', '24', '40']
# 867 회차 : [14, 17, 19, 22, 24, 40] 저장 됨
# {868} 회차가 저장됩니다. ['12', '17', '28', '41', '43', '44']
# 868 회차 : [12, 17, 28, 41, 43, 44] 저장 됨
# {869} 회차가 저장됩니다. ['2', '6', '20', '27', '37', '39']
# 869 회차 : [2, 6, 20, 27, 37, 39] 저장 됨
# {870} 회차가 저장됩니다. ['21', '25', '30', '32', '40', '42']
# 870 회차 : [21, 25, 30, 32, 40, 42] 저장 됨
# {871} 회차가 저장됩니다. ['2', '6', '12', '26', '30', '34']
# 871 회차 : [2, 6, 12, 26, 30, 34] 저장 됨
# {872} 회차가 저장됩니다. ['2', '4', '30', '32', '33', '43']
# 872 회차 : [2, 4, 30, 32, 33, 43] 저장 됨
# {873} 회차가 저장됩니다. ['3', '5', '12', '13', '33', '39']
# 873 회차 : [3, 5, 12, 13, 33, 39] 저장 됨
# {874} 회차가 저장됩니다. ['1', '15', '19', '23', '28', '42']
# 874 회차 : [1, 15, 19, 23, 28, 42] 저장 됨
# {875} 회차가 저장됩니다. ['19', '22', '30', '34', '39', '44']
# 875 회차 : [19, 22, 30, 34, 39, 44] 저장 됨
# {876} 회차가 저장됩니다. ['5', '16', '21', '26', '34', '42']
# 876 회차 : [5, 16, 21, 26, 34, 42] 저장 됨
# {877} 회차가 저장됩니다. ['5', '17', '18', '22', '23', '43']
# 877 회차 : [5, 17, 18, 22, 23, 43] 저장 됨
# {878} 회차가 저장됩니다. ['2', '6', '11', '16', '25', '31']
# 878 회차 : [2, 6, 11, 16, 25, 31] 저장 됨
# {879} 회차가 저장됩니다. ['1', '4', '10', '14', '15', '35']
# 879 회차 : [1, 4, 10, 14, 15, 35] 저장 됨
# {880} 회차가 저장됩니다. ['7', '17', '19', '23', '24', '45']
# 880 회차 : [7, 17, 19, 23, 24, 45] 저장 됨
# {881} 회차가 저장됩니다. ['4', '18', '20', '26', '27', '32']
# 881 회차 : [4, 18, 20, 26, 27, 32] 저장 됨
# {882} 회차가 저장됩니다. ['18', '34', '39', '43', '44', '45']
# 882 회차 : [18, 34, 39, 43, 44, 45] 저장 됨
# {883} 회차가 저장됩니다. ['9', '18', '32', '33', '37', '44']
# 883 회차 : [9, 18, 32, 33, 37, 44] 저장 됨
# {884} 회차가 저장됩니다. ['4', '14', '23', '28', '37', '45']
# 884 회차 : [4, 14, 23, 28, 37, 45] 저장 됨
# {885} 회차가 저장됩니다. ['1', '3', '24', '27', '39', '45']
# 885 회차 : [1, 3, 24, 27, 39, 45] 저장 됨
# {886} 회차가 저장됩니다. ['19', '23', '28', '37', '42', '45']
# 886 회차 : [19, 23, 28, 37, 42, 45] 저장 됨
# {887} 회차가 저장됩니다. ['8', '14', '17', '27', '36', '45']
# 887 회차 : [8, 14, 17, 27, 36, 45] 저장 됨
# {888} 회차가 저장됩니다. ['4', '14', '23', '28', '37', '45']
# 888 회차 : [4, 14, 23, 28, 37, 45] 저장 됨
# {889} 회차가 저장됩니다. ['3', '13', '29', '38', '39', '42']
# 889 회차 : [3, 13, 29, 38, 39, 42] 저장 됨
# {890} 회차가 저장됩니다. ['1', '4', '14', '18', '29', '37']
# 890 회차 : [1, 4, 14, 18, 29, 37] 저장 됨
# {891} 회차가 저장됩니다. ['9', '13', '28', '31', '39', '41']
# 891 회차 : [9, 13, 28, 31, 39, 41] 저장 됨
# {892} 회차가 저장됩니다. ['4', '9', '17', '18', '26', '42']
# 892 회차 : [4, 9, 17, 18, 26, 42] 저장 됨
# {893} 회차가 저장됩니다. ['1', '15', '17', '23', '25', '41']
# 893 회차 : [1, 15, 17, 23, 25, 41] 저장 됨
# {894} 회차가 저장됩니다. ['19', '32', '37', '40', '41', '43']
# 894 회차 : [19, 32, 37, 40, 41, 43] 저장 됨
# {895} 회차가 저장됩니다. ['16', '26', '31', '38', '39', '41']
# 895 회차 : [16, 26, 31, 38, 39, 41] 저장 됨
# {896} 회차가 저장됩니다. ['5', '12', '25', '26', '38', '45']
# 896 회차 : [5, 12, 25, 26, 38, 45] 저장 됨
# {897} 회차가 저장됩니다. ['6', '7', '12', '22', '26', '36']
# 897 회차 : [6, 7, 12, 22, 26, 36] 저장 됨
# {898} 회차가 저장됩니다. ['18', '21', '28', '35', '37', '42']
# 898 회차 : [18, 21, 28, 35, 37, 42] 저장 됨
# {899} 회차가 저장됩니다. ['8', '19', '20', '21', '33', '39']
# 899 회차 : [8, 19, 20, 21, 33, 39] 저장 됨
# {900} 회차가 저장됩니다. ['7', '13', '16', '18', '35', '38']
# 900 회차 : [7, 13, 16, 18, 35, 38] 저장 됨
# {901} 회차가 저장됩니다. ['5', '18', '20', '23', '30', '34']
# 901 회차 : [5, 18, 20, 23, 30, 34] 저장 됨
# {902} 회차가 저장됩니다. ['7', '19', '23', '24', '36', '39']
# 902 회차 : [7, 19, 23, 24, 36, 39] 저장 됨
# {903} 회차가 저장됩니다. ['2', '15', '16', '21', '22', '28']
# 903 회차 : [2, 15, 16, 21, 22, 28] 저장 됨
# {904} 회차가 저장됩니다. ['2', '6', '8', '26', '43', '45']
# 904 회차 : [2, 6, 8, 26, 43, 45] 저장 됨
# {905} 회차가 저장됩니다. ['3', '4', '16', '27', '38', '40']
# 905 회차 : [3, 4, 16, 27, 38, 40] 저장 됨
# {906} 회차가 저장됩니다. ['2', '5', '14', '28', '31', '32']
# 906 회차 : [2, 5, 14, 28, 31, 32] 저장 됨
# {907} 회차가 저장됩니다. ['21', '27', '29', '38', '40', '44']
# 907 회차 : [21, 27, 29, 38, 40, 44] 저장 됨
# {908} 회차가 저장됩니다. ['3', '16', '21', '22', '23', '44']
# 908 회차 : [3, 16, 21, 22, 23, 44] 저장 됨
# {909} 회차가 저장됩니다. ['7', '24', '29', '30', '34', '35']
# 909 회차 : [7, 24, 29, 30, 34, 35] 저장 됨
# {910} 회차가 저장됩니다. ['1', '11', '17', '27', '35', '39']
# 910 회차 : [1, 11, 17, 27, 35, 39] 저장 됨
# {911} 회차가 저장됩니다. ['4', '5', '12', '14', '32', '42']
# 911 회차 : [4, 5, 12, 14, 32, 42] 저장 됨
# {912} 회차가 저장됩니다. ['5', '8', '18', '21', '22', '38']
# 912 회차 : [5, 8, 18, 21, 22, 38] 저장 됨
# {913} 회차가 저장됩니다. ['6', '14', '16', '21', '27', '37']
# 913 회차 : [6, 14, 16, 21, 27, 37] 저장 됨
# {914} 회차가 저장됩니다. ['16', '19', '24', '33', '42', '44']
# 914 회차 : [16, 19, 24, 33, 42, 44] 저장 됨
# {915} 회차가 저장됩니다. ['2', '6', '11', '13', '22', '37']
# 915 회차 : [2, 6, 11, 13, 22, 37] 저장 됨
# {916} 회차가 저장됩니다. ['6', '21', '22', '32', '35', '36']
# 916 회차 : [6, 21, 22, 32, 35, 36] 저장 됨
# {917} 회차가 저장됩니다. ['1', '3', '23', '24', '27', '43']
# 917 회차 : [1, 3, 23, 24, 27, 43] 저장 됨
# {918} 회차가 저장됩니다. ['7', '11', '12', '31', '33', '38']
# 918 회차 : [7, 11, 12, 31, 33, 38] 저장 됨
# {919} 회차가 저장됩니다. ['9', '14', '17', '18', '42', '44']
# 919 회차 : [9, 14, 17, 18, 42, 44] 저장 됨
# {920} 회차가 저장됩니다. ['2', '3', '26', '33', '34', '43']
# 920 회차 : [2, 3, 26, 33, 34, 43] 저장 됨
# {921} 회차가 저장됩니다. ['5', '7', '12', '22', '28', '41']
# 921 회차 : [5, 7, 12, 22, 28, 41] 저장 됨
# {922} 회차가 저장됩니다. ['2', '6', '13', '17', '27', '43']
# 922 회차 : [2, 6, 13, 17, 27, 43] 저장 됨
# {923} 회차가 저장됩니다. ['3', '17', '18', '23', '36', '41']
# 923 회차 : [3, 17, 18, 23, 36, 41] 저장 됨
# {924} 회차가 저장됩니다. ['3', '11', '34', '42', '43', '44']
# 924 회차 : [3, 11, 34, 42, 43, 44] 저장 됨
# {925} 회차가 저장됩니다. ['13', '24', '32', '34', '39', '42']
# 925 회차 : [13, 24, 32, 34, 39, 42] 저장 됨
# {926} 회차가 저장됩니다. ['10', '16', '18', '20', '25', '31']
# 926 회차 : [10, 16, 18, 20, 25, 31] 저장 됨
# {927} 회차가 저장됩니다. ['4', '15', '22', '38', '41', '43']
# 927 회차 : [4, 15, 22, 38, 41, 43] 저장 됨
# {928} 회차가 저장됩니다. ['3', '4', '10', '20', '28', '44']
# 928 회차 : [3, 4, 10, 20, 28, 44] 저장 됨
# {929} 회차가 저장됩니다. ['7', '9', '12', '15', '19', '23']
# 929 회차 : [7, 9, 12, 15, 19, 23] 저장 됨
# {930} 회차가 저장됩니다. ['8', '21', '25', '38', '39', '44']
# 930 회차 : [8, 21, 25, 38, 39, 44] 저장 됨
# {931} 회차가 저장됩니다. ['14', '15', '23', '25', '35', '43']
# 931 회차 : [14, 15, 23, 25, 35, 43] 저장 됨
# {932} 회차가 저장됩니다. ['1', '6', '15', '36', '37', '38']
# 932 회차 : [1, 6, 15, 36, 37, 38] 저장 됨
# {933} 회차가 저장됩니다. ['23', '27', '29', '31', '36', '45']
# 933 회차 : [23, 27, 29, 31, 36, 45] 저장 됨
# {934} 회차가 저장됩니다. ['1', '3', '30', '33', '36', '39']
# 934 회차 : [1, 3, 30, 33, 36, 39] 저장 됨
# {935} 회차가 저장됩니다. ['4', '10', '20', '32', '38', '44']
# 935 회차 : [4, 10, 20, 32, 38, 44] 저장 됨
# {936} 회차가 저장됩니다. ['7', '11', '13', '17', '18', '29']
# 936 회차 : [7, 11, 13, 17, 18, 29] 저장 됨
# {937} 회차가 저장됩니다. ['2', '10', '13', '22', '29', '40']
# 937 회차 : [2, 10, 13, 22, 29, 40] 저장 됨
# {938} 회차가 저장됩니다. ['4', '8', '10', '16', '31', '36']
# 938 회차 : [4, 8, 10, 16, 31, 36] 저장 됨
# {939} 회차가 저장됩니다. ['4', '11', '28', '39', '42', '45']
# 939 회차 : [4, 11, 28, 39, 42, 45] 저장 됨
# {940} 회차가 저장됩니다. ['3', '15', '20', '22', '24', '41']
# 940 회차 : [3, 15, 20, 22, 24, 41] 저장 됨
# {941} 회차가 저장됩니다. ['12', '14', '25', '27', '39', '40']
# 941 회차 : [12, 14, 25, 27, 39, 40] 저장 됨
# {942} 회차가 저장됩니다. ['10', '12', '18', '35', '42', '43']
# 942 회차 : [10, 12, 18, 35, 42, 43] 저장 됨
# {943} 회차가 저장됩니다. ['1', '8', '13', '36', '44', '45']
# 943 회차 : [1, 8, 13, 36, 44, 45] 저장 됨
# {944} 회차가 저장됩니다. ['2', '13', '16', '19', '32', '33']
# 944 회차 : [2, 13, 16, 19, 32, 33] 저장 됨
# {945} 회차가 저장됩니다. ['9', '10', '15', '30', '33', '37']
# 945 회차 : [9, 10, 15, 30, 33, 37] 저장 됨
# {946} 회차가 저장됩니다. ['9', '18', '19', '30', '34', '40']
# 946 회차 : [9, 18, 19, 30, 34, 40] 저장 됨
# {947} 회차가 저장됩니다. ['3', '8', '17', '20', '27', '35']
# 947 회차 : [3, 8, 17, 20, 27, 35] 저장 됨
# {948} 회차가 저장됩니다. ['13', '18', '30', '31', '38', '41']
# 948 회차 : [13, 18, 30, 31, 38, 41] 저장 됨
# {949} 회차가 저장됩니다. ['14', '21', '35', '36', '40', '44']
# 949 회차 : [14, 21, 35, 36, 40, 44] 저장 됨
# {950} 회차가 저장됩니다. ['3', '4', '15', '22', '28', '40']
# 950 회차 : [3, 4, 15, 22, 28, 40] 저장 됨
# {951} 회차가 저장됩니다. ['2', '12', '30', '31', '39', '43']
# 951 회차 : [2, 12, 30, 31, 39, 43] 저장 됨
# {952} 회차가 저장됩니다. ['4', '12', '22', '24', '33', '41']
# 952 회차 : [4, 12, 22, 24, 33, 41] 저장 됨
# {953} 회차가 저장됩니다. ['7', '9', '22', '27', '37', '42']
# 953 회차 : [7, 9, 22, 27, 37, 42] 저장 됨
# {954} 회차가 저장됩니다. ['1', '9', '26', '28', '30', '41']
# 954 회차 : [1, 9, 26, 28, 30, 41] 저장 됨
# {955} 회차가 저장됩니다. ['4', '9', '23', '26', '29', '33']
# 955 회차 : [4, 9, 23, 26, 29, 33] 저장 됨
# {956} 회차가 저장됩니다. ['10', '11', '20', '21', '25', '41']
# 956 회차 : [10, 11, 20, 21, 25, 41] 저장 됨
# {957} 회차가 저장됩니다. ['4', '15', '24', '35', '36', '40']
# 957 회차 : [4, 15, 24, 35, 36, 40] 저장 됨
# {958} 회차가 저장됩니다. ['2', '9', '10', '16', '35', '37']
# 958 회차 : [2, 9, 10, 16, 35, 37] 저장 됨
# {959} 회차가 저장됩니다. ['1', '14', '15', '24', '40', '41']
# 959 회차 : [1, 14, 15, 24, 40, 41] 저장 됨
# {960} 회차가 저장됩니다. ['2', '18', '24', '30', '32', '45']
# 960 회차 : [2, 18, 24, 30, 32, 45] 저장 됨
# {961} 회차가 저장됩니다. ['11', '20', '29', '31', '33', '42']
# 961 회차 : [11, 20, 29, 31, 33, 42] 저장 됨
# {962} 회차가 저장됩니다. ['1', '18', '28', '31', '34', '43']
# 962 회차 : [1, 18, 28, 31, 34, 43] 저장 됨
# {963} 회차가 저장됩니다. ['6', '12', '19', '23', '34', '42']
# 963 회차 : [6, 12, 19, 23, 34, 42] 저장 됨
# {964} 회차가 저장됩니다. ['6', '21', '36', '38', '39', '43']
# 964 회차 : [6, 21, 36, 38, 39, 43] 저장 됨
# {965} 회차가 저장됩니다. ['2', '13', '25', '28', '29', '36']
# 965 회차 : [2, 13, 25, 28, 29, 36] 저장 됨
# {966} 회차가 저장됩니다. ['1', '21', '25', '29', '34', '37']
# 966 회차 : [1, 21, 25, 29, 34, 37] 저장 됨
# {967} 회차가 저장됩니다. ['1', '6', '13', '37', '38', '40']
# 967 회차 : [1, 6, 13, 37, 38, 40] 저장 됨
# {968} 회차가 저장됩니다. ['2', '5', '12', '14', '24', '39']
# 968 회차 : [2, 5, 12, 14, 24, 39] 저장 됨
# {969} 회차가 저장됩니다. ['3', '9', '10', '29', '40', '45']
# 969 회차 : [3, 9, 10, 29, 40, 45] 저장 됨
# {970} 회차가 저장됩니다. ['9', '11', '16', '21', '28', '36']
# 970 회차 : [9, 11, 16, 21, 28, 36] 저장 됨
# {971} 회차가 저장됩니다. ['2', '6', '17', '18', '21', '26']
# 971 회차 : [2, 6, 17, 18, 21, 26] 저장 됨
# {972} 회차가 저장됩니다. ['3', '6', '17', '23', '37', '39']
# 972 회차 : [3, 6, 17, 23, 37, 39] 저장 됨
# {973} 회차가 저장됩니다. ['22', '26', '31', '37', '41', '42']
# 973 회차 : [22, 26, 31, 37, 41, 42] 저장 됨
# {974} 회차가 저장됩니다. ['1', '2', '11', '16', '39', '44']
# 974 회차 : [1, 2, 11, 16, 39, 44] 저장 됨
# {975} 회차가 저장됩니다. ['7', '8', '9', '17', '22', '24']
# 975 회차 : [7, 8, 9, 17, 22, 24] 저장 됨
# {976} 회차가 저장됩니다. ['4', '12', '14', '25', '35', '37']
# 976 회차 : [4, 12, 14, 25, 35, 37] 저장 됨
# {977} 회차가 저장됩니다. ['2', '9', '10', '14', '22', '44']
# 977 회차 : [2, 9, 10, 14, 22, 44] 저장 됨
# {978} 회차가 저장됩니다. ['1', '7', '15', '32', '34', '42']
# 978 회차 : [1, 7, 15, 32, 34, 42] 저장 됨
# {979} 회차가 저장됩니다. ['7', '11', '16', '21', '27', '33']
# 979 회차 : [7, 11, 16, 21, 27, 33] 저장 됨
# {980} 회차가 저장됩니다. ['3', '13', '16', '23', '24', '35']
# 980 회차 : [3, 13, 16, 23, 24, 35] 저장 됨
# {981} 회차가 저장됩니다. ['27', '36', '37', '41', '43', '45']
# 981 회차 : [27, 36, 37, 41, 43, 45] 저장 됨
# {982} 회차가 저장됩니다. ['5', '7', '13', '20', '21', '44']
# 982 회차 : [5, 7, 13, 20, 21, 44] 저장 됨
# {983} 회차가 저장됩니다. ['13', '23', '26', '31', '35', '43']
# 983 회차 : [13, 23, 26, 31, 35, 43] 저장 됨
# {984} 회차가 저장됩니다. ['3', '10', '23', '35', '36', '37']
# 984 회차 : [3, 10, 23, 35, 36, 37] 저장 됨
# {985} 회차가 저장됩니다. ['17', '21', '23', '30', '34', '44']
# 985 회차 : [17, 21, 23, 30, 34, 44] 저장 됨
# {986} 회차가 저장됩니다. ['7', '10', '16', '28', '41', '42']
# 986 회차 : [7, 10, 16, 28, 41, 42] 저장 됨
# {987} 회차가 저장됩니다. ['2', '4', '15', '23', '29', '38']
# 987 회차 : [2, 4, 15, 23, 29, 38] 저장 됨
# {988} 회차가 저장됩니다. ['2', '13', '20', '30', '31', '41']
# 988 회차 : [2, 13, 20, 30, 31, 41] 저장 됨
# {989} 회차가 저장됩니다. ['17', '18', '21', '27', '29', '33']
# 989 회차 : [17, 18, 21, 27, 29, 33] 저장 됨
# {990} 회차가 저장됩니다. ['2', '4', '25', '26', '36', '37']
# 990 회차 : [2, 4, 25, 26, 36, 37] 저장 됨
# {991} 회차가 저장됩니다. ['13', '18', '25', '31', '33', '44']
# 991 회차 : [13, 18, 25, 31, 33, 44] 저장 됨
# {992} 회차가 저장됩니다. ['12', '20', '26', '33', '44', '45']
# 992 회차 : [12, 20, 26, 33, 44, 45] 저장 됨
# {993} 회차가 저장됩니다. ['6', '14', '16', '18', '24', '42']
# 993 회차 : [6, 14, 16, 18, 24, 42] 저장 됨
# {994} 회차가 저장됩니다. ['1', '3', '8', '24', '27', '35']
# 994 회차 : [1, 3, 8, 24, 27, 35] 저장 됨
# {995} 회차가 저장됩니다. ['1', '4', '13', '29', '38', '39']
# 995 회차 : [1, 4, 13, 29, 38, 39] 저장 됨
# {996} 회차가 저장됩니다. ['6', '11', '15', '24', '32', '39']
# 996 회차 : [6, 11, 15, 24, 32, 39] 저장 됨
# {997} 회차가 저장됩니다. ['4', '7', '14', '16', '24', '44']
# 997 회차 : [4, 7, 14, 16, 24, 44] 저장 됨
# {998} 회차가 저장됩니다. ['13', '17', '18', '20', '42', '45']
# 998 회차 : [13, 17, 18, 20, 42, 45] 저장 됨
# {999} 회차가 저장됩니다. ['1', '4', '13', '29', '38', '39']
# 999 회차 : [1, 4, 13, 29, 38, 39] 저장 됨
# {1000} 회차가 저장됩니다. ['2', '8', '19', '22', '32', '42']
# 1000 회차 : [2, 8, 19, 22, 32, 42] 저장 됨
# {1001} 회차가 저장됩니다. ['6', '10', '12', '14', '20', '42']
# 1001 회차 : [6, 10, 12, 14, 20, 42] 저장 됨
# {1002} 회차가 저장됩니다. ['17', '25', '33', '35', '38', '45']
# 1002 회차 : [17, 25, 33, 35, 38, 45] 저장 됨
# {1003} 회차가 저장됩니다. ['1', '4', '29', '39', '43', '45']
# 1003 회차 : [1, 4, 29, 39, 43, 45] 저장 됨
# {1004} 회차가 저장됩니다. ['7', '15', '30', '37', '39', '44']
# 1004 회차 : [7, 15, 30, 37, 39, 44] 저장 됨
# {1005} 회차가 저장됩니다. ['8', '13', '18', '24', '27', '29']
# 1005 회차 : [8, 13, 18, 24, 27, 29] 저장 됨
# {1006} 회차가 저장됩니다. ['8', '11', '15', '16', '17', '37']
# 1006 회차 : [8, 11, 15, 16, 17, 37] 저장 됨
# {1007} 회차가 저장됩니다. ['8', '11', '16', '19', '21', '25']
# 1007 회차 : [8, 11, 16, 19, 21, 25] 저장 됨
# {1008} 회차가 저장됩니다. ['9', '11', '30', '31', '41', '44']
# 1008 회차 : [9, 11, 30, 31, 41, 44] 저장 됨
# {1009} 회차가 저장됩니다. ['15', '23', '29', '34', '40', '44']
# 1009 회차 : [15, 23, 29, 34, 40, 44] 저장 됨
# {1010} 회차가 저장됩니다. ['9', '12', '15', '25', '34', '36']
# 1010 회차 : [9, 12, 15, 25, 34, 36] 저장 됨
# {1011} 회차가 저장됩니다. ['1', '9', '12', '26', '35', '38']
# 1011 회차 : [1, 9, 12, 26, 35, 38] 저장 됨
# {1012} 회차가 저장됩니다. ['5', '11', '18', '20', '35', '45']
# 1012 회차 : [5, 11, 18, 20, 35, 45] 저장 됨
# {1013} 회차가 저장됩니다. ['21', '22', '26', '34', '36', '41']
# 1013 회차 : [21, 22, 26, 34, 36, 41] 저장 됨
# {1014} 회차가 저장됩니다. ['3', '11', '14', '18', '26', '27']
# 1014 회차 : [3, 11, 14, 18, 26, 27] 저장 됨
# {1015} 회차가 저장됩니다. ['14', '23', '31', '33', '37', '40']
# 1015 회차 : [14, 23, 31, 33, 37, 40] 저장 됨
# {1016} 회차가 저장됩니다. ['15', '26', '28', '34', '41', '42']
# 1016 회차 : [15, 26, 28, 34, 41, 42] 저장 됨
# {1017} 회차가 저장됩니다. ['12', '18', '22', '23', '30', '34']
# 1017 회차 : [12, 18, 22, 23, 30, 34] 저장 됨
# {1018} 회차가 저장됩니다. ['3', '19', '21', '25', '37', '45']
# 1018 회차 : [3, 19, 21, 25, 37, 45] 저장 됨
# {1019} 회차가 저장됩니다. ['1', '4', '13', '17', '34', '39']
# 1019 회차 : [1, 4, 13, 17, 34, 39] 저장 됨
# {1020} 회차가 저장됩니다. ['12', '27', '29', '38', '41', '45']
# 1020 회차 : [12, 27, 29, 38, 41, 45] 저장 됨
# {1021} 회차가 저장됩니다. ['12', '15', '17', '24', '29', '45']
# 1021 회차 : [12, 15, 17, 24, 29, 45] 저장 됨
# {1022} 회차가 저장됩니다. ['5', '6', '11', '29', '42', '45']
# 1022 회차 : [5, 6, 11, 29, 42, 45] 저장 됨
# {1023} 회차가 저장됩니다. ['10', '14', '16', '18', '29', '35']
# 1023 회차 : [10, 14, 16, 18, 29, 35] 저장 됨
# {1024} 회차가 저장됩니다. ['9', '18', '20', '22', '38', '44']
# 1024 회차 : [9, 18, 20, 22, 38, 44] 저장 됨

# %%
# Out:
# [('lotto_nums',)]

# %%
service = Service('../chromedriver')
url = 'https://www.dhlottery.co.kr/gameResult.do?method=byWin'
try:
    driver = webdriver.Chrome(service = service)
except:
    print('chromedriver의 버전을 확인해 주세요 😣')
    time.sleep(2)
    sys.exit()

driver.get(url)


# 최신회차 조회
new = int(driver.find_element(By.XPATH, '//*[@id="dwrNoList"]').text.strip().split()[0])
print('최신 회차 : {}회'.format(new))


for i in range(new, 0, -1):     # 신규회차부터 1회차까지 역순으로 데이터 저장

            driver.find_element(By.XPATH, '//*[@id="dwrNoList"]').send_keys(i)
            time.sleep(1)
            driver.find_element(By.XPATH, '//*[@id="searchBtn"]').send_keys(Keys.ENTER)
            time.sleep(1)

            nums = []
            for _ in range(1, 7):

                # 신규 회차의 로또번호 6개를 리스트에 넣기
                nums.append(driver.find_element(By.XPATH, '//*[@id="article"]/div[2]/div/div[2]/div/div[1]/p/span[{}]'.format(_)).text)

            # 새로운 회차 및 번호 DB에 저장
            print({i}, '회차가 저장됩니다.', '{}'.format(nums))
            driver.implicitly_wait(10)
# driver.close()
# Out:
# 최신 회차 : 1024회
# {1024} 회차가 저장됩니다. ['9', '18', '20', '22', '38', '44']
# {1023} 회차가 저장됩니다. ['10', '14', '16', '18', '29', '35']
# {1022} 회차가 저장됩니다. ['5', '6', '11', '29', '42', '45']
# {1021} 회차가 저장됩니다. ['12', '15', '17', '24', '29', '45']
# {1020} 회차가 저장됩니다. ['12', '27', '29', '38', '41', '45']
# {1019} 회차가 저장됩니다. ['1', '4', '13', '17', '34', '39']
# {1018} 회차가 저장됩니다. ['3', '19', '21', '25', '37', '45']
# {1017} 회차가 저장됩니다. ['12', '18', '22', '23', '30', '34']
# {1016} 회차가 저장됩니다. ['15', '26', '28', '34', '41', '42']
# {1015} 회차가 저장됩니다. ['14', '23', '31', '33', '37', '40']
# {1014} 회차가 저장됩니다. ['3', '11', '14', '18', '26', '27']
# {1013} 회차가 저장됩니다. ['21', '22', '26', '34', '36', '41']
# {1012} 회차가 저장됩니다. ['5', '11', '18', '20', '35', '45']
# {1011} 회차가 저장됩니다. ['1', '9', '12', '26', '35', '38']
# {1010} 회차가 저장됩니다. ['9', '12', '15', '25', '34', '36']
# {1009} 회차가 저장됩니다. ['15', '23', '29', '34', '40', '44']
# {1008} 회차가 저장됩니다. ['9', '11', '30', '31', '41', '44']
# {1007} 회차가 저장됩니다. ['8', '11', '16', '19', '21', '25']
# {1006} 회차가 저장됩니다. ['8', '11', '15', '16', '17', '37']
# {1005} 회차가 저장됩니다. ['8', '13', '18', '24', '27', '29']
# {1004} 회차가 저장됩니다. ['7', '15', '30', '37', '39', '44']
# {1003} 회차가 저장됩니다. ['1', '4', '29', '39', '43', '45']
# {1002} 회차가 저장됩니다. ['17', '25', '33', '35', '38', '45']
# {1001} 회차가 저장됩니다. ['6', '10', '12', '14', '20', '42']
# {1000} 회차가 저장됩니다. ['2', '8', '19', '22', '32', '42']
# {999} 회차가 저장됩니다. ['4', '7', '14', '16', '24', '44']
# {998} 회차가 저장됩니다. ['13', '17', '18', '20', '42', '45']
# {997} 회차가 저장됩니다. ['4', '7', '14', '16', '24', '44']
# {996} 회차가 저장됩니다. ['6', '11', '15', '24', '32', '39']
# {995} 회차가 저장됩니다. ['1', '4', '13', '29', '38', '39']
# {994} 회차가 저장됩니다. ['1', '3', '8', '24', '27', '35']
# {993} 회차가 저장됩니다. ['6', '14', '16', '18', '24', '42']
# {992} 회차가 저장됩니다. ['12', '20', '26', '33', '44', '45']
# {991} 회차가 저장됩니다. ['13', '18', '25', '31', '33', '44']
# {990} 회차가 저장됩니다. ['2', '4', '25', '26', '36', '37']
# {989} 회차가 저장됩니다. ['17', '18', '21', '27', '29', '33']
# {988} 회차가 저장됩니다. ['2', '13', '20', '30', '31', '41']
# {987} 회차가 저장됩니다. ['2', '4', '15', '23', '29', '38']
# {986} 회차가 저장됩니다. ['7', '10', '16', '28', '41', '42']
# {985} 회차가 저장됩니다. ['17', '21', '23', '30', '34', '44']
# {984} 회차가 저장됩니다. ['3', '10', '23', '35', '36', '37']
# {983} 회차가 저장됩니다. ['13', '23', '26', '31', '35', '43']
# {982} 회차가 저장됩니다. ['5', '7', '13', '20', '21', '44']
# {981} 회차가 저장됩니다. ['27', '36', '37', '41', '43', '45']
# {980} 회차가 저장됩니다. ['3', '13', '16', '23', '24', '35']
# {979} 회차가 저장됩니다. ['7', '11', '16', '21', '27', '33']
# {978} 회차가 저장됩니다. ['1', '7', '15', '32', '34', '42']
# {977} 회차가 저장됩니다. ['2', '9', '10', '14', '22', '44']
# {976} 회차가 저장됩니다. ['4', '12', '14', '25', '35', '37']
# {975} 회차가 저장됩니다. ['7', '8', '9', '17', '22', '24']
# {974} 회차가 저장됩니다. ['1', '2', '11', '16', '39', '44']
# {973} 회차가 저장됩니다. ['22', '26', '31', '37', '41', '42']
# {972} 회차가 저장됩니다. ['3', '6', '17', '23', '37', '39']
# {971} 회차가 저장됩니다. ['2', '6', '17', '18', '21', '26']
# {970} 회차가 저장됩니다. ['9', '11', '16', '21', '28', '36']
# {969} 회차가 저장됩니다. ['3', '9', '10', '29', '40', '45']
# {968} 회차가 저장됩니다. ['2', '5', '12', '14', '24', '39']
# {967} 회차가 저장됩니다. ['1', '6', '13', '37', '38', '40']
# {966} 회차가 저장됩니다. ['1', '21', '25', '29', '34', '37']
# {965} 회차가 저장됩니다. ['2', '13', '25', '28', '29', '36']
# {964} 회차가 저장됩니다. ['6', '21', '36', '38', '39', '43']
# {963} 회차가 저장됩니다. ['6', '12', '19', '23', '34', '42']
# {962} 회차가 저장됩니다. ['1', '18', '28', '31', '34', '43']
# {961} 회차가 저장됩니다. ['11', '20', '29', '31', '33', '42']
# {960} 회차가 저장됩니다. ['2', '18', '24', '30', '32', '45']
# {959} 회차가 저장됩니다. ['1', '14', '15', '24', '40', '41']
# {958} 회차가 저장됩니다. ['2', '9', '10', '16', '35', '37']
# {957} 회차가 저장됩니다. ['4', '15', '24', '35', '36', '40']
# {956} 회차가 저장됩니다. ['10', '11', '20', '21', '25', '41']
# {955} 회차가 저장됩니다. ['4', '9', '23', '26', '29', '33']
# {954} 회차가 저장됩니다. ['1', '9', '26', '28', '30', '41']
# {953} 회차가 저장됩니다. ['7', '9', '22', '27', '37', '42']
# {952} 회차가 저장됩니다. ['4', '12', '22', '24', '33', '41']
# {951} 회차가 저장됩니다. ['2', '12', '30', '31', '39', '43']
# {950} 회차가 저장됩니다. ['3', '4', '15', '22', '28', '40']
# {949} 회차가 저장됩니다. ['14', '21', '35', '36', '40', '44']
# {948} 회차가 저장됩니다. ['13', '18', '30', '31', '38', '41']
# {947} 회차가 저장됩니다. ['3', '8', '17', '20', '27', '35']
# {946} 회차가 저장됩니다. ['9', '18', '19', '30', '34', '40']
# {945} 회차가 저장됩니다. ['9', '10', '15', '30', '33', '37']
# {944} 회차가 저장됩니다. ['2', '13', '16', '19', '32', '33']
# {943} 회차가 저장됩니다. ['1', '8', '13', '36', '44', '45']
# {942} 회차가 저장됩니다. ['10', '12', '18', '35', '42', '43']
# {941} 회차가 저장됩니다. ['12', '14', '25', '27', '39', '40']
# {940} 회차가 저장됩니다. ['3', '15', '20', '22', '24', '41']
# {939} 회차가 저장됩니다. ['4', '11', '28', '39', '42', '45']
# {938} 회차가 저장됩니다. ['4', '8', '10', '16', '31', '36']
# {937} 회차가 저장됩니다. ['2', '10', '13', '22', '29', '40']
# {936} 회차가 저장됩니다. ['7', '11', '13', '17', '18', '29']
# {935} 회차가 저장됩니다. ['4', '10', '20', '32', '38', '44']
# {934} 회차가 저장됩니다. ['1', '3', '30', '33', '36', '39']
# {933} 회차가 저장됩니다. ['23', '27', '29', '31', '36', '45']
# {932} 회차가 저장됩니다. ['1', '6', '15', '36', '37', '38']
# {931} 회차가 저장됩니다. ['14', '15', '23', '25', '35', '43']
# {930} 회차가 저장됩니다. ['8', '21', '25', '38', '39', '44']
# {929} 회차가 저장됩니다. ['7', '9', '12', '15', '19', '23']
# {928} 회차가 저장됩니다. ['3', '4', '10', '20', '28', '44']
# {927} 회차가 저장됩니다. ['4', '15', '22', '38', '41', '43']
# {926} 회차가 저장됩니다. ['10', '16', '18', '20', '25', '31']
# {925} 회차가 저장됩니다. ['13', '24', '32', '34', '39', '42']
# {924} 회차가 저장됩니다. ['3', '11', '34', '42', '43', '44']
# {923} 회차가 저장됩니다. ['3', '17', '18', '23', '36', '41']
# {922} 회차가 저장됩니다. ['2', '6', '13', '17', '27', '43']
# {921} 회차가 저장됩니다. ['5', '7', '12', '22', '28', '41']
# {920} 회차가 저장됩니다. ['2', '3', '26', '33', '34', '43']
# {919} 회차가 저장됩니다. ['9', '14', '17', '18', '42', '44']
# {918} 회차가 저장됩니다. ['7', '11', '12', '31', '33', '38']
# {917} 회차가 저장됩니다. ['1', '3', '23', '24', '27', '43']
# {916} 회차가 저장됩니다. ['6', '21', '22', '32', '35', '36']
# {915} 회차가 저장됩니다. ['2', '6', '11', '13', '22', '37']
# {914} 회차가 저장됩니다. ['16', '19', '24', '33', '42', '44']
# {913} 회차가 저장됩니다. ['6', '14', '16', '21', '27', '37']
# {912} 회차가 저장됩니다. ['5', '8', '18', '21', '22', '38']
# {911} 회차가 저장됩니다. ['4', '5', '12', '14', '32', '42']
# {910} 회차가 저장됩니다. ['1', '11', '17', '27', '35', '39']
# {909} 회차가 저장됩니다. ['7', '24', '29', '30', '34', '35']
# {908} 회차가 저장됩니다. ['3', '16', '21', '22', '23', '44']
# {907} 회차가 저장됩니다. ['21', '27', '29', '38', '40', '44']
# {906} 회차가 저장됩니다. ['2', '5', '14', '28', '31', '32']
# {905} 회차가 저장됩니다. ['3', '4', '16', '27', '38', '40']
# {904} 회차가 저장됩니다. ['2', '6', '8', '26', '43', '45']
# {903} 회차가 저장됩니다. ['2', '15', '16', '21', '22', '28']
# {902} 회차가 저장됩니다. ['7', '19', '23', '24', '36', '39']
# {901} 회차가 저장됩니다. ['5', '18', '20', '23', '30', '34']
# {900} 회차가 저장됩니다. ['7', '13', '16', '18', '35', '38']
# {899} 회차가 저장됩니다. ['8', '19', '20', '21', '33', '39']
# {898} 회차가 저장됩니다. ['18', '21', '28', '35', '37', '42']
# {897} 회차가 저장됩니다. ['6', '7', '12', '22', '26', '36']
# {896} 회차가 저장됩니다. ['5', '12', '25', '26', '38', '45']
# {895} 회차가 저장됩니다. ['16', '26', '31', '38', '39', '41']
# {894} 회차가 저장됩니다. ['19', '32', '37', '40', '41', '43']
# {893} 회차가 저장됩니다. ['1', '15', '17', '23', '25', '41']
# {892} 회차가 저장됩니다. ['4', '9', '17', '18', '26', '42']
# {891} 회차가 저장됩니다. ['9', '13', '28', '31', '39', '41']
# {890} 회차가 저장됩니다. ['1', '4', '14', '18', '29', '37']
# {889} 회차가 저장됩니다. ['3', '13', '29', '38', '39', '42']
# {888} 회차가 저장됩니다. ['19', '23', '28', '37', '42', '45']
# {887} 회차가 저장됩니다. ['8', '14', '17', '27', '36', '45']
# {886} 회차가 저장됩니다. ['19', '23', '28', '37', '42', '45']
# {885} 회차가 저장됩니다. ['1', '3', '24', '27', '39', '45']
# {884} 회차가 저장됩니다. ['4', '14', '23', '28', '37', '45']
# {883} 회차가 저장됩니다. ['9', '18', '32', '33', '37', '44']
# {882} 회차가 저장됩니다. ['18', '34', '39', '43', '44', '45']
# {881} 회차가 저장됩니다. ['4', '18', '20', '26', '27', '32']
# {880} 회차가 저장됩니다. ['7', '17', '19', '23', '24', '45']
# {879} 회차가 저장됩니다. ['1', '4', '10', '14', '15', '35']
# {878} 회차가 저장됩니다. ['2', '6', '11', '16', '25', '31']
# {877} 회차가 저장됩니다. ['5', '17', '18', '22', '23', '43']
# {876} 회차가 저장됩니다. ['5', '16', '21', '26', '34', '42']
# {875} 회차가 저장됩니다. ['19', '22', '30', '34', '39', '44']
# {874} 회차가 저장됩니다. ['1', '15', '19', '23', '28', '42']
# {873} 회차가 저장됩니다. ['3', '5', '12', '13', '33', '39']
# {872} 회차가 저장됩니다. ['2', '4', '30', '32', '33', '43']
# {871} 회차가 저장됩니다. ['2', '6', '12', '26', '30', '34']
# {870} 회차가 저장됩니다. ['21', '25', '30', '32', '40', '42']
# {869} 회차가 저장됩니다. ['2', '6', '20', '27', '37', '39']
# {868} 회차가 저장됩니다. ['12', '17', '28', '41', '43', '44']
# {867} 회차가 저장됩니다. ['14', '17', '19', '22', '24', '40']
# {866} 회차가 저장됩니다. ['9', '15', '29', '34', '37', '39']
# {865} 회차가 저장됩니다. ['3', '15', '22', '32', '33', '45']
# {864} 회차가 저장됩니다. ['3', '7', '10', '13', '25', '36']
# {863} 회차가 저장됩니다. ['16', '21', '28', '35', '39', '43']
# {862} 회차가 저장됩니다. ['10', '34', '38', '40', '42', '43']
# {861} 회차가 저장됩니다. ['11', '17', '19', '21', '22', '25']
# {860} 회차가 저장됩니다. ['4', '8', '18', '25', '27', '32']
# {859} 회차가 저장됩니다. ['8', '22', '35', '38', '39', '41']
# {858} 회차가 저장됩니다. ['9', '13', '32', '38', '39', '43']
# {857} 회차가 저장됩니다. ['6', '10', '16', '28', '34', '38']
# {856} 회차가 저장됩니다. ['10', '24', '40', '41', '43', '44']
# {855} 회차가 저장됩니다. ['8', '15', '17', '19', '43', '44']
# {854} 회차가 저장됩니다. ['20', '25', '31', '32', '36', '43']
# {853} 회차가 저장됩니다. ['2', '8', '23', '26', '27', '44']
# {852} 회차가 저장됩니다. ['11', '17', '28', '30', '33', '35']
# {851} 회차가 저장됩니다. ['14', '18', '22', '26', '31', '44']
# {850} 회차가 저장됩니다. ['16', '20', '24', '28', '36', '39']
# {849} 회차가 저장됩니다. ['5', '13', '17', '29', '34', '39']
# {848} 회차가 저장됩니다. ['1', '2', '16', '22', '38', '39']
# {847} 회차가 저장됩니다. ['12', '16', '26', '28', '30', '42']
# {846} 회차가 저장됩니다. ['5', '18', '30', '41', '43', '45']
# {845} 회차가 저장됩니다. ['1', '16', '29', '33', '40', '45']
# {844} 회차가 저장됩니다. ['7', '8', '13', '15', '33', '45']
# {843} 회차가 저장됩니다. ['19', '21', '30', '33', '34', '42']
# {842} 회차가 저장됩니다. ['14', '26', '32', '36', '39', '42']
# {841} 회차가 저장됩니다. ['5', '11', '14', '30', '33', '38']
# {840} 회차가 저장됩니다. ['2', '4', '11', '28', '29', '43']
# {839} 회차가 저장됩니다. ['3', '9', '11', '12', '13', '19']
# {838} 회차가 저장됩니다. ['9', '14', '17', '33', '36', '38']
# {837} 회차가 저장됩니다. ['2', '25', '28', '30', '33', '45']
# {836} 회차가 저장됩니다. ['1', '9', '11', '14', '26', '28']
# {835} 회차가 저장됩니다. ['9', '10', '13', '28', '38', '45']
# {834} 회차가 저장됩니다. ['6', '8', '18', '35', '42', '43']
# {833} 회차가 저장됩니다. ['12', '18', '30', '39', '41', '42']
# {832} 회차가 저장됩니다. ['13', '14', '19', '26', '40', '43']
# {831} 회차가 저장됩니다. ['3', '10', '16', '19', '31', '39']
# {830} 회차가 저장됩니다. ['5', '6', '16', '18', '37', '38']
# {829} 회차가 저장됩니다. ['4', '5', '31', '35', '43', '45']
# {828} 회차가 저장됩니다. ['4', '7', '13', '29', '31', '39']
# {827} 회차가 저장됩니다. ['5', '11', '12', '29', '33', '44']
# {826} 회차가 저장됩니다. ['13', '16', '24', '25', '33', '36']
# {825} 회차가 저장됩니다. ['8', '15', '21', '31', '33', '38']
# {824} 회차가 저장됩니다. ['7', '9', '24', '29', '34', '38']
# {823} 회차가 저장됩니다. ['12', '18', '24', '26', '39', '40']
# {822} 회차가 저장됩니다. ['9', '18', '20', '24', '27', '36']
# {821} 회차가 저장됩니다. ['1', '12', '13', '24', '29', '44']
# {820} 회차가 저장됩니다. ['10', '21', '22', '30', '35', '42']
# {819} 회차가 저장됩니다. ['16', '25', '33', '38', '40', '45']
# {818} 회차가 저장됩니다. ['14', '15', '25', '28', '29', '30']
# {817} 회차가 저장됩니다. ['3', '9', '12', '13', '25', '43']
# {816} 회차가 저장됩니다. ['12', '18', '19', '29', '31', '39']
# {815} 회차가 저장됩니다. ['17', '21', '25', '26', '27', '36']
# {814} 회차가 저장됩니다. ['2', '21', '28', '38', '42', '45']
# {813} 회차가 저장됩니다. ['11', '30', '34', '35', '42', '44']
# {812} 회차가 저장됩니다. ['1', '3', '12', '14', '16', '43']
# {811} 회차가 저장됩니다. ['8', '11', '19', '21', '36', '45']
# {810} 회차가 저장됩니다. ['5', '10', '13', '21', '39', '43']
# {809} 회차가 저장됩니다. ['6', '11', '15', '17', '23', '40']
# {808} 회차가 저장됩니다. ['15', '21', '31', '32', '41', '43']
# {807} 회차가 저장됩니다. ['6', '10', '18', '25', '34', '35']
# {806} 회차가 저장됩니다. ['14', '20', '23', '31', '37', '38']
# {805} 회차가 저장됩니다. ['3', '12', '13', '18', '31', '32']
# {804} 회차가 저장됩니다. ['1', '10', '13', '26', '32', '36']
# {803} 회차가 저장됩니다. ['5', '9', '14', '26', '30', '43']
# {802} 회차가 저장됩니다. ['10', '11', '12', '18', '24', '42']
# {801} 회차가 저장됩니다. ['17', '25', '28', '37', '43', '44']
# {800} 회차가 저장됩니다. ['1', '4', '10', '12', '28', '45']
# {799} 회차가 저장됩니다. ['12', '17', '23', '34', '42', '45']
# {798} 회차가 저장됩니다. ['2', '10', '14', '22', '32', '36']
# {797} 회차가 저장됩니다. ['5', '22', '31', '32', '39', '45']
# {796} 회차가 저장됩니다. ['1', '21', '26', '36', '40', '41']
# {795} 회차가 저장됩니다. ['3', '10', '13', '26', '34', '38']
# {794} 회차가 저장됩니다. ['6', '7', '18', '19', '30', '38']
# {793} 회차가 저장됩니다. ['10', '15', '21', '35', '38', '43']
# {792} 회차가 저장됩니다. ['2', '7', '19', '25', '29', '36']
# {791} 회차가 저장됩니다. ['2', '10', '12', '31', '33', '42']
# {790} 회차가 저장됩니다. ['3', '8', '19', '27', '30', '41']
# {789} 회차가 저장됩니다. ['2', '6', '7', '12', '19', '45']
# {788} 회차가 저장됩니다. ['2', '10', '11', '19', '35', '39']
# {787} 회차가 저장됩니다. ['5', '6', '13', '16', '27', '28']
# {786} 회차가 저장됩니다. ['12', '15', '16', '20', '24', '30']
# {785} 회차가 저장됩니다. ['4', '6', '15', '25', '26', '33']
# {784} 회차가 저장됩니다. ['3', '10', '23', '24', '31', '39']
# {783} 회차가 저장됩니다. ['14', '15', '16', '17', '38', '45']
# {782} 회차가 저장됩니다. ['6', '18', '31', '34', '38', '45']
# {781} 회차가 저장됩니다. ['11', '16', '18', '19', '24', '39']
# {780} 회차가 저장됩니다. ['15', '17', '19', '21', '27', '45']
# {779} 회차가 저장됩니다. ['6', '12', '19', '24', '34', '41']
# {778} 회차가 저장됩니다. ['6', '21', '35', '36', '37', '41']
# {777} 회차가 저장됩니다. ['11', '12', '29', '33', '38', '42']
# {776} 회차가 저장됩니다. ['8', '9', '18', '21', '28', '40']
# {775} 회차가 저장됩니다. ['11', '12', '29', '33', '38', '42']
# {774} 회차가 저장됩니다. ['12', '15', '18', '28', '34', '42']
# {773} 회차가 저장됩니다. ['8', '12', '19', '21', '31', '35']
# {772} 회차가 저장됩니다. ['5', '6', '11', '14', '21', '41']
# {771} 회차가 저장됩니다. ['6', '10', '17', '18', '21', '29']
# {770} 회차가 저장됩니다. ['1', '9', '12', '23', '39', '43']
# {769} 회차가 저장됩니다. ['5', '7', '11', '16', '41', '45']
# {768} 회차가 저장됩니다. ['7', '27', '29', '30', '38', '44']
# {767} 회차가 저장됩니다. ['5', '15', '20', '31', '34', '42']
# {766} 회차가 저장됩니다. ['9', '30', '34', '35', '39', '41']
# {765} 회차가 저장됩니다. ['1', '3', '8', '12', '42', '43']
# {764} 회차가 저장됩니다. ['7', '22', '24', '31', '34', '36']
# {763} 회차가 저장됩니다. ['3', '8', '16', '32', '34', '43']
# {762} 회차가 저장됩니다. ['1', '3', '12', '21', '26', '41']
# {761} 회차가 저장됩니다. ['4', '7', '11', '24', '42', '45']
# {760} 회차가 저장됩니다. ['10', '22', '27', '31', '42', '43']
# {759} 회차가 저장됩니다. ['9', '33', '36', '40', '42', '43']
# {758} 회차가 저장됩니다. ['5', '9', '12', '30', '39', '43']
# {757} 회차가 저장됩니다. ['6', '7', '11', '17', '33', '44']
# {756} 회차가 저장됩니다. ['10', '14', '16', '18', '27', '28']
# {755} 회차가 저장됩니다. ['13', '14', '26', '28', '30', '36']
# {754} 회차가 저장됩니다. ['2', '8', '17', '24', '29', '31']
# {753} 회차가 저장됩니다. ['2', '17', '19', '24', '37', '41']
# {752} 회차가 저장됩니다. ['4', '16', '20', '33', '40', '43']
# {751} 회차가 저장됩니다. ['3', '4', '16', '20', '28', '44']
# {750} 회차가 저장됩니다. ['1', '2', '15', '19', '24', '36']
# {749} 회차가 저장됩니다. ['12', '14', '24', '26', '34', '45']
# {748} 회차가 저장됩니다. ['3', '10', '13', '22', '31', '32']
# {747} 회차가 저장됩니다. ['7', '9', '12', '14', '23', '28']
# {746} 회차가 저장됩니다. ['3', '12', '33', '36', '42', '45']
# {745} 회차가 저장됩니다. ['1', '2', '3', '9', '12', '23']
# {744} 회차가 저장됩니다. ['10', '15', '18', '21', '34', '41']
# {743} 회차가 저장됩니다. ['15', '19', '21', '34', '41', '44']
# {742} 회차가 저장됩니다. ['8', '10', '13', '36', '37', '40']
# {741} 회차가 저장됩니다. ['5', '21', '27', '34', '44', '45']
# {740} 회차가 저장됩니다. ['4', '8', '9', '16', '17', '19']
# {739} 회차가 저장됩니다. ['7', '22', '29', '33', '34', '35']
# {738} 회차가 저장됩니다. ['23', '27', '28', '38', '42', '43']
# {737} 회차가 저장됩니다. ['13', '15', '18', '24', '27', '41']
# {736} 회차가 저장됩니다. ['2', '11', '17', '18', '21', '27']
# {735} 회차가 저장됩니다. ['5', '10', '13', '27', '37', '41']
# {734} 회차가 저장됩니다. ['6', '16', '37', '38', '41', '45']
# {733} 회차가 저장됩니다. ['11', '24', '32', '33', '35', '40']
# {732} 회차가 저장됩니다. ['2', '4', '5', '17', '27', '32']
# {731} 회차가 저장됩니다. ['2', '7', '13', '25', '42', '45']
# {730} 회차가 저장됩니다. ['4', '10', '14', '15', '18', '22']
# {729} 회차가 저장됩니다. ['11', '17', '21', '26', '36', '45']
# {728} 회차가 저장됩니다. ['3', '6', '10', '30', '34', '37']
# {727} 회차가 저장됩니다. ['7', '8', '10', '19', '21', '31']
# {726} 회차가 저장됩니다. ['1', '11', '21', '23', '34', '44']
# {725} 회차가 저장됩니다. ['6', '7', '19', '21', '41', '43']
# {724} 회차가 저장됩니다. ['2', '8', '33', '35', '37', '41']
# {723} 회차가 저장됩니다. ['20', '30', '33', '35', '36', '44']
# {722} 회차가 저장됩니다. ['12', '14', '21', '30', '39', '43']
# {721} 회차가 저장됩니다. ['1', '28', '35', '41', '43', '44']
# {720} 회차가 저장됩니다. ['1', '12', '29', '34', '36', '37']
# {719} 회차가 저장됩니다. ['4', '8', '13', '19', '20', '43']
# {718} 회차가 저장됩니다. ['4', '11', '20', '23', '32', '39']
# {717} 회차가 저장됩니다. ['2', '11', '19', '25', '28', '32']
# {716} 회차가 저장됩니다. ['2', '6', '13', '16', '29', '30']
# {715} 회차가 저장됩니다. ['2', '7', '27', '33', '41', '44']
# {714} 회차가 저장됩니다. ['1', '7', '22', '33', '37', '40']
# {713} 회차가 저장됩니다. ['2', '5', '15', '18', '19', '23']
# {712} 회차가 저장됩니다. ['17', '20', '30', '31', '33', '45']
# {711} 회차가 저장됩니다. ['11', '15', '24', '35', '37', '45']
# {710} 회차가 저장됩니다. ['3', '4', '9', '24', '25', '33']
# {709} 회차가 저장됩니다. ['10', '18', '30', '36', '39', '44']
# {708} 회차가 저장됩니다. ['2', '10', '16', '19', '34', '45']
# {707} 회차가 저장됩니다. ['2', '12', '19', '24', '39', '44']
# {706} 회차가 저장됩니다. ['3', '4', '6', '10', '28', '30']
# {705} 회차가 저장됩니다. ['1', '6', '17', '22', '28', '45']
# {704} 회차가 저장됩니다. ['1', '4', '8', '23', '33', '42']
# {703} 회차가 저장됩니다. ['10', '28', '31', '33', '41', '44']
# {702} 회차가 저장됩니다. ['3', '13', '16', '24', '26', '29']
# {701} 회차가 저장됩니다. ['3', '10', '14', '16', '36', '38']
# {700} 회차가 저장됩니다. ['11', '23', '28', '29', '30', '44']
# {699} 회차가 저장됩니다. ['4', '5', '8', '16', '21', '29']
# {698} 회차가 저장됩니다. ['3', '11', '13', '21', '33', '37']
# {697} 회차가 저장됩니다. ['2', '5', '8', '11', '33', '39']
# {696} 회차가 저장됩니다. ['1', '7', '16', '18', '34', '38']
# {695} 회차가 저장됩니다. ['4', '18', '26', '33', '34', '38']
# {694} 회차가 저장됩니다. ['7', '15', '20', '25', '33', '43']
# {693} 회차가 저장됩니다. ['1', '6', '11', '28', '34', '42']
# {692} 회차가 저장됩니다. ['3', '11', '14', '15', '32', '36']
# {691} 회차가 저장됩니다. ['15', '27', '33', '35', '43', '45']
# {690} 회차가 저장됩니다. ['24', '25', '33', '34', '38', '39']
# {689} 회차가 저장됩니다. ['7', '17', '19', '30', '36', '38']
# {688} 회차가 저장됩니다. ['5', '15', '22', '23', '34', '35']
# {687} 회차가 저장됩니다. ['1', '8', '10', '13', '28', '42']
# {686} 회차가 저장됩니다. ['7', '12', '15', '24', '25', '43']
# {685} 회차가 저장됩니다. ['6', '7', '12', '28', '38', '40']
# {684} 회차가 저장됩니다. ['1', '11', '15', '17', '25', '39']
# {683} 회차가 저장됩니다. ['6', '13', '20', '27', '28', '40']
# {682} 회차가 저장됩니다. ['17', '23', '27', '35', '38', '43']
# {681} 회차가 저장됩니다. ['21', '24', '27', '29', '43', '44']
# {680} 회차가 저장됩니다. ['4', '10', '19', '29', '32', '42']
# {679} 회차가 저장됩니다. ['3', '5', '7', '14', '26', '34']
# {678} 회차가 저장됩니다. ['4', '5', '6', '12', '25', '37']
# {677} 회차가 저장됩니다. ['12', '15', '24', '36', '41', '44']
# {676} 회차가 저장됩니다. ['1', '8', '17', '34', '39', '45']
# {675} 회차가 저장됩니다. ['1', '8', '11', '15', '18', '45']
# {674} 회차가 저장됩니다. ['9', '10', '14', '25', '27', '31']
# {673} 회차가 저장됩니다. ['7', '10', '17', '29', '33', '44']
# {672} 회차가 저장됩니다. ['8', '21', '28', '31', '36', '45']
# {671} 회차가 저장됩니다. ['7', '9', '10', '13', '31', '35']
# {670} 회차가 저장됩니다. ['11', '18', '26', '27', '40', '41']
# {669} 회차가 저장됩니다. ['7', '8', '20', '29', '33', '38']
# {668} 회차가 저장됩니다. ['12', '14', '15', '24', '27', '32']
# {667} 회차가 저장됩니다. ['15', '17', '25', '37', '42', '43']
# {666} 회차가 저장됩니다. ['10', '20', '33', '36', '41', '44']
# {665} 회차가 저장됩니다. ['5', '6', '11', '17', '38', '44']
# {664} 회차가 저장됩니다. ['10', '20', '33', '36', '41', '44']
# {663} 회차가 저장됩니다. ['3', '5', '8', '19', '38', '42']
# {662} 회차가 저장됩니다. ['5', '6', '9', '11', '15', '37']
# {661} 회차가 저장됩니다. ['2', '3', '12', '20', '27', '38']
# {660} 회차가 저장됩니다. ['4', '9', '23', '33', '39', '44']
# {659} 회차가 저장됩니다. ['7', '18', '19', '27', '29', '42']
# {658} 회차가 저장됩니다. ['8', '19', '25', '28', '32', '36']
# {657} 회차가 저장됩니다. ['10', '14', '19', '39', '40', '43']
# {656} 회차가 저장됩니다. ['3', '7', '14', '16', '31', '40']
# {655} 회차가 저장됩니다. ['7', '37', '38', '39', '40', '44']
# {654} 회차가 저장됩니다. ['16', '21', '26', '31', '36', '43']
# {653} 회차가 저장됩니다. ['5', '6', '26', '27', '38', '39']
# {652} 회차가 저장됩니다. ['3', '13', '15', '40', '41', '44']
# {651} 회차가 저장됩니다. ['11', '12', '16', '26', '29', '44']
# {650} 회차가 저장됩니다. ['3', '4', '7', '11', '31', '41']
# {649} 회차가 저장됩니다. ['3', '21', '22', '33', '41', '42']
# {648} 회차가 저장됩니다. ['13', '19', '28', '37', '38', '43']
# {647} 회차가 저장됩니다. ['5', '16', '21', '23', '24', '30']
# {646} 회차가 저장됩니다. ['2', '9', '24', '41', '43', '45']
# {645} 회차가 저장됩니다. ['1', '4', '16', '26', '40', '41']
# {644} 회차가 저장됩니다. ['5', '13', '17', '23', '28', '36']
# {643} 회차가 저장됩니다. ['15', '24', '31', '32', '33', '40']
# {642} 회차가 저장됩니다. ['8', '17', '18', '24', '39', '45']
# {641} 회차가 저장됩니다. ['11', '18', '21', '36', '37', '43']
# {640} 회차가 저장됩니다. ['14', '15', '18', '21', '26', '35']
# {639} 회차가 저장됩니다. ['6', '15', '22', '23', '25', '32']
# {638} 회차가 저장됩니다. ['7', '18', '22', '24', '31', '34']
# {637} 회차가 저장됩니다. ['3', '16', '22', '37', '38', '44']
# {636} 회차가 저장됩니다. ['6', '7', '15', '16', '20', '31']
# {635} 회차가 저장됩니다. ['11', '13', '25', '26', '29', '33']
# {634} 회차가 저장됩니다. ['4', '10', '11', '12', '20', '27']
# {633} 회차가 저장됩니다. ['9', '12', '19', '20', '39', '41']
# {632} 회차가 저장됩니다. ['15', '18', '21', '32', '35', '44']
# {631} 회차가 저장됩니다. ['1', '2', '4', '23', '31', '34']
# {630} 회차가 저장됩니다. ['8', '17', '21', '24', '27', '31']
# {629} 회차가 저장됩니다. ['19', '28', '31', '38', '43', '44']
# {628} 회차가 저장됩니다. ['1', '7', '12', '15', '23', '42']
# {627} 회차가 저장됩니다. ['2', '9', '22', '25', '31', '45']
# {626} 회차가 저장됩니다. ['13', '14', '26', '33', '40', '43']
# {625} 회차가 저장됩니다. ['3', '6', '7', '20', '21', '39']
# {624} 회차가 저장됩니다. ['1', '7', '19', '26', '27', '35']
# {623} 회차가 저장됩니다. ['7', '13', '30', '39', '41', '45']
# {622} 회차가 저장됩니다. ['9', '15', '16', '21', '28', '34']
# {621} 회차가 저장됩니다. ['1', '2', '6', '16', '19', '42']
# {620} 회차가 저장됩니다. ['2', '16', '17', '32', '39', '45']
# {619} 회차가 저장됩니다. ['6', '8', '13', '30', '35', '40']
# {618} 회차가 저장됩니다. ['8', '16', '25', '30', '42', '43']
# {617} 회차가 저장됩니다. ['4', '5', '11', '12', '24', '27']
# {616} 회차가 저장됩니다. ['5', '13', '18', '23', '40', '45']
# {615} 회차가 저장됩니다. ['10', '17', '18', '19', '23', '27']
# {614} 회차가 저장됩니다. ['8', '21', '25', '39', '40', '44']
# {613} 회차가 저장됩니다. ['7', '8', '11', '16', '41', '44']
# {612} 회차가 저장됩니다. ['6', '9', '18', '19', '25', '33']
# {611} 회차가 저장됩니다. ['2', '22', '27', '33', '36', '37']
# {610} 회차가 저장됩니다. ['14', '18', '20', '23', '28', '36']
# {609} 회차가 저장됩니다. ['4', '8', '27', '34', '39', '40']
# {608} 회차가 저장됩니다. ['4', '8', '18', '19', '39', '44']
# {607} 회차가 저장됩니다. ['8', '14', '23', '36', '38', '39']
# {606} 회차가 저장됩니다. ['1', '5', '6', '14', '20', '39']
# {605} 회차가 저장됩니다. ['1', '2', '7', '9', '10', '38']
# {604} 회차가 저장됩니다. ['2', '6', '18', '21', '33', '34']
# {603} 회차가 저장됩니다. ['2', '19', '25', '26', '27', '43']
# {602} 회차가 저장됩니다. ['13', '14', '22', '27', '30', '38']
# {601} 회차가 저장됩니다. ['2', '16', '19', '31', '34', '35']
# {600} 회차가 저장됩니다. ['5', '11', '14', '27', '29', '36']
# {599} 회차가 저장됩니다. ['5', '12', '17', '29', '34', '35']
# {598} 회차가 저장됩니다. ['4', '12', '24', '33', '38', '45']
# {597} 회차가 저장됩니다. ['8', '10', '23', '24', '35', '43']
# {596} 회차가 저장됩니다. ['3', '4', '12', '14', '25', '43']
# {595} 회차가 저장됩니다. ['8', '24', '28', '35', '38', '40']
# {594} 회차가 저장됩니다. ['2', '8', '13', '25', '28', '37']
# {593} 회차가 저장됩니다. ['9', '10', '13', '24', '33', '38']
# {592} 회차가 저장됩니다. ['2', '5', '6', '13', '28', '44']
# {591} 회차가 저장됩니다. ['8', '13', '14', '30', '38', '39']
# {590} 회차가 저장됩니다. ['20', '30', '36', '38', '41', '45']
# {589} 회차가 저장됩니다. ['6', '8', '28', '33', '38', '39']
# {588} 회차가 저장됩니다. ['2', '8', '15', '22', '25', '41']
# {587} 회차가 저장됩니다. ['14', '21', '29', '31', '32', '37']
# {586} 회차가 저장됩니다. ['2', '7', '12', '15', '21', '34']
# {585} 회차가 저장됩니다. ['6', '7', '10', '16', '38', '41']
# {584} 회차가 저장됩니다. ['7', '18', '30', '39', '40', '41']
# {583} 회차가 저장됩니다. ['8', '17', '27', '33', '40', '44']
# {582} 회차가 저장됩니다. ['2', '12', '14', '33', '40', '41']
# {581} 회차가 저장됩니다. ['3', '5', '14', '20', '42', '44']
# {580} 회차가 저장됩니다. ['5', '7', '9', '11', '32', '35']
# {579} 회차가 저장됩니다. ['5', '7', '20', '22', '37', '42']
# {578} 회차가 저장됩니다. ['5', '12', '14', '32', '34', '42']
# {577} 회차가 저장됩니다. ['16', '17', '22', '31', '34', '37']
# {576} 회차가 저장됩니다. ['10', '11', '15', '25', '35', '41']
# {575} 회차가 저장됩니다. ['2', '8', '20', '30', '33', '34']
# {574} 회차가 저장됩니다. ['14', '15', '16', '19', '25', '43']
# {573} 회차가 저장됩니다. ['2', '4', '20', '34', '35', '43']
# {572} 회차가 저장됩니다. ['3', '13', '18', '33', '37', '45']
# {571} 회차가 저장됩니다. ['11', '18', '21', '26', '38', '43']
# {570} 회차가 저장됩니다. ['1', '12', '26', '27', '29', '33']
# {569} 회차가 저장됩니다. ['3', '6', '13', '23', '24', '35']
# {568} 회차가 저장됩니다. ['1', '3', '17', '20', '31', '44']
# {567} 회차가 저장됩니다. ['1', '10', '15', '16', '32', '41']
# {566} 회차가 저장됩니다. ['4', '5', '6', '25', '26', '43']
# {565} 회차가 저장됩니다. ['4', '10', '18', '27', '40', '45']
# {564} 회차가 저장됩니다. ['14', '19', '25', '26', '27', '34']
# {563} 회차가 저장됩니다. ['5', '10', '16', '17', '31', '32']
# {562} 회차가 저장됩니다. ['4', '11', '13', '17', '20', '31']
# {561} 회차가 저장됩니다. ['5', '7', '18', '37', '42', '45']
# {560} 회차가 저장됩니다. ['1', '4', '20', '23', '29', '45']
# {559} 회차가 저장됩니다. ['11', '12', '25', '32', '44', '45']
# {558} 회차가 저장됩니다. ['12', '15', '19', '26', '40', '43']
# {557} 회차가 저장됩니다. ['4', '20', '26', '28', '35', '40']
# {556} 회차가 저장됩니다. ['12', '20', '23', '28', '30', '44']
# {555} 회차가 저장됩니다. ['2', '7', '17', '28', '29', '39']
# {554} 회차가 저장됩니다. ['13', '14', '17', '32', '41', '42']
# {553} 회차가 저장됩니다. ['2', '7', '17', '28', '29', '39']
# {552} 회차가 저장됩니다. ['1', '10', '20', '32', '35', '40']
# {551} 회차가 저장됩니다. ['3', '6', '20', '24', '27', '44']
# {550} 회차가 저장됩니다. ['1', '7', '14', '20', '34', '37']
# {549} 회차가 저장됩니다. ['29', '31', '35', '38', '40', '44']
# {548} 회차가 저장됩니다. ['1', '12', '13', '21', '32', '45']
# {547} 회차가 저장됩니다. ['6', '7', '15', '22', '34', '39']
# {546} 회차가 저장됩니다. ['8', '17', '20', '27', '37', '43']
# {545} 회차가 저장됩니다. ['4', '24', '25', '27', '34', '35']
# {544} 회차가 저장됩니다. ['5', '17', '21', '25', '36', '44']
# {543} 회차가 저장됩니다. ['13', '18', '26', '31', '34', '44']
# {542} 회차가 저장됩니다. ['5', '6', '19', '26', '41', '45']
# {541} 회차가 저장됩니다. ['8', '13', '26', '28', '32', '34']
# {540} 회차가 저장됩니다. ['3', '12', '13', '15', '34', '36']
# {539} 회차가 저장됩니다. ['3', '19', '22', '31', '42', '43']
# {538} 회차가 저장됩니다. ['6', '10', '18', '31', '32', '34']
# {537} 회차가 저장됩니다. ['12', '23', '26', '30', '36', '43']
# {536} 회차가 저장됩니다. ['7', '8', '18', '32', '37', '43']
# {535} 회차가 저장됩니다. ['11', '12', '14', '15', '18', '39']
# {534} 회차가 저장됩니다. ['10', '24', '26', '29', '37', '38']
# {533} 회차가 저장됩니다. ['9', '14', '15', '17', '31', '33']
# {532} 회차가 저장됩니다. ['16', '17', '23', '24', '29', '44']
# {531} 회차가 저장됩니다. ['1', '5', '9', '21', '27', '35']
# {530} 회차가 저장됩니다. ['16', '23', '27', '29', '33', '41']
# {529} 회차가 저장됩니다. ['18', '20', '24', '27', '31', '42']
# {528} 회차가 저장됩니다. ['5', '17', '25', '31', '39', '40']
# {527} 회차가 저장됩니다. ['1', '12', '22', '32', '33', '42']
# {526} 회차가 저장됩니다. ['7', '14', '17', '20', '35', '39']
# {525} 회차가 저장됩니다. ['11', '23', '26', '29', '39', '44']
# {524} 회차가 저장됩니다. ['10', '11', '29', '38', '41', '45']
# {523} 회차가 저장됩니다. ['1', '4', '37', '38', '40', '45']
# {522} 회차가 저장됩니다. ['4', '5', '13', '14', '37', '41']
# {521} 회차가 저장됩니다. ['3', '7', '18', '29', '32', '36']
# {520} 회차가 저장됩니다. ['4', '22', '27', '28', '38', '40']
# {519} 회차가 저장됩니다. ['6', '8', '13', '16', '30', '43']
# {518} 회차가 저장됩니다. ['14', '23', '30', '32', '34', '38']
# {517} 회차가 저장됩니다. ['1', '9', '12', '28', '36', '41']
# {516} 회차가 저장됩니다. ['2', '8', '23', '41', '43', '44']
# {515} 회차가 저장됩니다. ['2', '11', '12', '15', '23', '37']
# {514} 회차가 저장됩니다. ['1', '15', '20', '26', '35', '42']
# {513} 회차가 저장됩니다. ['5', '8', '21', '23', '27', '33']
# {512} 회차가 저장됩니다. ['4', '5', '9', '13', '26', '27']
# {511} 회차가 저장됩니다. ['3', '7', '14', '23', '26', '42']
# {510} 회차가 저장됩니다. ['12', '29', '32', '33', '39', '40']
# {509} 회차가 저장됩니다. ['12', '25', '29', '35', '42', '43']
# {508} 회차가 저장됩니다. ['5', '27', '31', '34', '35', '43']
# {507} 회차가 저장됩니다. ['12', '13', '32', '33', '40', '41']
# {506} 회차가 저장됩니다. ['6', '9', '11', '22', '24', '30']
# {505} 회차가 저장됩니다. ['7', '20', '22', '25', '38', '40']
# {504} 회차가 저장됩니다. ['6', '14', '22', '26', '43', '44']
# {503} 회차가 저장됩니다. ['1', '5', '27', '30', '34', '36']
# {502} 회차가 저장됩니다. ['6', '22', '28', '32', '34', '40']
# {501} 회차가 저장됩니다. ['1', '4', '10', '17', '31', '42']
# {500} 회차가 저장됩니다. ['3', '4', '12', '20', '24', '34']
# {499} 회차가 저장됩니다. ['5', '20', '23', '27', '35', '40']
# {498} 회차가 저장됩니다. ['13', '14', '24', '32', '39', '41']
# {497} 회차가 저장됩니다. ['19', '20', '23', '24', '43', '44']
# {496} 회차가 저장됩니다. ['4', '13', '20', '29', '36', '41']
# {495} 회차가 저장됩니다. ['4', '13', '22', '27', '34', '44']
# {494} 회차가 저장됩니다. ['5', '7', '8', '15', '30', '43']
# {493} 회차가 저장됩니다. ['20', '22', '26', '33', '36', '37']
# {492} 회차가 저장됩니다. ['22', '27', '31', '35', '37', '40']
# {491} 회차가 저장됩니다. ['8', '17', '35', '36', '39', '42']
# {490} 회차가 저장됩니다. ['2', '7', '26', '29', '40', '43']
# {489} 회차가 저장됩니다. ['2', '4', '8', '15', '20', '27']
# {488} 회차가 저장됩니다. ['2', '8', '17', '30', '31', '38']
# {487} 회차가 저장됩니다. ['4', '8', '25', '27', '37', '41']
# {486} 회차가 저장됩니다. ['1', '2', '23', '25', '38', '40']
# {485} 회차가 저장됩니다. ['17', '22', '26', '27', '36', '39']
# {484} 회차가 저장됩니다. ['1', '3', '27', '28', '32', '45']
# {483} 회차가 저장됩니다. ['12', '15', '19', '22', '28', '34']
# {482} 회차가 저장됩니다. ['1', '10', '16', '24', '25', '35']
# {481} 회차가 저장됩니다. ['3', '4', '23', '29', '40', '41']
# {480} 회차가 저장됩니다. ['3', '5', '10', '17', '30', '31']
# {479} 회차가 저장됩니다. ['8', '23', '25', '27', '35', '44']
# {478} 회차가 저장됩니다. ['18', '29', '30', '37', '39', '43']
# {477} 회차가 저장됩니다. ['14', '25', '29', '32', '33', '45']
# {476} 회차가 저장됩니다. ['9', '12', '13', '15', '37', '38']
# {475} 회차가 저장됩니다. ['1', '9', '14', '16', '21', '29']
# {474} 회차가 저장됩니다. ['4', '13', '18', '31', '33', '45']
# {473} 회차가 저장됩니다. ['8', '13', '20', '22', '23', '36']
# {472} 회차가 저장됩니다. ['16', '25', '26', '31', '36', '43']
# {471} 회차가 저장됩니다. ['6', '13', '29', '37', '39', '41']
# {470} 회차가 저장됩니다. ['10', '16', '20', '39', '41', '42']
# {469} 회차가 저장됩니다. ['4', '21', '22', '34', '37', '38']
# {468} 회차가 저장됩니다. ['8', '13', '15', '28', '37', '43']
# {467} 회차가 저장됩니다. ['2', '12', '14', '17', '24', '40']
# {466} 회차가 저장됩니다. ['4', '10', '13', '23', '32', '44']
# {465} 회차가 저장됩니다. ['1', '8', '11', '13', '22', '38']
# {464} 회차가 저장됩니다. ['6', '12', '15', '34', '42', '44']
# {463} 회차가 저장됩니다. ['23', '29', '31', '33', '34', '44']
# {462} 회차가 저장됩니다. ['3', '20', '24', '32', '37', '45']
# {461} 회차가 저장됩니다. ['11', '18', '26', '31', '37', '40']
# {460} 회차가 저장됩니다. ['8', '11', '28', '30', '43', '45']
# {459} 회차가 저장됩니다. ['4', '6', '10', '14', '25', '40']
# {458} 회차가 저장됩니다. ['4', '9', '10', '32', '36', '40']
# {457} 회차가 저장됩니다. ['8', '10', '18', '23', '27', '40']
# {456} 회차가 저장됩니다. ['1', '7', '12', '18', '23', '27']
# {455} 회차가 저장됩니다. ['4', '19', '20', '26', '30', '35']
# {454} 회차가 저장됩니다. ['13', '25', '27', '34', '38', '41']
# {453} 회차가 저장됩니다. ['12', '24', '33', '38', '40', '42']
# {452} 회차가 저장됩니다. ['8', '10', '18', '30', '32', '34']
# {451} 회차가 저장됩니다. ['12', '15', '20', '24', '30', '38']
# {450} 회차가 저장됩니다. ['6', '14', '19', '21', '23', '31']
# {449} 회차가 저장됩니다. ['3', '10', '20', '26', '35', '43']
# {448} 회차가 저장됩니다. ['3', '7', '13', '27', '40', '41']
# {447} 회차가 저장됩니다. ['2', '7', '8', '9', '17', '33']
# {446} 회차가 저장됩니다. ['1', '11', '12', '14', '26', '35']
# {445} 회차가 저장됩니다. ['13', '20', '21', '30', '39', '45']
# {444} 회차가 저장됩니다. ['25', '27', '29', '36', '38', '40']
# {443} 회차가 저장됩니다. ['4', '6', '10', '19', '20', '44']
# {442} 회차가 저장됩니다. ['25', '27', '29', '36', '38', '40']
# {441} 회차가 저장됩니다. ['1', '23', '28', '30', '34', '35']
# {440} 회차가 저장됩니다. ['10', '22', '28', '34', '36', '44']
# {439} 회차가 저장됩니다. ['17', '20', '30', '31', '37', '40']
# {438} 회차가 저장됩니다. ['6', '12', '20', '26', '29', '38']
# {437} 회차가 저장됩니다. ['11', '16', '29', '38', '41', '44']
# {436} 회차가 저장됩니다. ['9', '14', '20', '22', '33', '34']
# {435} 회차가 저장됩니다. ['8', '16', '26', '30', '38', '45']
# {434} 회차가 저장됩니다. ['3', '13', '20', '24', '33', '37']
# {433} 회차가 저장됩니다. ['19', '23', '29', '33', '35', '43']
# {432} 회차가 저장됩니다. ['2', '3', '5', '11', '27', '39']
# {431} 회차가 저장됩니다. ['18', '22', '25', '31', '38', '45']
# {430} 회차가 저장됩니다. ['1', '3', '16', '18', '30', '34']
# {429} 회차가 저장됩니다. ['3', '23', '28', '34', '39', '42']
# {428} 회차가 저장됩니다. ['12', '16', '19', '22', '37', '40']
# {427} 회차가 저장됩니다. ['6', '7', '15', '24', '28', '30']
# {426} 회차가 저장됩니다. ['4', '17', '18', '27', '39', '43']
# {425} 회차가 저장됩니다. ['8', '10', '14', '27', '33', '38']
# {424} 회차가 저장됩니다. ['10', '11', '26', '31', '34', '44']
# {423} 회차가 저장됩니다. ['1', '17', '27', '28', '29', '40']
# {422} 회차가 저장됩니다. ['8', '15', '19', '21', '34', '44']
# {421} 회차가 저장됩니다. ['6', '11', '26', '27', '28', '44']
# {420} 회차가 저장됩니다. ['4', '9', '10', '29', '31', '34']
# {419} 회차가 저장됩니다. ['2', '11', '13', '14', '28', '30']
# {418} 회차가 저장됩니다. ['11', '13', '15', '26', '28', '34']
# {417} 회차가 저장됩니다. ['4', '5', '14', '20', '22', '43']
# {416} 회차가 저장됩니다. ['5', '6', '8', '11', '22', '26']
# {415} 회차가 저장됩니다. ['7', '17', '20', '26', '30', '40']
# {414} 회차가 저장됩니다. ['2', '14', '15', '22', '23', '44']
# {413} 회차가 저장됩니다. ['2', '9', '15', '23', '34', '40']
# {412} 회차가 저장됩니다. ['4', '7', '39', '41', '42', '45']
# {411} 회차가 저장됩니다. ['11', '14', '22', '35', '37', '39']
# {410} 회차가 저장됩니다. ['1', '3', '18', '32', '40', '41']
# {409} 회차가 저장됩니다. ['6', '9', '21', '31', '32', '40']
# {408} 회차가 저장됩니다. ['9', '20', '21', '22', '30', '37']
# {407} 회차가 저장됩니다. ['6', '7', '13', '16', '24', '25']
# {406} 회차가 저장됩니다. ['7', '12', '21', '24', '27', '36']
# {405} 회차가 저장됩니다. ['1', '2', '10', '25', '26', '44']
# {404} 회차가 저장됩니다. ['5', '20', '21', '24', '33', '40']
# {403} 회차가 저장됩니다. ['10', '14', '22', '24', '28', '37']
# {402} 회차가 저장됩니다. ['5', '9', '15', '19', '22', '36']
# {401} 회차가 저장됩니다. ['6', '12', '18', '31', '38', '43']
# {400} 회차가 저장됩니다. ['9', '21', '27', '34', '41', '43']
# {399} 회차가 저장됩니다. ['1', '2', '9', '17', '19', '42']
# {398} 회차가 저장됩니다. ['10', '15', '20', '23', '42', '44']
# {397} 회차가 저장됩니다. ['12', '13', '17', '22', '25', '33']
# {396} 회차가 저장됩니다. ['18', '20', '31', '34', '40', '45']
# {395} 회차가 저장됩니다. ['11', '15', '20', '26', '31', '35']
# {394} 회차가 저장됩니다. ['1', '13', '20', '22', '25', '28']
# {393} 회차가 저장됩니다. ['9', '16', '28', '40', '41', '43']
# {392} 회차가 저장됩니다. ['1', '3', '7', '8', '24', '42']
# {391} 회차가 저장됩니다. ['10', '11', '18', '22', '28', '39']
# {390} 회차가 저장됩니다. ['16', '17', '28', '37', '39', '40']
# {389} 회차가 저장됩니다. ['7', '16', '18', '20', '23', '26']
# {388} 회차가 저장됩니다. ['1', '8', '9', '17', '29', '32']
# {387} 회차가 저장됩니다. ['1', '26', '31', '34', '40', '43']
# {386} 회차가 저장됩니다. ['4', '7', '10', '19', '31', '40']
# {385} 회차가 저장됩니다. ['7', '12', '19', '21', '29', '32']
# {384} 회차가 저장됩니다. ['11', '22', '24', '32', '36', '38']
# {383} 회차가 저장됩니다. ['4', '15', '28', '33', '37', '40']
# {382} 회차가 저장됩니다. ['10', '15', '22', '24', '27', '42']
# {381} 회차가 저장됩니다. ['1', '5', '10', '12', '16', '20']
# {380} 회차가 저장됩니다. ['1', '2', '8', '17', '26', '37']
# {379} 회차가 저장됩니다. ['6', '10', '22', '31', '35', '40']
# {378} 회차가 저장됩니다. ['5', '22', '29', '31', '34', '39']
# {377} 회차가 저장됩니다. ['6', '22', '29', '37', '43', '45']
# {376} 회차가 저장됩니다. ['1', '11', '13', '24', '28', '40']
# {375} 회차가 저장됩니다. ['4', '8', '19', '25', '27', '45']
# {374} 회차가 저장됩니다. ['11', '13', '15', '17', '25', '34']
# {373} 회차가 저장됩니다. ['15', '26', '37', '42', '43', '45']
# {372} 회차가 저장됩니다. ['8', '11', '14', '16', '18', '21']
# {371} 회차가 저장됩니다. ['7', '9', '15', '26', '27', '42']
# {370} 회차가 저장됩니다. ['16', '18', '24', '42', '44', '45']
# {369} 회차가 저장됩니다. ['17', '20', '35', '36', '41', '43']
# {368} 회차가 저장됩니다. ['11', '21', '24', '30', '39', '45']
# {367} 회차가 저장됩니다. ['3', '22', '25', '29', '32', '44']
# {366} 회차가 저장됩니다. ['5', '12', '19', '26', '27', '44']
# {365} 회차가 저장됩니다. ['5', '15', '21', '25', '26', '30']
# {364} 회차가 저장됩니다. ['2', '5', '7', '14', '16', '40']
# {363} 회차가 저장됩니다. ['11', '12', '14', '21', '32', '38']
# {362} 회차가 저장됩니다. ['2', '3', '22', '27', '30', '40']
# {361} 회차가 저장됩니다. ['5', '10', '16', '24', '27', '35']
# {360} 회차가 저장됩니다. ['4', '16', '23', '25', '35', '40']
# {359} 회차가 저장됩니다. ['1', '10', '19', '20', '24', '40']
# {358} 회차가 저장됩니다. ['1', '9', '10', '12', '21', '40']
# {357} 회차가 저장됩니다. ['10', '14', '18', '21', '36', '37']
# {356} 회차가 저장됩니다. ['2', '8', '14', '25', '29', '45']
# {355} 회차가 저장됩니다. ['5', '8', '29', '30', '35', '44']
# {354} 회차가 저장됩니다. ['14', '19', '36', '43', '44', '45']
# {353} 회차가 저장됩니다. ['11', '16', '19', '22', '29', '36']
# {352} 회차가 저장됩니다. ['5', '16', '17', '20', '26', '41']
# {351} 회차가 저장됩니다. ['5', '25', '27', '29', '34', '36']
# {350} 회차가 저장됩니다. ['1', '8', '18', '24', '29', '33']
# {349} 회차가 저장됩니다. ['5', '13', '14', '20', '24', '25']
# {348} 회차가 저장됩니다. ['3', '14', '17', '20', '24', '31']
# {347} 회차가 저장됩니다. ['3', '8', '13', '27', '32', '42']
# {346} 회차가 저장됩니다. ['5', '13', '14', '22', '44', '45']
# {345} 회차가 저장됩니다. ['15', '20', '23', '29', '39', '42']
# {344} 회차가 저장됩니다. ['1', '2', '15', '28', '34', '45']
# {343} 회차가 저장됩니다. ['1', '10', '17', '29', '31', '43']
# {342} 회차가 저장됩니다. ['1', '13', '14', '33', '34', '43']
# {341} 회차가 저장됩니다. ['1', '8', '19', '34', '39', '43']
# {340} 회차가 저장됩니다. ['18', '24', '26', '29', '34', '38']
# {339} 회차가 저장됩니다. ['6', '8', '14', '21', '30', '37']
# {338} 회차가 저장됩니다. ['2', '13', '34', '38', '42', '45']
# {337} 회차가 저장됩니다. ['1', '5', '14', '18', '32', '37']
# {336} 회차가 저장됩니다. ['3', '5', '20', '34', '35', '44']
# {335} 회차가 저장됩니다. ['5', '9', '16', '23', '26', '45']
# {334} 회차가 저장됩니다. ['13', '15', '21', '29', '39', '43']
# {333} 회차가 저장됩니다. ['4', '9', '14', '26', '31', '44']
# {332} 회차가 저장됩니다. ['16', '17', '34', '36', '42', '45']
# {331} 회차가 저장됩니다. ['4', '9', '14', '26', '31', '44']
# {330} 회차가 저장됩니다. ['3', '4', '16', '17', '19', '20']
# {329} 회차가 저장됩니다. ['9', '17', '19', '30', '35', '42']
# {328} 회차가 저장됩니다. ['1', '6', '9', '16', '17', '28']
# {327} 회차가 저장됩니다. ['6', '12', '13', '17', '32', '44']
# {326} 회차가 저장됩니다. ['16', '23', '25', '33', '36', '39']
# {325} 회차가 저장됩니다. ['7', '17', '20', '32', '44', '45']
# {324} 회차가 저장됩니다. ['2', '4', '21', '25', '33', '36']
# {323} 회차가 저장됩니다. ['10', '14', '15', '32', '36', '42']
# {322} 회차가 저장됩니다. ['9', '18', '29', '32', '38', '43']
# {321} 회차가 저장됩니다. ['12', '18', '20', '21', '25', '34']
# {320} 회차가 저장됩니다. ['16', '19', '23', '25', '41', '45']
# {319} 회차가 저장됩니다. ['5', '8', '22', '28', '33', '42']
# {318} 회차가 저장됩니다. ['2', '17', '19', '20', '34', '45']
# {317} 회차가 저장됩니다. ['3', '10', '11', '22', '36', '39']
# {316} 회차가 저장됩니다. ['10', '11', '21', '27', '31', '39']
# {315} 회차가 저장됩니다. ['1', '13', '33', '35', '43', '45']
# {314} 회차가 저장됩니다. ['15', '17', '19', '34', '38', '41']
# {313} 회차가 저장됩니다. ['9', '17', '34', '35', '43', '45']
# {312} 회차가 저장됩니다. ['2', '3', '5', '6', '12', '20']
# {311} 회차가 저장됩니다. ['4', '12', '24', '27', '28', '32']
# {310} 회차가 저장됩니다. ['1', '5', '19', '28', '34', '41']
# {309} 회차가 저장됩니다. ['1', '2', '5', '11', '18', '36']
# {308} 회차가 저장됩니다. ['14', '15', '17', '19', '37', '45']
# {307} 회차가 저장됩니다. ['5', '15', '21', '23', '25', '45']
# {306} 회차가 저장됩니다. ['4', '18', '23', '30', '34', '41']
# {305} 회차가 저장됩니다. ['7', '8', '18', '21', '23', '39']
# {304} 회차가 저장됩니다. ['4', '10', '16', '26', '33', '41']
# {303} 회차가 저장됩니다. ['2', '14', '17', '30', '38', '45']
# {302} 회차가 저장됩니다. ['13', '19', '20', '32', '38', '42']
# {301} 회차가 저장됩니다. ['7', '11', '13', '33', '37', '43']
# {300} 회차가 저장됩니다. ['7', '9', '10', '12', '26', '38']
# {299} 회차가 저장됩니다. ['1', '3', '20', '25', '36', '45']
# {298} 회차가 저장됩니다. ['5', '9', '27', '29', '37', '40']
# {297} 회차가 저장됩니다. ['6', '11', '19', '20', '28', '32']
# {296} 회차가 저장됩니다. ['3', '8', '15', '27', '30', '45']
# {295} 회차가 저장됩니다. ['1', '4', '12', '16', '18', '38']
# {294} 회차가 저장됩니다. ['6', '10', '17', '30', '37', '38']
# {293} 회차가 저장됩니다. ['1', '9', '17', '21', '29', '33']
# {292} 회차가 저장됩니다. ['17', '18', '31', '32', '33', '34']
# {291} 회차가 저장됩니다. ['3', '7', '8', '18', '20', '42']
# {290} 회차가 저장됩니다. ['8', '13', '18', '32', '39', '45']
# {289} 회차가 저장됩니다. ['3', '14', '33', '37', '38', '42']
# {288} 회차가 저장됩니다. ['1', '12', '17', '28', '35', '41']
# {287} 회차가 저장됩니다. ['6', '12', '24', '27', '35', '37']
# {286} 회차가 저장됩니다. ['1', '15', '19', '40', '42', '44']
# {285} 회차가 저장됩니다. ['13', '33', '37', '40', '41', '45']
# {284} 회차가 저장됩니다. ['2', '7', '15', '24', '30', '45']
# {283} 회차가 저장됩니다. ['6', '8', '18', '31', '38', '45']
# {282} 회차가 저장됩니다. ['2', '5', '10', '18', '31', '32']
# {281} 회차가 저장됩니다. ['1', '3', '4', '6', '14', '41']
# {280} 회차가 저장됩니다. ['10', '11', '23', '24', '36', '37']
# {279} 회차가 저장됩니다. ['7', '16', '31', '36', '37', '38']
# {278} 회차가 저장됩니다. ['3', '11', '37', '39', '41', '43']
# {277} 회차가 저장됩니다. ['10', '12', '13', '15', '25', '29']
# {276} 회차가 저장됩니다. ['4', '15', '21', '33', '39', '41']
# {275} 회차가 저장됩니다. ['14', '19', '20', '35', '38', '40']
# {274} 회차가 저장됩니다. ['13', '14', '15', '26', '35', '39']
# {273} 회차가 저장됩니다. ['1', '8', '24', '31', '34', '44']
# {272} 회차가 저장됩니다. ['7', '9', '12', '27', '39', '43']
# {271} 회차가 저장됩니다. ['3', '8', '9', '27', '29', '40']
# {270} 회차가 저장됩니다. ['5', '9', '12', '20', '21', '26']
# {269} 회차가 저장됩니다. ['5', '18', '20', '36', '42', '43']
# {268} 회차가 저장됩니다. ['3', '10', '19', '24', '32', '45']
# {267} 회차가 저장됩니다. ['7', '8', '24', '34', '36', '41']
# {266} 회차가 저장됩니다. ['3', '4', '9', '11', '22', '42']
# {265} 회차가 저장됩니다. ['5', '9', '34', '37', '38', '39']
# {264} 회차가 저장됩니다. ['9', '16', '27', '36', '41', '44']
# {263} 회차가 저장됩니다. ['1', '27', '28', '32', '37', '40']
# {262} 회차가 저장됩니다. ['9', '12', '24', '25', '29', '31']
# {261} 회차가 저장됩니다. ['6', '11', '16', '18', '31', '43']
# {260} 회차가 저장됩니다. ['7', '12', '15', '24', '37', '40']
# {259} 회차가 저장됩니다. ['4', '5', '14', '35', '42', '45']
# {258} 회차가 저장됩니다. ['14', '27', '30', '31', '38', '40']
# {257} 회차가 저장됩니다. ['6', '13', '27', '31', '32', '37']
# {256} 회차가 저장됩니다. ['4', '11', '14', '21', '23', '43']
# {255} 회차가 저장됩니다. ['1', '5', '6', '24', '27', '42']
# {254} 회차가 저장됩니다. ['1', '5', '19', '20', '24', '30']
# {253} 회차가 저장됩니다. ['8', '19', '25', '31', '34', '36']
# {252} 회차가 저장됩니다. ['14', '23', '26', '31', '39', '45']
# {251} 회차가 저장됩니다. ['6', '7', '19', '25', '28', '38']
# {250} 회차가 저장됩니다. ['19', '23', '30', '37', '43', '45']
# {249} 회차가 저장됩니다. ['3', '8', '27', '31', '41', '44']
# {248} 회차가 저장됩니다. ['3', '8', '17', '23', '38', '45']
# {247} 회차가 저장됩니다. ['12', '15', '28', '36', '39', '40']
# {246} 회차가 저장됩니다. ['13', '18', '21', '23', '26', '39']
# {245} 회차가 저장됩니다. ['9', '11', '27', '31', '32', '38']
# {244} 회차가 저장됩니다. ['13', '16', '25', '36', '37', '38']
# {243} 회차가 저장됩니다. ['2', '12', '17', '19', '28', '42']
# {242} 회차가 저장됩니다. ['4', '19', '20', '21', '32', '34']
# {241} 회차가 저장됩니다. ['2', '16', '24', '27', '28', '35']
# {240} 회차가 저장됩니다. ['6', '10', '16', '40', '41', '43']
# {239} 회차가 저장됩니다. ['11', '15', '24', '39', '41', '44']
# {238} 회차가 저장됩니다. ['2', '4', '15', '28', '31', '34']
# {237} 회차가 저장됩니다. ['1', '11', '17', '21', '24', '44']
# {236} 회차가 저장됩니다. ['1', '4', '8', '13', '37', '39']
# {235} 회차가 저장됩니다. ['21', '22', '26', '27', '31', '37']
# {234} 회차가 저장됩니다. ['13', '21', '22', '24', '26', '37']
# {233} 회차가 저장됩니다. ['4', '6', '13', '17', '28', '40']
# {232} 회차가 저장됩니다. ['8', '9', '10', '12', '24', '44']
# {231} 회차가 저장됩니다. ['5', '10', '19', '31', '44', '45']
# {230} 회차가 저장됩니다. ['5', '11', '14', '29', '32', '33']
# {229} 회차가 저장됩니다. ['4', '5', '9', '11', '23', '38']
# {228} 회차가 저장됩니다. ['17', '25', '35', '36', '39', '44']
# {227} 회차가 저장됩니다. ['4', '5', '15', '16', '22', '42']
# {226} 회차가 저장됩니다. ['2', '6', '8', '14', '21', '22']
# {225} 회차가 저장됩니다. ['5', '11', '13', '19', '31', '36']
# {224} 회차가 저장됩니다. ['4', '19', '26', '27', '30', '42']
# {223} 회차가 저장됩니다. ['1', '3', '18', '20', '26', '27']
# {222} 회차가 저장됩니다. ['5', '11', '19', '21', '34', '43']
# {221} 회차가 저장됩니다. ['2', '20', '33', '35', '37', '40']
# {220} 회차가 저장됩니다. ['5', '11', '19', '21', '34', '43']
# {219} 회차가 저장됩니다. ['4', '11', '20', '26', '35', '37']
# {218} 회차가 저장됩니다. ['1', '8', '14', '18', '29', '44']
# {217} 회차가 저장됩니다. ['16', '20', '27', '33', '35', '39']
# {216} 회차가 저장됩니다. ['7', '16', '17', '33', '36', '40']
# {215} 회차가 저장됩니다. ['2', '3', '7', '15', '43', '44']
# {214} 회차가 저장됩니다. ['5', '7', '20', '25', '28', '37']
# {213} 회차가 저장됩니다. ['2', '3', '4', '5', '20', '24']
# {212} 회차가 저장됩니다. ['11', '12', '18', '21', '31', '38']
# {211} 회차가 저장됩니다. ['12', '13', '17', '20', '33', '41']
# {210} 회차가 저장됩니다. ['10', '19', '22', '23', '25', '37']
# {209} 회차가 저장됩니다. ['2', '7', '18', '20', '24', '33']
# {208} 회차가 저장됩니다. ['14', '25', '31', '34', '40', '44']
# {207} 회차가 저장됩니다. ['3', '11', '14', '31', '32', '37']
# {206} 회차가 저장됩니다. ['1', '2', '3', '15', '20', '25']
# {205} 회차가 저장됩니다. ['1', '3', '21', '29', '35', '37']
# {204} 회차가 저장됩니다. ['3', '12', '14', '35', '40', '45']
# {203} 회차가 저장됩니다. ['1', '3', '11', '24', '30', '32']
# {202} 회차가 저장됩니다. ['12', '14', '27', '33', '39', '44']
# {201} 회차가 저장됩니다. ['3', '11', '24', '38', '39', '44']
# {200} 회차가 저장됩니다. ['5', '6', '13', '14', '17', '20']
# {199} 회차가 저장됩니다. ['14', '21', '22', '25', '30', '36']
# {198} 회차가 저장됩니다. ['12', '19', '20', '25', '41', '45']
# {197} 회차가 저장됩니다. ['7', '12', '16', '34', '42', '45']
# {196} 회차가 저장됩니다. ['35', '36', '37', '41', '44', '45']
# {195} 회차가 저장됩니다. ['7', '10', '19', '22', '35', '40']
# {194} 회차가 저장됩니다. ['15', '20', '23', '26', '39', '44']
# {193} 회차가 저장됩니다. ['6', '14', '18', '26', '36', '39']
# {192} 회차가 저장됩니다. ['4', '8', '11', '18', '37', '45']
# {191} 회차가 저장됩니다. ['5', '6', '24', '25', '32', '37']
# {190} 회차가 저장됩니다. ['8', '14', '18', '30', '31', '44']
# {189} 회차가 저장됩니다. ['8', '14', '32', '35', '37', '45']
# {188} 회차가 저장됩니다. ['19', '24', '27', '30', '31', '34']
# {187} 회차가 저장됩니다. ['1', '2', '8', '18', '29', '38']
# {186} 회차가 저장됩니다. ['4', '10', '14', '19', '21', '45']
# {185} 회차가 저장됩니다. ['1', '2', '4', '8', '19', '38']
# {184} 회차가 저장됩니다. ['1', '2', '6', '16', '20', '33']
# {183} 회차가 저장됩니다. ['2', '18', '24', '34', '40', '42']
# {182} 회차가 저장됩니다. ['13', '15', '27', '29', '34', '40']
# {181} 회차가 저장됩니다. ['14', '21', '23', '32', '40', '45']
# {180} 회차가 저장됩니다. ['2', '15', '20', '21', '29', '34']
# {179} 회차가 저장됩니다. ['5', '9', '17', '25', '39', '43']
# {178} 회차가 저장됩니다. ['1', '5', '11', '12', '18', '23']
# {177} 회차가 저장됩니다. ['1', '10', '13', '16', '37', '43']
# {176} 회차가 저장됩니다. ['4', '17', '30', '32', '33', '34']
# {175} 회차가 저장됩니다. ['19', '26', '28', '31', '33', '36']
# {174} 회차가 저장됩니다. ['13', '14', '18', '22', '35', '39']
# {173} 회차가 저장됩니다. ['3', '9', '24', '30', '33', '34']
# {172} 회차가 저장됩니다. ['4', '19', '21', '24', '26', '41']
# {171} 회차가 저장됩니다. ['4', '16', '25', '29', '34', '35']
# {170} 회차가 저장됩니다. ['2', '11', '13', '15', '31', '42']
# {169} 회차가 저장됩니다. ['16', '27', '35', '37', '43', '45']
# {168} 회차가 저장됩니다. ['3', '10', '31', '40', '42', '43']
# {167} 회차가 저장됩니다. ['24', '27', '28', '30', '36', '39']
# {166} 회차가 저장됩니다. ['9', '12', '27', '36', '39', '45']
# {165} 회차가 저장됩니다. ['5', '13', '18', '19', '22', '42']
# {164} 회차가 저장됩니다. ['6', '9', '10', '11', '39', '41']
# {163} 회차가 저장됩니다. ['7', '11', '26', '28', '29', '44']
# {162} 회차가 저장됩니다. ['1', '5', '21', '25', '38', '41']
# {161} 회차가 저장됩니다. ['22', '34', '36', '40', '42', '45']
# {160} 회차가 저장됩니다. ['3', '7', '8', '34', '39', '41']
# {159} 회차가 저장됩니다. ['1', '18', '30', '41', '42', '43']
# {158} 회차가 저장됩니다. ['4', '9', '13', '18', '21', '34']
# {157} 회차가 저장됩니다. ['19', '26', '30', '33', '35', '39']
# {156} 회차가 저장됩니다. ['5', '18', '28', '30', '42', '45']
# {155} 회차가 저장됩니다. ['16', '19', '20', '32', '33', '41']
# {154} 회차가 저장됩니다. ['6', '19', '21', '35', '40', '45']
# {153} 회차가 저장됩니다. ['3', '8', '11', '12', '13', '36']
# {152} 회차가 저장됩니다. ['1', '5', '13', '26', '29', '34']
# {151} 회차가 저장됩니다. ['1', '2', '10', '13', '18', '19']
# {150} 회차가 저장됩니다. ['2', '18', '25', '28', '37', '39']
# {149} 회차가 저장됩니다. ['2', '11', '21', '34', '41', '42']
# {148} 회차가 저장됩니다. ['21', '25', '33', '34', '35', '36']
# {147} 회차가 저장됩니다. ['4', '6', '13', '21', '40', '42']
# {146} 회차가 저장됩니다. ['2', '19', '27', '35', '41', '42']
# {145} 회차가 저장됩니다. ['2', '3', '13', '20', '27', '44']
# {144} 회차가 저장됩니다. ['4', '15', '17', '26', '36', '37']
# {143} 회차가 저장됩니다. ['26', '27', '28', '42', '43', '45']
# {142} 회차가 저장됩니다. ['12', '16', '30', '34', '40', '44']
# {141} 회차가 저장됩니다. ['8', '12', '29', '31', '42', '43']
# {140} 회차가 저장됩니다. ['3', '13', '17', '18', '19', '28']
# {139} 회차가 저장됩니다. ['9', '11', '15', '20', '28', '43']
# {138} 회차가 저장됩니다. ['10', '11', '27', '28', '37', '39']
# {137} 회차가 저장됩니다. ['7', '9', '20', '25', '36', '39']
# {136} 회차가 저장됩니다. ['2', '16', '30', '36', '41', '42']
# {135} 회차가 저장됩니다. ['6', '14', '22', '28', '35', '39']
# {134} 회차가 저장됩니다. ['3', '12', '20', '23', '31', '35']
# {133} 회차가 저장됩니다. ['4', '7', '15', '18', '23', '26']
# {132} 회차가 저장됩니다. ['3', '17', '23', '34', '41', '45']
# {131} 회차가 저장됩니다. ['8', '10', '11', '14', '15', '21']
# {130} 회차가 저장됩니다. ['7', '19', '24', '27', '42', '45']
# {129} 회차가 저장됩니다. ['19', '23', '25', '28', '38', '42']
# {128} 회차가 저장됩니다. ['12', '30', '34', '36', '37', '45']
# {127} 회차가 저장됩니다. ['3', '5', '10', '29', '32', '43']
# {126} 회차가 저장됩니다. ['7', '20', '22', '27', '40', '43']
# {125} 회차가 저장됩니다. ['2', '8', '32', '33', '35', '36']
# {124} 회차가 저장됩니다. ['4', '16', '23', '25', '29', '42']
# {123} 회차가 저장됩니다. ['7', '17', '18', '28', '30', '45']
# {122} 회차가 저장됩니다. ['1', '11', '16', '17', '36', '40']
# {121} 회차가 저장됩니다. ['12', '28', '30', '34', '38', '43']
# {120} 회차가 저장됩니다. ['4', '6', '10', '11', '32', '37']
# {119} 회차가 저장됩니다. ['3', '11', '13', '14', '17', '21']
# {118} 회차가 저장됩니다. ['3', '4', '10', '17', '19', '22']
# {117} 회차가 저장됩니다. ['5', '10', '22', '34', '36', '44']
# {116} 회차가 저장됩니다. ['2', '4', '25', '31', '34', '37']
# {115} 회차가 저장됩니다. ['1', '2', '6', '9', '25', '28']
# {114} 회차가 저장됩니다. ['11', '14', '19', '26', '28', '41']
# {113} 회차가 저장됩니다. ['4', '9', '28', '33', '36', '45']
# {112} 회차가 저장됩니다. ['26', '29', '30', '33', '41', '42']
# {111} 회차가 저장됩니다. ['1', '5', '34', '36', '42', '44']
# {110} 회차가 저장됩니다. ['7', '20', '22', '23', '29', '43']
# {109} 회차가 저장됩니다. ['1', '5', '34', '36', '42', '44']
# {108} 회차가 저장됩니다. ['7', '18', '22', '23', '29', '44']
# {107} 회차가 저장됩니다. ['1', '4', '5', '6', '9', '31']
# {106} 회차가 저장됩니다. ['4', '10', '12', '22', '24', '33']
# {105} 회차가 저장됩니다. ['8', '10', '20', '34', '41', '45']
# {104} 회차가 저장됩니다. ['17', '32', '33', '34', '42', '44']
# {103} 회차가 저장됩니다. ['5', '14', '15', '27', '30', '45']
# {102} 회차가 저장됩니다. ['17', '22', '24', '26', '35', '40']
# {101} 회차가 저장됩니다. ['1', '3', '17', '32', '35', '45']
# {100} 회차가 저장됩니다. ['1', '7', '11', '23', '37', '42']
# {99} 회차가 저장됩니다. ['6', '9', '16', '23', '24', '32']
# {98} 회차가 저장됩니다. ['17', '18', '21', '27', '29', '33']
# {97} 회차가 저장됩니다. ['7', '11', '16', '21', '27', '33']
# {96} 회차가 저장됩니다. ['3', '9', '10', '29', '40', '45']
# {95} 회차가 저장됩니다. ['1', '14', '15', '24', '40', '41']
# {94} 회차가 저장됩니다. ['14', '21', '35', '36', '40', '44']
# {93} 회차가 저장됩니다. ['4', '11', '28', '39', '42', '45']
# {92} 회차가 저장됩니다. ['7', '9', '12', '15', '19', '23']
# {91} 회차가 저장됩니다. ['9', '14', '17', '18', '42', '44']
# {90} 회차가 저장됩니다. ['7', '24', '29', '30', '34', '35']
# {89} 회차가 저장됩니다. ['8', '19', '20', '21', '33', '39']
# {88} 회차가 저장됩니다. ['6', '7', '12', '22', '26', '36']
# {87} 회차가 저장됩니다. ['1', '4', '10', '14', '15', '35']
# {86} 회차가 저장됩니다. ['2', '6', '20', '27', '37', '39']
# {85} 회차가 저장됩니다. ['8', '22', '35', '38', '39', '41']
# {84} 회차가 저장됩니다. ['5', '13', '17', '29', '34', '39']
# {83} 회차가 저장됩니다. ['3', '9', '11', '12', '13', '19']
# {82} 회차가 저장됩니다. ['4', '5', '31', '35', '43', '45']
# {81} 회차가 저장됩니다. ['16', '25', '33', '38', '40', '45']
# {80} 회차가 저장됩니다. ['6', '11', '15', '17', '23', '40']
# {79} 회차가 저장됩니다. ['12', '17', '23', '34', '42', '45']
# {78} 회차가 저장됩니다. ['2', '6', '7', '12', '19', '45']
# {77} 회차가 저장됩니다. ['5', '6', '13', '16', '27', '28']
# {76} 회차가 저장됩니다. ['5', '7', '11', '16', '41', '45']
# {75} 회차가 저장됩니다. ['9', '33', '36', '40', '42', '43']
# {74} 회차가 저장됩니다. ['12', '14', '24', '26', '34', '45']
# {73} 회차가 저장됩니다. ['7', '22', '29', '33', '34', '35']
# {72} 회차가 저장됩니다. ['11', '17', '21', '26', '36', '45']
# {71} 회차가 저장됩니다. ['4', '8', '13', '19', '20', '43']
# {70} 회차가 저장됩니다. ['10', '18', '30', '36', '39', '44']
# {69} 회차가 저장됩니다. ['4', '5', '8', '16', '21', '29']
# {68} 회차가 저장됩니다. ['7', '17', '19', '30', '36', '38']
# {67} 회차가 저장됩니다. ['3', '5', '7', '14', '26', '34']
# {66} 회차가 저장됩니다. ['12', '15', '24', '36', '41', '44']
# {65} 회차가 저장됩니다. ['7', '18', '19', '27', '29', '42']
# {64} 회차가 저장됩니다. ['3', '21', '22', '33', '41', '42']
# {63} 회차가 저장됩니다. ['6', '15', '22', '23', '25', '32']
# {62} 회차가 저장됩니다. ['19', '28', '31', '38', '43', '44']
# {61} 회차가 저장됩니다. ['6', '8', '13', '30', '35', '40']
# {60} 회차가 저장됩니다. ['4', '8', '27', '34', '39', '40']
# {59} 회차가 저장됩니다. ['5', '12', '17', '29', '34', '35']
# {58} 회차가 저장됩니다. ['6', '8', '28', '33', '38', '39']
# {57} 회차가 저장됩니다. ['5', '7', '20', '22', '37', '42']
# {56} 회차가 저장됩니다. ['3', '6', '13', '23', '24', '35']
# {55} 회차가 저장됩니다. ['1', '10', '15', '16', '32', '41']
# {54} 회차가 저장됩니다. ['29', '31', '35', '38', '40', '44']
# {53} 회차가 저장됩니다. ['3', '19', '22', '31', '42', '43']
# {52} 회차가 저장됩니다. ['18', '20', '24', '27', '31', '42']
# {51} 회차가 저장됩니다. ['6', '8', '13', '16', '30', '43']
# {50} 회차가 저장됩니다. ['12', '25', '29', '35', '42', '43']
# {49} 회차가 저장됩니다. ['5', '20', '23', '27', '35', '40']
# {48} 회차가 저장됩니다. ['2', '4', '8', '15', '20', '27']
# {47} 회차가 저장됩니다. ['8', '23', '25', '27', '35', '44']
# {46} 회차가 저장됩니다. ['4', '21', '22', '34', '37', '38']
# {45} 회차가 저장됩니다. ['4', '6', '10', '14', '25', '40']
# {44} 회차가 저장됩니다. ['8', '10', '18', '23', '27', '40']
# {43} 회차가 저장됩니다. ['17', '20', '30', '31', '37', '40']
# {42} 회차가 저장됩니다. ['3', '23', '28', '34', '39', '42']
# {41} 회차가 저장됩니다. ['2', '11', '13', '14', '28', '30']
# {40} 회차가 저장됩니다. ['6', '9', '21', '31', '32', '40']
# {39} 회차가 저장됩니다. ['1', '2', '9', '17', '19', '42']
# {38} 회차가 저장됩니다. ['7', '16', '18', '20', '23', '26']
# {37} 회차가 저장됩니다. ['6', '10', '22', '31', '35', '40']
# {36} 회차가 저장됩니다. ['17', '20', '35', '36', '41', '43']
# {35} 회차가 저장됩니다. ['1', '10', '19', '20', '24', '40']
# {34} 회차가 저장됩니다. ['5', '13', '14', '20', '24', '25']
# {33} 회차가 저장됩니다. ['3', '8', '13', '27', '32', '42']
# {32} 회차가 저장됩니다. ['9', '17', '19', '30', '35', '42']
# {31} 회차가 저장됩니다. ['5', '8', '22', '28', '33', '42']
# {30} 회차가 저장됩니다. ['1', '2', '5', '11', '18', '36']
# {29} 회차가 저장됩니다. ['1', '3', '20', '25', '36', '45']
# {28} 회차가 저장됩니다. ['3', '14', '33', '37', '38', '42']
# {27} 회차가 저장됩니다. ['7', '16', '31', '36', '37', '38']
# {26} 회차가 저장됩니다. ['5', '18', '20', '36', '42', '43']
# {25} 회차가 저장됩니다. ['4', '5', '14', '35', '42', '45']
# {24} 회차가 저장됩니다. ['3', '8', '27', '31', '41', '44']
# {23} 회차가 저장됩니다. ['11', '15', '24', '39', '41', '44']
# {22} 회차가 저장됩니다. ['1', '11', '17', '21', '24', '44']
# {21} 회차가 저장됩니다. ['4', '11', '20', '26', '35', '37']
# {20} 회차가 저장됩니다. ['2', '7', '18', '20', '24', '33']
# {19} 회차가 저장됩니다. ['14', '21', '22', '25', '30', '36']
# {18} 회차가 저장됩니다. ['8', '14', '32', '35', '37', '45']
# {17} 회차가 저장됩니다. ['5', '9', '17', '25', '39', '43']
# {16} 회차가 저장됩니다. ['16', '27', '35', '37', '43', '45']
# {15} 회차가 저장됩니다. ['1', '18', '30', '41', '42', '43']
# {14} 회차가 저장됩니다. ['2', '11', '21', '34', '41', '42']
# {13} 회차가 저장됩니다. ['9', '11', '15', '20', '28', '43']
# {12} 회차가 저장됩니다. ['19', '23', '25', '28', '38', '42']
# {11} 회차가 저장됩니다. ['3', '5', '10', '29', '32', '43']
# {10} 회차가 저장됩니다. ['1', '5', '34', '36', '42', '44']
# {9} 회차가 저장됩니다. ['1', '3', '10', '27', '29', '37']
# {8} 회차가 저장됩니다. ['4', '26', '28', '29', '33', '40']
# {7} 회차가 저장됩니다. ['3', '12', '24', '27', '30', '32']
# {6} 회차가 저장됩니다. ['5', '8', '14', '15', '19', '39']
# {5} 회차가 저장됩니다. ['6', '29', '36', '39', '41', '45']
# {4} 회차가 저장됩니다. ['4', '7', '16', '19', '33', '40']
# {3} 회차가 저장됩니다. ['6', '7', '13', '15', '21', '43']
# {2} 회차가 저장됩니다. ['1', '5', '13', '34', '39', '40']
# {1} 회차가 저장됩니다. ['6', '30', '38', '39', '40', '43']

# %%
## 콤보박스의 회차 수가 text로 잡혀있어서 send_key(회차번호) 를 쓰면, 제대로 작동하지 않는 것을 확인
# ex. ~ 1000회 까지는 무난히 가능했지만,
# 999 를 send_key 하는 순간 999의 숫자가 선택되는것이 아니라 997이 선택된다.

# 추론 : 999 라는 번호는 텍스트로 이뤄져 있다. 이에 1000 다음 숫자로 9를 send 하면 999가 선택된다.
# 하지만 그 다음으로 99를 send 하면 997이 선택된다.

## 해결 :   from selenium.webdriver.support.ui import Select 
# select = Select(driver.find_element(By.XPATH, '//*[@id="dwrNoList"]'))
# select.select_by_value(i)
## > value값을 선택하면 된다!

# %%
driver.find_element(By.XPATH, '//*[@id="dwrNoList"]').click()
driver.find_element(By.XPATH, '//*[@id="dwrNoList"]').send_keys()

# %%
driver.find_element(By.XPATH, '//*[@id="searchBtn"]').send_keys(Keys.ENTER)

# %%
nums = []
for _ in range(1, 7):

    # 신규 회차의 로또번호 6개를 리스트에 넣기
    nums.append(driver.find_element(By.XPATH, '//*[@id="article"]/div[2]/div/div[2]/div/div[1]/p/span[{}]'.format(_)).text)

# 새로운 회차 및 번호 DB에 저장
print({i}, '회차가 저장됩니다.', '{}'.format(nums))
# Out:
# {4} 회차가 저장됩니다. ['10', '14', '16', '18', '29', '35']

# %%
driver.close()

# %%
nums
# Out:
# ['6', '30', '38', '39', '40', '43']

# %%
service = Service('../chromedriver')
url = 'https://www.dhlottery.co.kr/gameResult.do?method=byWin'
try:
    driver = webdriver.Chrome(service = service)
except:
    print('chromedriver의 버전을 확인해 주세요 😣')
    time.sleep(2)
    sys.exit()

driver.get(url)

# %%
from selenium.webdriver.support.ui import Select

select = Select(driver.find_element(By.XPATH, '//*[@id="dwrNoList"]'))

# select.select_by_index(index=2)
# select.select_by_visible_text(text="option_text")
select.select_by_value(value='1')

# %%
from selenium.webdriver.support.ui import Select

service = Service('../chromedriver')
url = 'https://www.dhlottery.co.kr/gameResult.do?method=byWin'
try:
    driver = webdriver.Chrome(service = service)
except:
    print('chromedriver의 버전을 확인해 주세요 😣')
    time.sleep(2)
    sys.exit()

driver.get(url)


# 최신회차 조회
new = int(driver.find_element(By.XPATH, '//*[@id="dwrNoList"]').text.strip().split()[0])
print('최신 회차 : {}회'.format(new))


for i in range(new, 0, -1):     # 신규회차부터 1회차까지 역순으로 데이터 저장

            # select = Select(driver.find_element(By.XPATH, '//*[@id="dwrNoList"]'))
            # select.select_by_value(value=i)
            
            driver.find_element(By.XPATH, '//*[@id="dwrNoList"]').send_keys(i)
            time.sleep(1)
            driver.find_element(By.XPATH, '//*[@id="searchBtn"]').send_keys('1000', Keys.ENTER)
            time.sleep(1)

            nums = []
            for _ in range(1, 7):

                # 신규 회차의 로또번호 6개를 리스트에 넣기
                nums.append(driver.find_element(By.XPATH, '//*[@id="article"]/div[2]/div/div[2]/div/div[1]/p/span[{}]'.format(_)).text)

            # 새로운 회차 및 번호 DB에 저장
            print({i}, '회차가 저장됩니다.', '{}'.format(nums))
            driver.implicitly_wait(10)
# driver.close()

# %%
# driver.find_element(By.XPATH, '//*[@id="dwrNoList"]').send_keys(i)

driver.find_element(By.XPATH, '//*[@id="searchBtn"]').send_keys('2', Keys.ENTER)

# %%
select = Select(driver.find_element(By.XPATH, '//*[@id="dwrNoList"]'))
select.select_by_value(value='999')
driver.find_element(By.XPATH, '//*[@id="searchBtn"]').send_keys(Keys.ENTER)

# %%
driver.find_element(By.XPATH, '//*[@id="dwrNoList"]').send_keys('999', Keys.ENTER)

# %% [markdown]
# ----------------

# %% [markdown]
# # 새로운 테이블 만들기

# %%
import mysql
import mysql.connector
from selenium import *
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import Select
import sys, time

# ====================== #

# # host 정보 확인
# host = int(input('which is your host? 1. local / 2. server  >> '))
# if host == 1:
#     host = '192.168.35.159'
# elif host == 2:
#     host = input('input server address: ')
# else:
#     sys.exit()
    
mydb = mysql.connector.connect(host = '192.168.35.159', port = '3306', user='', password = '')
mydb

table_name = 'lot_num'      # table name 지정

mycursor = mydb.cursor(buffered = True)


## =========== USE DB ============= ##
mycursor.execute('USE lotto_db')

## =========== Table ======== ##

# DB 에 새로운 TABLE 만들기
mycursor.execute('SHOW TABLES')
find_table = mycursor.fetchall()

if ('{}'.format(table_name),) in find_table:     # TABLE 중복 여부 확인
    print("{} 이라는 테이블이 이미 DB에 존재합니다.".format(table_name))

else:       # TABLE 이 없을 때, 새로 만들기
    mycursor.execute('CREATE TABLE {} (ID INT NOT NULL AUTO_INCREMENT PRIMARY KEY, NUM1 INT NOT NULL, NUM2 INT NOT NULL, NUM3 INT NOT NULL, NUM4 INT NOT NULL, NUM5 INT NOT NULL, NUM6 INT NOT NULL)'.format(table_name))
    mydb.commit()
    print('{} 이라는 테이블을 새로 만들었습니다.'.format(table_name))

# TABLE 의 DESC 확인
mycursor.execute('DESC {}'.format(table_name))
print(mycursor.fetchall())

# DB에 저장된 모든 회차 정보 조회
mycursor.execute('SELECT ID FROM {} ORDER BY ID DESC'.format(table_name))
all_num_in_sql = mycursor.fetchall()
all_num_in_sql = [all_num_in_sql[i][0] for i in range(0,len(all_num_in_sql))]
# print(all_num_in_sql)       # 저장된 전체 회차 조회

# # DB에 저장된 최신 회차 정보 조회
# mycursor.execute('SELECT * FROM {} ORDER BY ID DESC LIMIT 1'.format(table_name))
# latest_num_in_sql = mycursor.fetchall()
# print(latest_num_in_sql[0])
# print(f'TABLE에 저장된 최신회차는 : {latest_num_in_sql} 회차 입니다.')

## ========= Page access ======= ##

# 로또 홈페이지 접속
service = Service('../chromedriver')
url = 'https://www.dhlottery.co.kr/gameResult.do?method=byWin'
try:
    driver = webdriver.Chrome(service = service)
except:
    print('chromedriver의 버전을 확인해 주세요 😣')
    time.sleep(2)
    sys.exit()

driver.get(url)

# 최신회차 조회
new = int(driver.find_element(By.XPATH, '//*[@id="dwrNoList"]').text.strip().split()[0])
print('최신 회차 : {}회'.format(new))

# 최신회차 검사
if new in all_num_in_sql:
    print('최신 회차 ({})가 DB에 저장되어 있습니다.'.format(new))
    mycursor.execute('SELECT * FROM {} ORDER BY ID DESC LIMIT 1'.format(table_name))        # 최신회차 정보 불러오기
    latest_nums = list(mycursor.fetchall()[0])
    print('({}회차 : {})'.format(new, latest_nums))

elif all_num_in_sql == []:
    print('TABLE 에 로또 정보가 없습니다.')
    q = int(input('웹에서 정보를 받아오시겠습니까? (1 : yes, 2: no) '))
    if q == 1:

        for i in range(1, new+1):     # 1회차 부터 신규 회차까지 루프 > 데이터 저장

            select = Select(driver.find_element(By.XPATH, '//*[@id="dwrNoList"]'))      # 드롭박스 선택
            select.select_by_value(str(i))       # value 선택

            # driver.find_element(By.XPATH, '//*[@id="dwrNoList"]').send_keys(i)        ### >> 삭제 // 해당 element의 값이 str 형식으로, i키를 받으면 오류가 발생
            driver.implicitly_wait(10)
            driver.find_element(By.XPATH, '//*[@id="searchBtn"]').send_keys(Keys.ENTER)     # 조회버튼 클릭

            nums = []
            for _ in range(1, 7):

                # 신규 회차의 로또번호 6개를 리스트에 넣기
                nums.append(driver.find_element(By.XPATH, '//*[@id="article"]/div[2]/div/div[2]/div/div[1]/p/span[{}]'.format(_)).text)

            # 새로운 회차 및 번호 DB에 저장
            print({i}, '회차가 저장됩니다.', '{}'.format(nums))
            mycursor.execute('INSERT INTO {} (ID, NUM1, NUM2, NUM3, NUM4, NUM5, NUM6) VALUES ({}, {}, {}, {}, {}, {}, {})'.format(table_name, i, nums[0],nums[1],nums[2],nums[3],nums[4],nums[5]))
                                            ## {table_name} table desc : ID, num1 ~ num6
            mydb.commit()       # 커서의 쿼리 실행 저장

            # DB의 저장된 데이터 확인
            mycursor.execute('SELECT * FROM {} ORDER BY ID DESC LIMIT 1'.format(table_name))
            latest_info = mycursor.fetchall()[0]
            print('{} 회차 : [{}, {}, {}, {}, {}, {}] 저장 됨'.format(latest_info[0], latest_info[1],latest_info[2],latest_info[3],latest_info[4],latest_info[5],latest_info[6]))
            
else:
    print('최신 회차 ({})가 저장되어 있지 않습니다. (현재 저장되어있는 최신회차 : {}회)'.format(new, all_num_in_sql[0]))
    q = int(input('최신회차 정보를 업데이트 하시겠습니까? (1 : yes, 2: no)'))
    if q == 1:

        for i in range(all_num_in_sql[0]+1, new+1):     # DB에 저장된 최신회차 + 1 부터 신규 회차까지 루프 > 데이터 저장
            
            select = Select(driver.find_element(By.XPATH, '//*[@id="dwrNoList"]'))      # 드롭박스 선택
            select.select_by_value(str(i))       # value 선택   

            # driver.find_element(By.XPATH, '//*[@id="dwrNoList"]').send_keys(i)        ### >> 삭제 // 해당 element의 값이 str 형식으로, i키를 받으면 오류가 발생
            driver.implicitly_wait(10)
            driver.find_element(By.XPATH, '//*[@id="searchBtn"]').send_keys(Keys.ENTER)     # 조회버튼 클릭

            nums = []
            for _ in range(1, 7):

                # 신규 회차의 로또번호 6개를 리스트에 넣기
                nums.append(driver.find_element(By.XPATH, '//*[@id="article"]/div[2]/div/div[2]/div/div[1]/p/span[{}]'.format(_)).text)

            # 새로운 회차 및 번호 DB에 저장
            print({i}, '회차가 저장됩니다.', '{}'.format(nums))
            mycursor.execute('INSERT INTO {} (ID, NUM1, NUM2, NUM3, NUM4, NUM5, NUM6) VALUES ({}, {}, {}, {}, {}, {}, {})'.format(table_name, i, nums[0],nums[1],nums[2],nums[3],nums[4],nums[5]))
                                            ## {table_name} table desc : ID, num1 ~ num6
            mydb.commit()       # 커서의 쿼리 실행 저장

            # DB의 저장된 데이터 확인
            mycursor.execute('SELECT * FROM {} ORDER BY ID DESC LIMIT 1'.format(table_name))
            latest_info = mycursor.fetchall()[0]
            print('{} 회차 : [{}, {}, {}, {}, {}, {}] 저장 됨'.format(latest_info[0], latest_info[1],latest_info[2],latest_info[3],latest_info[4],latest_info[5],latest_info[6]))
            
driver.close()
mydb.close()
# Out:
# lot_num 이라는 테이블이 이미 DB에 존재합니다.
# [('ID', 'int(11)', 'NO', 'PRI', None, 'auto_increment'), ('NUM1', 'int(11)', 'NO', '', None, ''), ('NUM2', 'int(11)', 'NO', '', None, ''), ('NUM3', 'int(11)', 'NO', '', None, ''), ('NUM4', 'int(11)', 'NO', '', None, ''), ('NUM5', 'int(11)', 'NO', '', None, ''), ('NUM6', 'int(11)', 'NO', '', None, '')]
# 최신 회차 : 1024회
# TABLE 에 로또 정보가 없습니다.
# {1} 회차가 저장됩니다. ['10', '23', '29', '33', '37', '40']
# 1 회차 : [10, 23, 29, 33, 37, 40] 저장 됨
# {2} 회차가 저장됩니다. ['9', '13', '21', '25', '32', '42']
# 2 회차 : [9, 13, 21, 25, 32, 42] 저장 됨
# {3} 회차가 저장됩니다. ['11', '16', '19', '21', '27', '31']
# 3 회차 : [11, 16, 19, 21, 27, 31] 저장 됨
# {4} 회차가 저장됩니다. ['14', '27', '30', '31', '40', '42']
# 4 회차 : [14, 27, 30, 31, 40, 42] 저장 됨
# {5} 회차가 저장됩니다. ['16', '24', '29', '40', '41', '42']
# 5 회차 : [16, 24, 29, 40, 41, 42] 저장 됨
# {6} 회차가 저장됩니다. ['14', '15', '26', '27', '40', '42']
# 6 회차 : [14, 15, 26, 27, 40, 42] 저장 됨
# {7} 회차가 저장됩니다. ['2', '9', '16', '25', '26', '40']
# 7 회차 : [2, 9, 16, 25, 26, 40] 저장 됨
# {8} 회차가 저장됩니다. ['8', '19', '25', '34', '37', '39']
# 8 회차 : [8, 19, 25, 34, 37, 39] 저장 됨
# {9} 회차가 저장됩니다. ['2', '4', '16', '17', '36', '39']
# 9 회차 : [2, 4, 16, 17, 36, 39] 저장 됨
# {10} 회차가 저장됩니다. ['9', '25', '30', '33', '41', '44']
# 10 회차 : [9, 25, 30, 33, 41, 44] 저장 됨
# {11} 회차가 저장됩니다. ['1', '7', '36', '37', '41', '42']
# 11 회차 : [1, 7, 36, 37, 41, 42] 저장 됨
# {12} 회차가 저장됩니다. ['2', '11', '21', '25', '39', '45']
# 12 회차 : [2, 11, 21, 25, 39, 45] 저장 됨
# {13} 회차가 저장됩니다. ['22', '23', '25', '37', '38', '42']
# 13 회차 : [22, 23, 25, 37, 38, 42] 저장 됨
# {14} 회차가 저장됩니다. ['2', '6', '12', '31', '33', '40']
# 14 회차 : [2, 6, 12, 31, 33, 40] 저장 됨
# {15} 회차가 저장됩니다. ['3', '4', '16', '30', '31', '37']
# 15 회차 : [3, 4, 16, 30, 31, 37] 저장 됨
# {16} 회차가 저장됩니다. ['6', '7', '24', '37', '38', '40']
# 16 회차 : [6, 7, 24, 37, 38, 40] 저장 됨
# {17} 회차가 저장됩니다. ['3', '4', '9', '17', '32', '37']
# 17 회차 : [3, 4, 9, 17, 32, 37] 저장 됨
# {18} 회차가 저장됩니다. ['3', '12', '13', '19', '32', '35']
# 18 회차 : [3, 12, 13, 19, 32, 35] 저장 됨
# {19} 회차가 저장됩니다. ['6', '30', '38', '39', '40', '43']
# 19 회차 : [6, 30, 38, 39, 40, 43] 저장 됨
# {20} 회차가 저장됩니다. ['10', '14', '18', '20', '23', '30']
# 20 회차 : [10, 14, 18, 20, 23, 30] 저장 됨
# {21} 회차가 저장됩니다. ['6', '12', '17', '18', '31', '32']
# 21 회차 : [6, 12, 17, 18, 31, 32] 저장 됨
# {22} 회차가 저장됩니다. ['4', '5', '6', '8', '17', '39']
# 22 회차 : [4, 5, 6, 8, 17, 39] 저장 됨
# {23} 회차가 저장됩니다. ['5', '13', '17', '18', '33', '42']
# 23 회차 : [5, 13, 17, 18, 33, 42] 저장 됨
# {24} 회차가 저장됩니다. ['7', '8', '27', '29', '36', '43']
# 24 회차 : [7, 8, 27, 29, 36, 43] 저장 됨
# {25} 회차가 저장됩니다. ['2', '4', '21', '26', '43', '44']
# 25 회차 : [2, 4, 21, 26, 43, 44] 저장 됨
# {26} 회차가 저장됩니다. ['4', '5', '7', '18', '20', '25']
# 26 회차 : [4, 5, 7, 18, 20, 25] 저장 됨
# {27} 회차가 저장됩니다. ['1', '20', '26', '28', '37', '43']
# 27 회차 : [1, 20, 26, 28, 37, 43] 저장 됨
# {28} 회차가 저장됩니다. ['9', '18', '23', '25', '35', '37']
# 28 회차 : [9, 18, 23, 25, 35, 37] 저장 됨
# {29} 회차가 저장됩니다. ['1', '5', '13', '34', '39', '40']
# 29 회차 : [1, 5, 13, 34, 39, 40] 저장 됨
# {30} 회차가 저장됩니다. ['8', '17', '20', '35', '36', '44']
# 30 회차 : [8, 17, 20, 35, 36, 44] 저장 됨
# {31} 회차가 저장됩니다. ['7', '9', '18', '23', '28', '35']
# 31 회차 : [7, 9, 18, 23, 28, 35] 저장 됨
# {32} 회차가 저장됩니다. ['6', '14', '19', '25', '34', '44']
# 32 회차 : [6, 14, 19, 25, 34, 44] 저장 됨
# {33} 회차가 저장됩니다. ['4', '7', '32', '33', '40', '41']
# 33 회차 : [4, 7, 32, 33, 40, 41] 저장 됨
# {34} 회차가 저장됩니다. ['9', '26', '35', '37', '40', '42']
# 34 회차 : [9, 26, 35, 37, 40, 42] 저장 됨
# {35} 회차가 저장됩니다. ['2', '3', '11', '26', '37', '43']
# 35 회차 : [2, 3, 11, 26, 37, 43] 저장 됨
# {36} 회차가 저장됩니다. ['1', '10', '23', '26', '28', '40']
# 36 회차 : [1, 10, 23, 26, 28, 40] 저장 됨
# {37} 회차가 저장됩니다. ['7', '27', '30', '33', '35', '37']
# 37 회차 : [7, 27, 30, 33, 35, 37] 저장 됨
# {38} 회차가 저장됩니다. ['16', '17', '22', '30', '37', '43']
# 38 회차 : [16, 17, 22, 30, 37, 43] 저장 됨
# {39} 회차가 저장됩니다. ['6', '7', '13', '15', '21', '43']
# 39 회차 : [6, 7, 13, 15, 21, 43] 저장 됨
# {40} 회차가 저장됩니다. ['7', '13', '18', '19', '25', '26']
# 40 회차 : [7, 13, 18, 19, 25, 26] 저장 됨
# {41} 회차가 저장됩니다. ['13', '20', '23', '35', '38', '43']
# 41 회차 : [13, 20, 23, 35, 38, 43] 저장 됨
# {42} 회차가 저장됩니다. ['17', '18', '19', '21', '23', '32']
# 42 회차 : [17, 18, 19, 21, 23, 32] 저장 됨
# {43} 회차가 저장됩니다. ['6', '31', '35', '38', '39', '44']
# 43 회차 : [6, 31, 35, 38, 39, 44] 저장 됨
# {44} 회차가 저장됩니다. ['3', '11', '21', '30', '38', '45']
# 44 회차 : [3, 11, 21, 30, 38, 45] 저장 됨
# {45} 회차가 저장됩니다. ['1', '10', '20', '27', '33', '35']
# 45 회차 : [1, 10, 20, 27, 33, 35] 저장 됨
# {46} 회차가 저장됩니다. ['8', '13', '15', '23', '31', '38']
# 46 회차 : [8, 13, 15, 23, 31, 38] 저장 됨
# {47} 회차가 저장됩니다. ['14', '17', '26', '31', '36', '45']
# 47 회차 : [14, 17, 26, 31, 36, 45] 저장 됨
# {48} 회차가 저장됩니다. ['6', '10', '18', '26', '37', '38']
# 48 회차 : [6, 10, 18, 26, 37, 38] 저장 됨
# {49} 회차가 저장됩니다. ['4', '7', '16', '19', '33', '40']
# 49 회차 : [4, 7, 16, 19, 33, 40] 저장 됨
# {50} 회차가 저장됩니다. ['2', '10', '12', '15', '22', '44']
# 50 회차 : [2, 10, 12, 15, 22, 44] 저장 됨
# {51} 회차가 저장됩니다. ['2', '3', '11', '16', '26', '44']
# 51 회차 : [2, 3, 11, 16, 26, 44] 저장 됨
# {52} 회차가 저장됩니다. ['2', '4', '15', '16', '20', '29']
# 52 회차 : [2, 4, 15, 16, 20, 29] 저장 됨
# {53} 회차가 저장됩니다. ['7', '8', '14', '32', '33', '39']
# 53 회차 : [7, 8, 14, 32, 33, 39] 저장 됨
# {54} 회차가 저장됩니다. ['1', '8', '21', '27', '36', '39']
# 54 회차 : [1, 8, 21, 27, 36, 39] 저장 됨
# {55} 회차가 저장됩니다. ['17', '21', '31', '37', '40', '44']
# 55 회차 : [17, 21, 31, 37, 40, 44] 저장 됨
# {56} 회차가 저장됩니다. ['10', '14', '30', '31', '33', '37']
# 56 회차 : [10, 14, 30, 31, 33, 37] 저장 됨
# {57} 회차가 저장됩니다. ['7', '10', '16', '25', '29', '44']
# 57 회차 : [7, 10, 16, 25, 29, 44] 저장 됨
# {58} 회차가 저장됩니다. ['10', '24', '25', '33', '40', '44']
# 58 회차 : [10, 24, 25, 33, 40, 44] 저장 됨
# {59} 회차가 저장됩니다. ['6', '29', '36', '39', '41', '45']
# 59 회차 : [6, 29, 36, 39, 41, 45] 저장 됨
# {60} 회차가 저장됩니다. ['2', '8', '25', '36', '39', '42']
# 60 회차 : [2, 8, 25, 36, 39, 42] 저장 됨
# {61} 회차가 저장됩니다. ['14', '15', '19', '30', '38', '43']
# 61 회차 : [14, 15, 19, 30, 38, 43] 저장 됨
# {62} 회차가 저장됩니다. ['3', '8', '15', '27', '29', '35']
# 62 회차 : [3, 8, 15, 27, 29, 35] 저장 됨
# {63} 회차가 저장됩니다. ['3', '20', '23', '36', '38', '40']
# 63 회차 : [3, 20, 23, 36, 38, 40] 저장 됨
# {64} 회차가 저장됩니다. ['14', '15', '18', '21', '26', '36']
# 64 회차 : [14, 15, 18, 21, 26, 36] 저장 됨
# {65} 회차가 저장됩니다. ['4', '25', '33', '36', '40', '43']
# 65 회차 : [4, 25, 33, 36, 40, 43] 저장 됨
# {66} 회차가 저장됩니다. ['2', '3', '7', '17', '22', '24']
# 66 회차 : [2, 3, 7, 17, 22, 24] 저장 됨
# {67} 회차가 저장됩니다. ['3', '7', '10', '15', '36', '38']
# 67 회차 : [3, 7, 10, 15, 36, 38] 저장 됨
# {68} 회차가 저장됩니다. ['10', '12', '15', '16', '26', '39']
# 68 회차 : [10, 12, 15, 16, 26, 39] 저장 됨
# {69} 회차가 저장됩니다. ['5', '8', '14', '15', '19', '39']
# 69 회차 : [5, 8, 14, 15, 19, 39] 저장 됨
# {70} 회차가 저장됩니다. ['5', '19', '22', '25', '28', '43']
# 70 회차 : [5, 19, 22, 25, 28, 43] 저장 됨
# {71} 회차가 저장됩니다. ['5', '9', '12', '16', '29', '41']
# 71 회차 : [5, 9, 12, 16, 29, 41] 저장 됨
# {72} 회차가 저장됩니다. ['2', '4', '11', '17', '26', '27']
# 72 회차 : [2, 4, 11, 17, 26, 27] 저장 됨
# {73} 회차가 저장됩니다. ['3', '12', '18', '32', '40', '43']
# 73 회차 : [3, 12, 18, 32, 40, 43] 저장 됨
# {74} 회차가 저장됩니다. ['6', '15', '17', '18', '35', '40']
# 74 회차 : [6, 15, 17, 18, 35, 40] 저장 됨
# {75} 회차가 저장됩니다. ['2', '5', '24', '32', '34', '44']
# 75 회차 : [2, 5, 24, 32, 34, 44] 저장 됨
# {76} 회차가 저장됩니다. ['1', '3', '15', '22', '25', '37']
# 76 회차 : [1, 3, 15, 22, 25, 37] 저장 됨
# {77} 회차가 저장됩니다. ['2', '18', '29', '32', '43', '44']
# 77 회차 : [2, 18, 29, 32, 43, 44] 저장 됨
# {78} 회차가 저장됩니다. ['10', '13', '25', '29', '33', '35']
# 78 회차 : [10, 13, 25, 29, 33, 35] 저장 됨
# {79} 회차가 저장됩니다. ['3', '12', '24', '27', '30', '32']
# 79 회차 : [3, 12, 24, 27, 30, 32] 저장 됨
# {80} 회차가 저장됩니다. ['17', '18', '24', '25', '26', '30']
# 80 회차 : [17, 18, 24, 25, 26, 30] 저장 됨
# {81} 회차가 저장됩니다. ['5', '7', '11', '13', '20', '33']
# 81 회차 : [5, 7, 11, 13, 20, 33] 저장 됨
# {82} 회차가 저장됩니다. ['1', '2', '3', '14', '27', '42']
# 82 회차 : [1, 2, 3, 14, 27, 42] 저장 됨
# {83} 회차가 저장됩니다. ['6', '10', '15', '17', '19', '34']
# 83 회차 : [6, 10, 15, 17, 19, 34] 저장 됨
# {84} 회차가 저장됩니다. ['16', '23', '27', '34', '42', '45']
# 84 회차 : [16, 23, 27, 34, 42, 45] 저장 됨
# {85} 회차가 저장됩니다. ['6', '8', '13', '23', '31', '36']
# 85 회차 : [6, 8, 13, 23, 31, 36] 저장 됨
# {86} 회차가 저장됩니다. ['2', '12', '37', '39', '41', '45']
# 86 회차 : [2, 12, 37, 39, 41, 45] 저장 됨
# {87} 회차가 저장됩니다. ['4', '12', '16', '23', '34', '43']
# 87 회차 : [4, 12, 16, 23, 34, 43] 저장 됨
# {88} 회차가 저장됩니다. ['1', '17', '20', '24', '30', '41']
# 88 회차 : [1, 17, 20, 24, 30, 41] 저장 됨
# {89} 회차가 저장됩니다. ['4', '26', '28', '29', '33', '40']
# 89 회차 : [4, 26, 28, 29, 33, 40] 저장 됨
# {90} 회차가 저장됩니다. ['17', '20', '29', '35', '38', '44']
# 90 회차 : [17, 20, 29, 35, 38, 44] 저장 됨
# {91} 회차가 저장됩니다. ['1', '21', '24', '26', '29', '42']
# 91 회차 : [1, 21, 24, 26, 29, 42] 저장 됨
# {92} 회차가 저장됩니다. ['3', '14', '24', '33', '35', '36']
# 92 회차 : [3, 14, 24, 33, 35, 36] 저장 됨
# {93} 회차가 저장됩니다. ['6', '22', '24', '36', '38', '44']
# 93 회차 : [6, 22, 24, 36, 38, 44] 저장 됨
# {94} 회차가 저장됩니다. ['5', '32', '34', '40', '41', '45']
# 94 회차 : [5, 32, 34, 40, 41, 45] 저장 됨
# {95} 회차가 저장됩니다. ['8', '17', '27', '31', '34', '43']
# 95 회차 : [8, 17, 27, 31, 34, 43] 저장 됨
# {96} 회차가 저장됩니다. ['1', '3', '8', '21', '22', '31']
# 96 회차 : [1, 3, 8, 21, 22, 31] 저장 됨
# {97} 회차가 저장됩니다. ['6', '7', '14', '15', '20', '36']
# 97 회차 : [6, 7, 14, 15, 20, 36] 저장 됨
# {98} 회차가 저장됩니다. ['6', '9', '16', '23', '24', '32']
# 98 회차 : [6, 9, 16, 23, 24, 32] 저장 됨
# {99} 회차가 저장됩니다. ['1', '3', '10', '27', '29', '37']
# 99 회차 : [1, 3, 10, 27, 29, 37] 저장 됨
# {100} 회차가 저장됩니다. ['1', '7', '11', '23', '37', '42']
# 100 회차 : [1, 7, 11, 23, 37, 42] 저장 됨
# {101} 회차가 저장됩니다. ['1', '3', '17', '32', '35', '45']
# 101 회차 : [1, 3, 17, 32, 35, 45] 저장 됨
# {102} 회차가 저장됩니다. ['17', '22', '24', '26', '35', '40']
# 102 회차 : [17, 22, 24, 26, 35, 40] 저장 됨
# {103} 회차가 저장됩니다. ['5', '14', '15', '27', '30', '45']
# 103 회차 : [5, 14, 15, 27, 30, 45] 저장 됨
# {104} 회차가 저장됩니다. ['17', '32', '33', '34', '42', '44']
# 104 회차 : [17, 32, 33, 34, 42, 44] 저장 됨
# {105} 회차가 저장됩니다. ['8', '10', '20', '34', '41', '45']
# 105 회차 : [8, 10, 20, 34, 41, 45] 저장 됨
# {106} 회차가 저장됩니다. ['4', '10', '12', '22', '24', '33']
# 106 회차 : [4, 10, 12, 22, 24, 33] 저장 됨
# {107} 회차가 저장됩니다. ['1', '4', '5', '6', '9', '31']
# 107 회차 : [1, 4, 5, 6, 9, 31] 저장 됨
# {108} 회차가 저장됩니다. ['7', '18', '22', '23', '29', '44']
# 108 회차 : [7, 18, 22, 23, 29, 44] 저장 됨
# {109} 회차가 저장됩니다. ['1', '5', '34', '36', '42', '44']
# 109 회차 : [1, 5, 34, 36, 42, 44] 저장 됨
# {110} 회차가 저장됩니다. ['7', '20', '22', '23', '29', '43']
# 110 회차 : [7, 20, 22, 23, 29, 43] 저장 됨
# {111} 회차가 저장됩니다. ['7', '18', '31', '33', '36', '40']
# 111 회차 : [7, 18, 31, 33, 36, 40] 저장 됨
# {112} 회차가 저장됩니다. ['26', '29', '30', '33', '41', '42']
# 112 회차 : [26, 29, 30, 33, 41, 42] 저장 됨
# {113} 회차가 저장됩니다. ['4', '9', '28', '33', '36', '45']
# 113 회차 : [4, 9, 28, 33, 36, 45] 저장 됨
# {114} 회차가 저장됩니다. ['11', '14', '19', '26', '28', '41']
# 114 회차 : [11, 14, 19, 26, 28, 41] 저장 됨
# {115} 회차가 저장됩니다. ['1', '2', '6', '9', '25', '28']
# 115 회차 : [1, 2, 6, 9, 25, 28] 저장 됨
# {116} 회차가 저장됩니다. ['2', '4', '25', '31', '34', '37']
# 116 회차 : [2, 4, 25, 31, 34, 37] 저장 됨
# {117} 회차가 저장됩니다. ['5', '10', '22', '34', '36', '44']
# 117 회차 : [5, 10, 22, 34, 36, 44] 저장 됨
# {118} 회차가 저장됩니다. ['3', '4', '10', '17', '19', '22']
# 118 회차 : [3, 4, 10, 17, 19, 22] 저장 됨
# {119} 회차가 저장됩니다. ['3', '11', '13', '14', '17', '21']
# 119 회차 : [3, 11, 13, 14, 17, 21] 저장 됨
# {120} 회차가 저장됩니다. ['4', '6', '10', '11', '32', '37']
# 120 회차 : [4, 6, 10, 11, 32, 37] 저장 됨
# {121} 회차가 저장됩니다. ['12', '28', '30', '34', '38', '43']
# 121 회차 : [12, 28, 30, 34, 38, 43] 저장 됨
# {122} 회차가 저장됩니다. ['1', '11', '16', '17', '36', '40']
# 122 회차 : [1, 11, 16, 17, 36, 40] 저장 됨
# {123} 회차가 저장됩니다. ['7', '17', '18', '28', '30', '45']
# 123 회차 : [7, 17, 18, 28, 30, 45] 저장 됨
# {124} 회차가 저장됩니다. ['4', '16', '23', '25', '29', '42']
# 124 회차 : [4, 16, 23, 25, 29, 42] 저장 됨
# {125} 회차가 저장됩니다. ['2', '8', '32', '33', '35', '36']
# 125 회차 : [2, 8, 32, 33, 35, 36] 저장 됨
# {126} 회차가 저장됩니다. ['7', '20', '22', '27', '40', '43']
# 126 회차 : [7, 20, 22, 27, 40, 43] 저장 됨
# {127} 회차가 저장됩니다. ['3', '5', '10', '29', '32', '43']
# 127 회차 : [3, 5, 10, 29, 32, 43] 저장 됨
# {128} 회차가 저장됩니다. ['12', '30', '34', '36', '37', '45']
# 128 회차 : [12, 30, 34, 36, 37, 45] 저장 됨
# {129} 회차가 저장됩니다. ['19', '23', '25', '28', '38', '42']
# 129 회차 : [19, 23, 25, 28, 38, 42] 저장 됨
# {130} 회차가 저장됩니다. ['7', '19', '24', '27', '42', '45']
# 130 회차 : [7, 19, 24, 27, 42, 45] 저장 됨
# {131} 회차가 저장됩니다. ['8', '10', '11', '14', '15', '21']
# 131 회차 : [8, 10, 11, 14, 15, 21] 저장 됨
# {132} 회차가 저장됩니다. ['3', '17', '23', '34', '41', '45']
# 132 회차 : [3, 17, 23, 34, 41, 45] 저장 됨
# {133} 회차가 저장됩니다. ['4', '7', '15', '18', '23', '26']
# 133 회차 : [4, 7, 15, 18, 23, 26] 저장 됨
# {134} 회차가 저장됩니다. ['3', '12', '20', '23', '31', '35']
# 134 회차 : [3, 12, 20, 23, 31, 35] 저장 됨
# {135} 회차가 저장됩니다. ['6', '14', '22', '28', '35', '39']
# 135 회차 : [6, 14, 22, 28, 35, 39] 저장 됨
# {136} 회차가 저장됩니다. ['2', '16', '30', '36', '41', '42']
# 136 회차 : [2, 16, 30, 36, 41, 42] 저장 됨
# {137} 회차가 저장됩니다. ['7', '9', '20', '25', '36', '39']
# 137 회차 : [7, 9, 20, 25, 36, 39] 저장 됨
# {138} 회차가 저장됩니다. ['10', '11', '27', '28', '37', '39']
# 138 회차 : [10, 11, 27, 28, 37, 39] 저장 됨
# {139} 회차가 저장됩니다. ['9', '11', '15', '20', '28', '43']
# 139 회차 : [9, 11, 15, 20, 28, 43] 저장 됨
# {140} 회차가 저장됩니다. ['3', '13', '17', '18', '19', '28']
# 140 회차 : [3, 13, 17, 18, 19, 28] 저장 됨
# {141} 회차가 저장됩니다. ['8', '12', '29', '31', '42', '43']
# 141 회차 : [8, 12, 29, 31, 42, 43] 저장 됨
# {142} 회차가 저장됩니다. ['12', '16', '30', '34', '40', '44']
# 142 회차 : [12, 16, 30, 34, 40, 44] 저장 됨
# {143} 회차가 저장됩니다. ['26', '27', '28', '42', '43', '45']
# 143 회차 : [26, 27, 28, 42, 43, 45] 저장 됨
# {144} 회차가 저장됩니다. ['4', '15', '17', '26', '36', '37']
# 144 회차 : [4, 15, 17, 26, 36, 37] 저장 됨
# {145} 회차가 저장됩니다. ['2', '3', '13', '20', '27', '44']
# 145 회차 : [2, 3, 13, 20, 27, 44] 저장 됨
# {146} 회차가 저장됩니다. ['2', '19', '27', '35', '41', '42']
# 146 회차 : [2, 19, 27, 35, 41, 42] 저장 됨
# {147} 회차가 저장됩니다. ['4', '6', '13', '21', '40', '42']
# 147 회차 : [4, 6, 13, 21, 40, 42] 저장 됨
# {148} 회차가 저장됩니다. ['21', '25', '33', '34', '35', '36']
# 148 회차 : [21, 25, 33, 34, 35, 36] 저장 됨
# {149} 회차가 저장됩니다. ['2', '11', '21', '34', '41', '42']
# 149 회차 : [2, 11, 21, 34, 41, 42] 저장 됨
# {150} 회차가 저장됩니다. ['2', '18', '25', '28', '37', '39']
# 150 회차 : [2, 18, 25, 28, 37, 39] 저장 됨
# {151} 회차가 저장됩니다. ['1', '2', '10', '13', '18', '19']
# 151 회차 : [1, 2, 10, 13, 18, 19] 저장 됨
# {152} 회차가 저장됩니다. ['1', '5', '13', '26', '29', '34']
# 152 회차 : [1, 5, 13, 26, 29, 34] 저장 됨
# {153} 회차가 저장됩니다. ['3', '8', '11', '12', '13', '36']
# 153 회차 : [3, 8, 11, 12, 13, 36] 저장 됨
# {154} 회차가 저장됩니다. ['6', '19', '21', '35', '40', '45']
# 154 회차 : [6, 19, 21, 35, 40, 45] 저장 됨
# {155} 회차가 저장됩니다. ['16', '19', '20', '32', '33', '41']
# 155 회차 : [16, 19, 20, 32, 33, 41] 저장 됨
# {156} 회차가 저장됩니다. ['5', '18', '28', '30', '42', '45']
# 156 회차 : [5, 18, 28, 30, 42, 45] 저장 됨
# {157} 회차가 저장됩니다. ['19', '26', '30', '33', '35', '39']
# 157 회차 : [19, 26, 30, 33, 35, 39] 저장 됨
# {158} 회차가 저장됩니다. ['4', '9', '13', '18', '21', '34']
# 158 회차 : [4, 9, 13, 18, 21, 34] 저장 됨
# {159} 회차가 저장됩니다. ['1', '18', '30', '41', '42', '43']
# 159 회차 : [1, 18, 30, 41, 42, 43] 저장 됨
# {160} 회차가 저장됩니다. ['3', '7', '8', '34', '39', '41']
# 160 회차 : [3, 7, 8, 34, 39, 41] 저장 됨
# {161} 회차가 저장됩니다. ['22', '34', '36', '40', '42', '45']
# 161 회차 : [22, 34, 36, 40, 42, 45] 저장 됨
# {162} 회차가 저장됩니다. ['1', '5', '21', '25', '38', '41']
# 162 회차 : [1, 5, 21, 25, 38, 41] 저장 됨
# {163} 회차가 저장됩니다. ['7', '11', '26', '28', '29', '44']
# 163 회차 : [7, 11, 26, 28, 29, 44] 저장 됨
# {164} 회차가 저장됩니다. ['6', '9', '10', '11', '39', '41']
# 164 회차 : [6, 9, 10, 11, 39, 41] 저장 됨
# {165} 회차가 저장됩니다. ['5', '13', '18', '19', '22', '42']
# 165 회차 : [5, 13, 18, 19, 22, 42] 저장 됨
# {166} 회차가 저장됩니다. ['9', '12', '27', '36', '39', '45']
# 166 회차 : [9, 12, 27, 36, 39, 45] 저장 됨
# {167} 회차가 저장됩니다. ['24', '27', '28', '30', '36', '39']
# 167 회차 : [24, 27, 28, 30, 36, 39] 저장 됨
# {168} 회차가 저장됩니다. ['3', '10', '31', '40', '42', '43']
# 168 회차 : [3, 10, 31, 40, 42, 43] 저장 됨
# {169} 회차가 저장됩니다. ['16', '27', '35', '37', '43', '45']
# 169 회차 : [16, 27, 35, 37, 43, 45] 저장 됨
# {170} 회차가 저장됩니다. ['2', '11', '13', '15', '31', '42']
# 170 회차 : [2, 11, 13, 15, 31, 42] 저장 됨
# {171} 회차가 저장됩니다. ['4', '16', '25', '29', '34', '35']
# 171 회차 : [4, 16, 25, 29, 34, 35] 저장 됨
# {172} 회차가 저장됩니다. ['4', '19', '21', '24', '26', '41']
# 172 회차 : [4, 19, 21, 24, 26, 41] 저장 됨
# {173} 회차가 저장됩니다. ['3', '9', '24', '30', '33', '34']
# 173 회차 : [3, 9, 24, 30, 33, 34] 저장 됨
# {174} 회차가 저장됩니다. ['13', '14', '18', '22', '35', '39']
# 174 회차 : [13, 14, 18, 22, 35, 39] 저장 됨
# {175} 회차가 저장됩니다. ['19', '26', '28', '31', '33', '36']
# 175 회차 : [19, 26, 28, 31, 33, 36] 저장 됨
# {176} 회차가 저장됩니다. ['4', '17', '30', '32', '33', '34']
# 176 회차 : [4, 17, 30, 32, 33, 34] 저장 됨
# {177} 회차가 저장됩니다. ['1', '10', '13', '16', '37', '43']
# 177 회차 : [1, 10, 13, 16, 37, 43] 저장 됨
# {178} 회차가 저장됩니다. ['1', '5', '11', '12', '18', '23']
# 178 회차 : [1, 5, 11, 12, 18, 23] 저장 됨
# {179} 회차가 저장됩니다. ['5', '9', '17', '25', '39', '43']
# 179 회차 : [5, 9, 17, 25, 39, 43] 저장 됨
# {180} 회차가 저장됩니다. ['2', '15', '20', '21', '29', '34']
# 180 회차 : [2, 15, 20, 21, 29, 34] 저장 됨
# {181} 회차가 저장됩니다. ['14', '21', '23', '32', '40', '45']
# 181 회차 : [14, 21, 23, 32, 40, 45] 저장 됨
# {182} 회차가 저장됩니다. ['13', '15', '27', '29', '34', '40']
# 182 회차 : [13, 15, 27, 29, 34, 40] 저장 됨
# {183} 회차가 저장됩니다. ['2', '18', '24', '34', '40', '42']
# 183 회차 : [2, 18, 24, 34, 40, 42] 저장 됨
# {184} 회차가 저장됩니다. ['1', '2', '6', '16', '20', '33']
# 184 회차 : [1, 2, 6, 16, 20, 33] 저장 됨
# {185} 회차가 저장됩니다. ['1', '2', '4', '8', '19', '38']
# 185 회차 : [1, 2, 4, 8, 19, 38] 저장 됨
# {186} 회차가 저장됩니다. ['4', '10', '14', '19', '21', '45']
# 186 회차 : [4, 10, 14, 19, 21, 45] 저장 됨
# {187} 회차가 저장됩니다. ['1', '2', '8', '18', '29', '38']
# 187 회차 : [1, 2, 8, 18, 29, 38] 저장 됨
# {188} 회차가 저장됩니다. ['19', '24', '27', '30', '31', '34']
# 188 회차 : [19, 24, 27, 30, 31, 34] 저장 됨
# {189} 회차가 저장됩니다. ['8', '14', '32', '35', '37', '45']
# 189 회차 : [8, 14, 32, 35, 37, 45] 저장 됨
# {190} 회차가 저장됩니다. ['8', '14', '18', '30', '31', '44']
# 190 회차 : [8, 14, 18, 30, 31, 44] 저장 됨
# {191} 회차가 저장됩니다. ['5', '6', '24', '25', '32', '37']
# 191 회차 : [5, 6, 24, 25, 32, 37] 저장 됨
# {192} 회차가 저장됩니다. ['4', '8', '11', '18', '37', '45']
# 192 회차 : [4, 8, 11, 18, 37, 45] 저장 됨
# {193} 회차가 저장됩니다. ['6', '14', '18', '26', '36', '39']
# 193 회차 : [6, 14, 18, 26, 36, 39] 저장 됨
# {194} 회차가 저장됩니다. ['15', '20', '23', '26', '39', '44']
# 194 회차 : [15, 20, 23, 26, 39, 44] 저장 됨
# {195} 회차가 저장됩니다. ['7', '10', '19', '22', '35', '40']
# 195 회차 : [7, 10, 19, 22, 35, 40] 저장 됨
# {196} 회차가 저장됩니다. ['35', '36', '37', '41', '44', '45']
# 196 회차 : [35, 36, 37, 41, 44, 45] 저장 됨
# {197} 회차가 저장됩니다. ['7', '12', '16', '34', '42', '45']
# 197 회차 : [7, 12, 16, 34, 42, 45] 저장 됨
# {198} 회차가 저장됩니다. ['12', '19', '20', '25', '41', '45']
# 198 회차 : [12, 19, 20, 25, 41, 45] 저장 됨
# {199} 회차가 저장됩니다. ['14', '21', '22', '25', '30', '36']
# 199 회차 : [14, 21, 22, 25, 30, 36] 저장 됨
# {200} 회차가 저장됩니다. ['5', '6', '13', '14', '17', '20']
# 200 회차 : [5, 6, 13, 14, 17, 20] 저장 됨
# {201} 회차가 저장됩니다. ['3', '11', '24', '38', '39', '44']
# 201 회차 : [3, 11, 24, 38, 39, 44] 저장 됨
# {202} 회차가 저장됩니다. ['12', '14', '27', '33', '39', '44']
# 202 회차 : [12, 14, 27, 33, 39, 44] 저장 됨
# {203} 회차가 저장됩니다. ['1', '3', '11', '24', '30', '32']
# 203 회차 : [1, 3, 11, 24, 30, 32] 저장 됨
# {204} 회차가 저장됩니다. ['3', '12', '14', '35', '40', '45']
# 204 회차 : [3, 12, 14, 35, 40, 45] 저장 됨
# {205} 회차가 저장됩니다. ['1', '3', '21', '29', '35', '37']
# 205 회차 : [1, 3, 21, 29, 35, 37] 저장 됨
# {206} 회차가 저장됩니다. ['1', '2', '3', '15', '20', '25']
# 206 회차 : [1, 2, 3, 15, 20, 25] 저장 됨
# {207} 회차가 저장됩니다. ['3', '11', '14', '31', '32', '37']
# 207 회차 : [3, 11, 14, 31, 32, 37] 저장 됨
# {208} 회차가 저장됩니다. ['14', '25', '31', '34', '40', '44']
# 208 회차 : [14, 25, 31, 34, 40, 44] 저장 됨
# {209} 회차가 저장됩니다. ['2', '7', '18', '20', '24', '33']
# 209 회차 : [2, 7, 18, 20, 24, 33] 저장 됨
# {210} 회차가 저장됩니다. ['10', '19', '22', '23', '25', '37']
# 210 회차 : [10, 19, 22, 23, 25, 37] 저장 됨
# {211} 회차가 저장됩니다. ['12', '13', '17', '20', '33', '41']
# 211 회차 : [12, 13, 17, 20, 33, 41] 저장 됨
# {212} 회차가 저장됩니다. ['11', '12', '18', '21', '31', '38']
# 212 회차 : [11, 12, 18, 21, 31, 38] 저장 됨
# {213} 회차가 저장됩니다. ['2', '3', '4', '5', '20', '24']
# 213 회차 : [2, 3, 4, 5, 20, 24] 저장 됨
# {214} 회차가 저장됩니다. ['5', '7', '20', '25', '28', '37']
# 214 회차 : [5, 7, 20, 25, 28, 37] 저장 됨
# {215} 회차가 저장됩니다. ['2', '3', '7', '15', '43', '44']
# 215 회차 : [2, 3, 7, 15, 43, 44] 저장 됨
# {216} 회차가 저장됩니다. ['7', '16', '17', '33', '36', '40']
# 216 회차 : [7, 16, 17, 33, 36, 40] 저장 됨
# {217} 회차가 저장됩니다. ['16', '20', '27', '33', '35', '39']
# 217 회차 : [16, 20, 27, 33, 35, 39] 저장 됨
# {218} 회차가 저장됩니다. ['1', '8', '14', '18', '29', '44']
# 218 회차 : [1, 8, 14, 18, 29, 44] 저장 됨
# {219} 회차가 저장됩니다. ['4', '11', '20', '26', '35', '37']
# 219 회차 : [4, 11, 20, 26, 35, 37] 저장 됨
# {220} 회차가 저장됩니다. ['5', '11', '19', '21', '34', '43']
# 220 회차 : [5, 11, 19, 21, 34, 43] 저장 됨
# {221} 회차가 저장됩니다. ['2', '20', '33', '35', '37', '40']
# 221 회차 : [2, 20, 33, 35, 37, 40] 저장 됨
# {222} 회차가 저장됩니다. ['5', '7', '28', '29', '39', '43']
# 222 회차 : [5, 7, 28, 29, 39, 43] 저장 됨
# {223} 회차가 저장됩니다. ['1', '3', '18', '20', '26', '27']
# 223 회차 : [1, 3, 18, 20, 26, 27] 저장 됨
# {224} 회차가 저장됩니다. ['4', '19', '26', '27', '30', '42']
# 224 회차 : [4, 19, 26, 27, 30, 42] 저장 됨
# {225} 회차가 저장됩니다. ['5', '11', '13', '19', '31', '36']
# 225 회차 : [5, 11, 13, 19, 31, 36] 저장 됨
# {226} 회차가 저장됩니다. ['2', '6', '8', '14', '21', '22']
# 226 회차 : [2, 6, 8, 14, 21, 22] 저장 됨
# {227} 회차가 저장됩니다. ['4', '5', '15', '16', '22', '42']
# 227 회차 : [4, 5, 15, 16, 22, 42] 저장 됨
# {228} 회차가 저장됩니다. ['17', '25', '35', '36', '39', '44']
# 228 회차 : [17, 25, 35, 36, 39, 44] 저장 됨
# {229} 회차가 저장됩니다. ['4', '5', '9', '11', '23', '38']
# 229 회차 : [4, 5, 9, 11, 23, 38] 저장 됨
# {230} 회차가 저장됩니다. ['5', '11', '14', '29', '32', '33']
# 230 회차 : [5, 11, 14, 29, 32, 33] 저장 됨
# {231} 회차가 저장됩니다. ['5', '10', '19', '31', '44', '45']
# 231 회차 : [5, 10, 19, 31, 44, 45] 저장 됨
# {232} 회차가 저장됩니다. ['8', '9', '10', '12', '24', '44']
# 232 회차 : [8, 9, 10, 12, 24, 44] 저장 됨
# {233} 회차가 저장됩니다. ['4', '6', '13', '17', '28', '40']
# 233 회차 : [4, 6, 13, 17, 28, 40] 저장 됨
# {234} 회차가 저장됩니다. ['13', '21', '22', '24', '26', '37']
# 234 회차 : [13, 21, 22, 24, 26, 37] 저장 됨
# {235} 회차가 저장됩니다. ['21', '22', '26', '27', '31', '37']
# 235 회차 : [21, 22, 26, 27, 31, 37] 저장 됨
# {236} 회차가 저장됩니다. ['1', '4', '8', '13', '37', '39']
# 236 회차 : [1, 4, 8, 13, 37, 39] 저장 됨
# {237} 회차가 저장됩니다. ['1', '11', '17', '21', '24', '44']
# 237 회차 : [1, 11, 17, 21, 24, 44] 저장 됨
# {238} 회차가 저장됩니다. ['2', '4', '15', '28', '31', '34']
# 238 회차 : [2, 4, 15, 28, 31, 34] 저장 됨
# {239} 회차가 저장됩니다. ['11', '15', '24', '39', '41', '44']
# 239 회차 : [11, 15, 24, 39, 41, 44] 저장 됨
# {240} 회차가 저장됩니다. ['6', '10', '16', '40', '41', '43']
# 240 회차 : [6, 10, 16, 40, 41, 43] 저장 됨
# {241} 회차가 저장됩니다. ['2', '16', '24', '27', '28', '35']
# 241 회차 : [2, 16, 24, 27, 28, 35] 저장 됨
# {242} 회차가 저장됩니다. ['4', '19', '20', '21', '32', '34']
# 242 회차 : [4, 19, 20, 21, 32, 34] 저장 됨
# {243} 회차가 저장됩니다. ['2', '12', '17', '19', '28', '42']
# 243 회차 : [2, 12, 17, 19, 28, 42] 저장 됨
# {244} 회차가 저장됩니다. ['13', '16', '25', '36', '37', '38']
# 244 회차 : [13, 16, 25, 36, 37, 38] 저장 됨
# {245} 회차가 저장됩니다. ['9', '11', '27', '31', '32', '38']
# 245 회차 : [9, 11, 27, 31, 32, 38] 저장 됨
# {246} 회차가 저장됩니다. ['13', '18', '21', '23', '26', '39']
# 246 회차 : [13, 18, 21, 23, 26, 39] 저장 됨
# {247} 회차가 저장됩니다. ['12', '15', '28', '36', '39', '40']
# 247 회차 : [12, 15, 28, 36, 39, 40] 저장 됨
# {248} 회차가 저장됩니다. ['3', '8', '17', '23', '38', '45']
# 248 회차 : [3, 8, 17, 23, 38, 45] 저장 됨
# {249} 회차가 저장됩니다. ['3', '8', '27', '31', '41', '44']
# 249 회차 : [3, 8, 27, 31, 41, 44] 저장 됨
# {250} 회차가 저장됩니다. ['19', '23', '30', '37', '43', '45']
# 250 회차 : [19, 23, 30, 37, 43, 45] 저장 됨
# {251} 회차가 저장됩니다. ['6', '7', '19', '25', '28', '38']
# 251 회차 : [6, 7, 19, 25, 28, 38] 저장 됨
# {252} 회차가 저장됩니다. ['14', '23', '26', '31', '39', '45']
# 252 회차 : [14, 23, 26, 31, 39, 45] 저장 됨
# {253} 회차가 저장됩니다. ['8', '19', '25', '31', '34', '36']
# 253 회차 : [8, 19, 25, 31, 34, 36] 저장 됨
# {254} 회차가 저장됩니다. ['1', '5', '19', '20', '24', '30']
# 254 회차 : [1, 5, 19, 20, 24, 30] 저장 됨
# {255} 회차가 저장됩니다. ['1', '5', '6', '24', '27', '42']
# 255 회차 : [1, 5, 6, 24, 27, 42] 저장 됨
# {256} 회차가 저장됩니다. ['4', '11', '14', '21', '23', '43']
# 256 회차 : [4, 11, 14, 21, 23, 43] 저장 됨
# {257} 회차가 저장됩니다. ['6', '13', '27', '31', '32', '37']
# 257 회차 : [6, 13, 27, 31, 32, 37] 저장 됨
# {258} 회차가 저장됩니다. ['14', '27', '30', '31', '38', '40']
# 258 회차 : [14, 27, 30, 31, 38, 40] 저장 됨
# {259} 회차가 저장됩니다. ['4', '5', '14', '35', '42', '45']
# 259 회차 : [4, 5, 14, 35, 42, 45] 저장 됨
# {260} 회차가 저장됩니다. ['7', '12', '15', '24', '37', '40']
# 260 회차 : [7, 12, 15, 24, 37, 40] 저장 됨
# {261} 회차가 저장됩니다. ['6', '11', '16', '18', '31', '43']
# 261 회차 : [6, 11, 16, 18, 31, 43] 저장 됨
# {262} 회차가 저장됩니다. ['9', '12', '24', '25', '29', '31']
# 262 회차 : [9, 12, 24, 25, 29, 31] 저장 됨
# {263} 회차가 저장됩니다. ['1', '27', '28', '32', '37', '40']
# 263 회차 : [1, 27, 28, 32, 37, 40] 저장 됨
# {264} 회차가 저장됩니다. ['9', '16', '27', '36', '41', '44']
# 264 회차 : [9, 16, 27, 36, 41, 44] 저장 됨
# {265} 회차가 저장됩니다. ['5', '9', '34', '37', '38', '39']
# 265 회차 : [5, 9, 34, 37, 38, 39] 저장 됨
# {266} 회차가 저장됩니다. ['3', '4', '9', '11', '22', '42']
# 266 회차 : [3, 4, 9, 11, 22, 42] 저장 됨
# {267} 회차가 저장됩니다. ['7', '8', '24', '34', '36', '41']
# 267 회차 : [7, 8, 24, 34, 36, 41] 저장 됨
# {268} 회차가 저장됩니다. ['3', '10', '19', '24', '32', '45']
# 268 회차 : [3, 10, 19, 24, 32, 45] 저장 됨
# {269} 회차가 저장됩니다. ['5', '18', '20', '36', '42', '43']
# 269 회차 : [5, 18, 20, 36, 42, 43] 저장 됨
# {270} 회차가 저장됩니다. ['5', '9', '12', '20', '21', '26']
# 270 회차 : [5, 9, 12, 20, 21, 26] 저장 됨
# {271} 회차가 저장됩니다. ['3', '8', '9', '27', '29', '40']
# 271 회차 : [3, 8, 9, 27, 29, 40] 저장 됨
# {272} 회차가 저장됩니다. ['7', '9', '12', '27', '39', '43']
# 272 회차 : [7, 9, 12, 27, 39, 43] 저장 됨
# {273} 회차가 저장됩니다. ['1', '8', '24', '31', '34', '44']
# 273 회차 : [1, 8, 24, 31, 34, 44] 저장 됨
# {274} 회차가 저장됩니다. ['13', '14', '15', '26', '35', '39']
# 274 회차 : [13, 14, 15, 26, 35, 39] 저장 됨
# {275} 회차가 저장됩니다. ['14', '19', '20', '35', '38', '40']
# 275 회차 : [14, 19, 20, 35, 38, 40] 저장 됨
# {276} 회차가 저장됩니다. ['4', '15', '21', '33', '39', '41']
# 276 회차 : [4, 15, 21, 33, 39, 41] 저장 됨
# {277} 회차가 저장됩니다. ['10', '12', '13', '15', '25', '29']
# 277 회차 : [10, 12, 13, 15, 25, 29] 저장 됨
# {278} 회차가 저장됩니다. ['3', '11', '37', '39', '41', '43']
# 278 회차 : [3, 11, 37, 39, 41, 43] 저장 됨
# {279} 회차가 저장됩니다. ['7', '16', '31', '36', '37', '38']
# 279 회차 : [7, 16, 31, 36, 37, 38] 저장 됨
# {280} 회차가 저장됩니다. ['10', '11', '23', '24', '36', '37']
# 280 회차 : [10, 11, 23, 24, 36, 37] 저장 됨
# {281} 회차가 저장됩니다. ['1', '3', '4', '6', '14', '41']
# 281 회차 : [1, 3, 4, 6, 14, 41] 저장 됨
# {282} 회차가 저장됩니다. ['2', '5', '10', '18', '31', '32']
# 282 회차 : [2, 5, 10, 18, 31, 32] 저장 됨
# {283} 회차가 저장됩니다. ['6', '8', '18', '31', '38', '45']
# 283 회차 : [6, 8, 18, 31, 38, 45] 저장 됨
# {284} 회차가 저장됩니다. ['2', '7', '15', '24', '30', '45']
# 284 회차 : [2, 7, 15, 24, 30, 45] 저장 됨
# {285} 회차가 저장됩니다. ['13', '33', '37', '40', '41', '45']
# 285 회차 : [13, 33, 37, 40, 41, 45] 저장 됨
# {286} 회차가 저장됩니다. ['1', '15', '19', '40', '42', '44']
# 286 회차 : [1, 15, 19, 40, 42, 44] 저장 됨
# {287} 회차가 저장됩니다. ['6', '12', '24', '27', '35', '37']
# 287 회차 : [6, 12, 24, 27, 35, 37] 저장 됨
# {288} 회차가 저장됩니다. ['1', '12', '17', '28', '35', '41']
# 288 회차 : [1, 12, 17, 28, 35, 41] 저장 됨
# {289} 회차가 저장됩니다. ['3', '14', '33', '37', '38', '42']
# 289 회차 : [3, 14, 33, 37, 38, 42] 저장 됨
# {290} 회차가 저장됩니다. ['8', '13', '18', '32', '39', '45']
# 290 회차 : [8, 13, 18, 32, 39, 45] 저장 됨
# {291} 회차가 저장됩니다. ['3', '7', '8', '18', '20', '42']
# 291 회차 : [3, 7, 8, 18, 20, 42] 저장 됨
# {292} 회차가 저장됩니다. ['17', '18', '31', '32', '33', '34']
# 292 회차 : [17, 18, 31, 32, 33, 34] 저장 됨
# {293} 회차가 저장됩니다. ['1', '9', '17', '21', '29', '33']
# 293 회차 : [1, 9, 17, 21, 29, 33] 저장 됨
# {294} 회차가 저장됩니다. ['6', '10', '17', '30', '37', '38']
# 294 회차 : [6, 10, 17, 30, 37, 38] 저장 됨
# {295} 회차가 저장됩니다. ['1', '4', '12', '16', '18', '38']
# 295 회차 : [1, 4, 12, 16, 18, 38] 저장 됨
# {296} 회차가 저장됩니다. ['3', '8', '15', '27', '30', '45']
# 296 회차 : [3, 8, 15, 27, 30, 45] 저장 됨
# {297} 회차가 저장됩니다. ['6', '11', '19', '20', '28', '32']
# 297 회차 : [6, 11, 19, 20, 28, 32] 저장 됨
# {298} 회차가 저장됩니다. ['5', '9', '27', '29', '37', '40']
# 298 회차 : [5, 9, 27, 29, 37, 40] 저장 됨
# {299} 회차가 저장됩니다. ['1', '3', '20', '25', '36', '45']
# 299 회차 : [1, 3, 20, 25, 36, 45] 저장 됨
# {300} 회차가 저장됩니다. ['7', '9', '10', '12', '26', '38']
# 300 회차 : [7, 9, 10, 12, 26, 38] 저장 됨
# {301} 회차가 저장됩니다. ['7', '11', '13', '33', '37', '43']
# 301 회차 : [7, 11, 13, 33, 37, 43] 저장 됨
# {302} 회차가 저장됩니다. ['13', '19', '20', '32', '38', '42']
# 302 회차 : [13, 19, 20, 32, 38, 42] 저장 됨
# {303} 회차가 저장됩니다. ['2', '14', '17', '30', '38', '45']
# 303 회차 : [2, 14, 17, 30, 38, 45] 저장 됨
# {304} 회차가 저장됩니다. ['4', '10', '16', '26', '33', '41']
# 304 회차 : [4, 10, 16, 26, 33, 41] 저장 됨
# {305} 회차가 저장됩니다. ['7', '8', '18', '21', '23', '39']
# 305 회차 : [7, 8, 18, 21, 23, 39] 저장 됨
# {306} 회차가 저장됩니다. ['4', '18', '23', '30', '34', '41']
# 306 회차 : [4, 18, 23, 30, 34, 41] 저장 됨
# {307} 회차가 저장됩니다. ['5', '15', '21', '23', '25', '45']
# 307 회차 : [5, 15, 21, 23, 25, 45] 저장 됨
# {308} 회차가 저장됩니다. ['14', '15', '17', '19', '37', '45']
# 308 회차 : [14, 15, 17, 19, 37, 45] 저장 됨
# {309} 회차가 저장됩니다. ['1', '2', '5', '11', '18', '36']
# 309 회차 : [1, 2, 5, 11, 18, 36] 저장 됨
# {310} 회차가 저장됩니다. ['1', '5', '19', '28', '34', '41']
# 310 회차 : [1, 5, 19, 28, 34, 41] 저장 됨
# {311} 회차가 저장됩니다. ['4', '12', '24', '27', '28', '32']
# 311 회차 : [4, 12, 24, 27, 28, 32] 저장 됨
# {312} 회차가 저장됩니다. ['2', '3', '5', '6', '12', '20']
# 312 회차 : [2, 3, 5, 6, 12, 20] 저장 됨
# {313} 회차가 저장됩니다. ['9', '17', '34', '35', '43', '45']
# 313 회차 : [9, 17, 34, 35, 43, 45] 저장 됨
# {314} 회차가 저장됩니다. ['15', '17', '19', '34', '38', '41']
# 314 회차 : [15, 17, 19, 34, 38, 41] 저장 됨
# {315} 회차가 저장됩니다. ['1', '13', '33', '35', '43', '45']
# 315 회차 : [1, 13, 33, 35, 43, 45] 저장 됨
# {316} 회차가 저장됩니다. ['10', '11', '21', '27', '31', '39']
# 316 회차 : [10, 11, 21, 27, 31, 39] 저장 됨
# {317} 회차가 저장됩니다. ['3', '10', '11', '22', '36', '39']
# 317 회차 : [3, 10, 11, 22, 36, 39] 저장 됨
# {318} 회차가 저장됩니다. ['2', '17', '19', '20', '34', '45']
# 318 회차 : [2, 17, 19, 20, 34, 45] 저장 됨
# {319} 회차가 저장됩니다. ['5', '8', '22', '28', '33', '42']
# 319 회차 : [5, 8, 22, 28, 33, 42] 저장 됨
# {320} 회차가 저장됩니다. ['16', '19', '23', '25', '41', '45']
# 320 회차 : [16, 19, 23, 25, 41, 45] 저장 됨
# {321} 회차가 저장됩니다. ['12', '18', '20', '21', '25', '34']
# 321 회차 : [12, 18, 20, 21, 25, 34] 저장 됨
# {322} 회차가 저장됩니다. ['9', '18', '29', '32', '38', '43']
# 322 회차 : [9, 18, 29, 32, 38, 43] 저장 됨
# {323} 회차가 저장됩니다. ['10', '14', '15', '32', '36', '42']
# 323 회차 : [10, 14, 15, 32, 36, 42] 저장 됨
# {324} 회차가 저장됩니다. ['2', '4', '21', '25', '33', '36']
# 324 회차 : [2, 4, 21, 25, 33, 36] 저장 됨
# {325} 회차가 저장됩니다. ['7', '17', '20', '32', '44', '45']
# 325 회차 : [7, 17, 20, 32, 44, 45] 저장 됨
# {326} 회차가 저장됩니다. ['16', '23', '25', '33', '36', '39']
# 326 회차 : [16, 23, 25, 33, 36, 39] 저장 됨
# {327} 회차가 저장됩니다. ['6', '12', '13', '17', '32', '44']
# 327 회차 : [6, 12, 13, 17, 32, 44] 저장 됨
# {328} 회차가 저장됩니다. ['1', '6', '9', '16', '17', '28']
# 328 회차 : [1, 6, 9, 16, 17, 28] 저장 됨
# {329} 회차가 저장됩니다. ['9', '17', '19', '30', '35', '42']
# 329 회차 : [9, 17, 19, 30, 35, 42] 저장 됨
# {330} 회차가 저장됩니다. ['3', '4', '16', '17', '19', '20']
# 330 회차 : [3, 4, 16, 17, 19, 20] 저장 됨
# {331} 회차가 저장됩니다. ['4', '9', '14', '26', '31', '44']
# 331 회차 : [4, 9, 14, 26, 31, 44] 저장 됨
# {332} 회차가 저장됩니다. ['16', '17', '34', '36', '42', '45']
# 332 회차 : [16, 17, 34, 36, 42, 45] 저장 됨
# {333} 회차가 저장됩니다. ['5', '14', '27', '30', '39', '43']
# 333 회차 : [5, 14, 27, 30, 39, 43] 저장 됨
# {334} 회차가 저장됩니다. ['13', '15', '21', '29', '39', '43']
# 334 회차 : [13, 15, 21, 29, 39, 43] 저장 됨
# {335} 회차가 저장됩니다. ['5', '9', '16', '23', '26', '45']
# 335 회차 : [5, 9, 16, 23, 26, 45] 저장 됨
# {336} 회차가 저장됩니다. ['3', '5', '20', '34', '35', '44']
# 336 회차 : [3, 5, 20, 34, 35, 44] 저장 됨
# {337} 회차가 저장됩니다. ['1', '5', '14', '18', '32', '37']
# 337 회차 : [1, 5, 14, 18, 32, 37] 저장 됨
# {338} 회차가 저장됩니다. ['2', '13', '34', '38', '42', '45']
# 338 회차 : [2, 13, 34, 38, 42, 45] 저장 됨
# {339} 회차가 저장됩니다. ['6', '8', '14', '21', '30', '37']
# 339 회차 : [6, 8, 14, 21, 30, 37] 저장 됨
# {340} 회차가 저장됩니다. ['18', '24', '26', '29', '34', '38']
# 340 회차 : [18, 24, 26, 29, 34, 38] 저장 됨
# {341} 회차가 저장됩니다. ['1', '8', '19', '34', '39', '43']
# 341 회차 : [1, 8, 19, 34, 39, 43] 저장 됨
# {342} 회차가 저장됩니다. ['1', '13', '14', '33', '34', '43']
# 342 회차 : [1, 13, 14, 33, 34, 43] 저장 됨
# {343} 회차가 저장됩니다. ['1', '10', '17', '29', '31', '43']
# 343 회차 : [1, 10, 17, 29, 31, 43] 저장 됨
# {344} 회차가 저장됩니다. ['1', '2', '15', '28', '34', '45']
# 344 회차 : [1, 2, 15, 28, 34, 45] 저장 됨
# {345} 회차가 저장됩니다. ['15', '20', '23', '29', '39', '42']
# 345 회차 : [15, 20, 23, 29, 39, 42] 저장 됨
# {346} 회차가 저장됩니다. ['5', '13', '14', '22', '44', '45']
# 346 회차 : [5, 13, 14, 22, 44, 45] 저장 됨
# {347} 회차가 저장됩니다. ['3', '8', '13', '27', '32', '42']
# 347 회차 : [3, 8, 13, 27, 32, 42] 저장 됨
# {348} 회차가 저장됩니다. ['3', '14', '17', '20', '24', '31']
# 348 회차 : [3, 14, 17, 20, 24, 31] 저장 됨
# {349} 회차가 저장됩니다. ['5', '13', '14', '20', '24', '25']
# 349 회차 : [5, 13, 14, 20, 24, 25] 저장 됨
# {350} 회차가 저장됩니다. ['1', '8', '18', '24', '29', '33']
# 350 회차 : [1, 8, 18, 24, 29, 33] 저장 됨
# {351} 회차가 저장됩니다. ['5', '25', '27', '29', '34', '36']
# 351 회차 : [5, 25, 27, 29, 34, 36] 저장 됨
# {352} 회차가 저장됩니다. ['5', '16', '17', '20', '26', '41']
# 352 회차 : [5, 16, 17, 20, 26, 41] 저장 됨
# {353} 회차가 저장됩니다. ['11', '16', '19', '22', '29', '36']
# 353 회차 : [11, 16, 19, 22, 29, 36] 저장 됨
# {354} 회차가 저장됩니다. ['14', '19', '36', '43', '44', '45']
# 354 회차 : [14, 19, 36, 43, 44, 45] 저장 됨
# {355} 회차가 저장됩니다. ['5', '8', '29', '30', '35', '44']
# 355 회차 : [5, 8, 29, 30, 35, 44] 저장 됨
# {356} 회차가 저장됩니다. ['2', '8', '14', '25', '29', '45']
# 356 회차 : [2, 8, 14, 25, 29, 45] 저장 됨
# {357} 회차가 저장됩니다. ['10', '14', '18', '21', '36', '37']
# 357 회차 : [10, 14, 18, 21, 36, 37] 저장 됨
# {358} 회차가 저장됩니다. ['1', '9', '10', '12', '21', '40']
# 358 회차 : [1, 9, 10, 12, 21, 40] 저장 됨
# {359} 회차가 저장됩니다. ['1', '10', '19', '20', '24', '40']
# 359 회차 : [1, 10, 19, 20, 24, 40] 저장 됨
# {360} 회차가 저장됩니다. ['4', '16', '23', '25', '35', '40']
# 360 회차 : [4, 16, 23, 25, 35, 40] 저장 됨
# {361} 회차가 저장됩니다. ['5', '10', '16', '24', '27', '35']
# 361 회차 : [5, 10, 16, 24, 27, 35] 저장 됨
# {362} 회차가 저장됩니다. ['2', '3', '22', '27', '30', '40']
# 362 회차 : [2, 3, 22, 27, 30, 40] 저장 됨
# {363} 회차가 저장됩니다. ['11', '12', '14', '21', '32', '38']
# 363 회차 : [11, 12, 14, 21, 32, 38] 저장 됨
# {364} 회차가 저장됩니다. ['2', '5', '7', '14', '16', '40']
# 364 회차 : [2, 5, 7, 14, 16, 40] 저장 됨
# {365} 회차가 저장됩니다. ['5', '15', '21', '25', '26', '30']
# 365 회차 : [5, 15, 21, 25, 26, 30] 저장 됨
# {366} 회차가 저장됩니다. ['5', '12', '19', '26', '27', '44']
# 366 회차 : [5, 12, 19, 26, 27, 44] 저장 됨
# {367} 회차가 저장됩니다. ['3', '22', '25', '29', '32', '44']
# 367 회차 : [3, 22, 25, 29, 32, 44] 저장 됨
# {368} 회차가 저장됩니다. ['11', '21', '24', '30', '39', '45']
# 368 회차 : [11, 21, 24, 30, 39, 45] 저장 됨
# {369} 회차가 저장됩니다. ['17', '20', '35', '36', '41', '43']
# 369 회차 : [17, 20, 35, 36, 41, 43] 저장 됨
# {370} 회차가 저장됩니다. ['16', '18', '24', '42', '44', '45']
# 370 회차 : [16, 18, 24, 42, 44, 45] 저장 됨
# {371} 회차가 저장됩니다. ['7', '9', '15', '26', '27', '42']
# 371 회차 : [7, 9, 15, 26, 27, 42] 저장 됨
# {372} 회차가 저장됩니다. ['8', '11', '14', '16', '18', '21']
# 372 회차 : [8, 11, 14, 16, 18, 21] 저장 됨
# {373} 회차가 저장됩니다. ['15', '26', '37', '42', '43', '45']
# 373 회차 : [15, 26, 37, 42, 43, 45] 저장 됨
# {374} 회차가 저장됩니다. ['11', '13', '15', '17', '25', '34']
# 374 회차 : [11, 13, 15, 17, 25, 34] 저장 됨
# {375} 회차가 저장됩니다. ['4', '8', '19', '25', '27', '45']
# 375 회차 : [4, 8, 19, 25, 27, 45] 저장 됨
# {376} 회차가 저장됩니다. ['1', '11', '13', '24', '28', '40']
# 376 회차 : [1, 11, 13, 24, 28, 40] 저장 됨
# {377} 회차가 저장됩니다. ['6', '22', '29', '37', '43', '45']
# 377 회차 : [6, 22, 29, 37, 43, 45] 저장 됨
# {378} 회차가 저장됩니다. ['5', '22', '29', '31', '34', '39']
# 378 회차 : [5, 22, 29, 31, 34, 39] 저장 됨
# {379} 회차가 저장됩니다. ['6', '10', '22', '31', '35', '40']
# 379 회차 : [6, 10, 22, 31, 35, 40] 저장 됨
# {380} 회차가 저장됩니다. ['1', '2', '8', '17', '26', '37']
# 380 회차 : [1, 2, 8, 17, 26, 37] 저장 됨
# {381} 회차가 저장됩니다. ['1', '5', '10', '12', '16', '20']
# 381 회차 : [1, 5, 10, 12, 16, 20] 저장 됨
# {382} 회차가 저장됩니다. ['10', '15', '22', '24', '27', '42']
# 382 회차 : [10, 15, 22, 24, 27, 42] 저장 됨
# {383} 회차가 저장됩니다. ['4', '15', '28', '33', '37', '40']
# 383 회차 : [4, 15, 28, 33, 37, 40] 저장 됨
# {384} 회차가 저장됩니다. ['11', '22', '24', '32', '36', '38']
# 384 회차 : [11, 22, 24, 32, 36, 38] 저장 됨
# {385} 회차가 저장됩니다. ['7', '12', '19', '21', '29', '32']
# 385 회차 : [7, 12, 19, 21, 29, 32] 저장 됨
# {386} 회차가 저장됩니다. ['4', '7', '10', '19', '31', '40']
# 386 회차 : [4, 7, 10, 19, 31, 40] 저장 됨
# {387} 회차가 저장됩니다. ['1', '26', '31', '34', '40', '43']
# 387 회차 : [1, 26, 31, 34, 40, 43] 저장 됨
# {388} 회차가 저장됩니다. ['1', '8', '9', '17', '29', '32']
# 388 회차 : [1, 8, 9, 17, 29, 32] 저장 됨
# {389} 회차가 저장됩니다. ['7', '16', '18', '20', '23', '26']
# 389 회차 : [7, 16, 18, 20, 23, 26] 저장 됨
# {390} 회차가 저장됩니다. ['16', '17', '28', '37', '39', '40']
# 390 회차 : [16, 17, 28, 37, 39, 40] 저장 됨
# {391} 회차가 저장됩니다. ['10', '11', '18', '22', '28', '39']
# 391 회차 : [10, 11, 18, 22, 28, 39] 저장 됨
# {392} 회차가 저장됩니다. ['1', '3', '7', '8', '24', '42']
# 392 회차 : [1, 3, 7, 8, 24, 42] 저장 됨
# {393} 회차가 저장됩니다. ['9', '16', '28', '40', '41', '43']
# 393 회차 : [9, 16, 28, 40, 41, 43] 저장 됨
# {394} 회차가 저장됩니다. ['1', '13', '20', '22', '25', '28']
# 394 회차 : [1, 13, 20, 22, 25, 28] 저장 됨
# {395} 회차가 저장됩니다. ['11', '15', '20', '26', '31', '35']
# 395 회차 : [11, 15, 20, 26, 31, 35] 저장 됨
# {396} 회차가 저장됩니다. ['18', '20', '31', '34', '40', '45']
# 396 회차 : [18, 20, 31, 34, 40, 45] 저장 됨
# {397} 회차가 저장됩니다. ['12', '13', '17', '22', '25', '33']
# 397 회차 : [12, 13, 17, 22, 25, 33] 저장 됨
# {398} 회차가 저장됩니다. ['10', '15', '20', '23', '42', '44']
# 398 회차 : [10, 15, 20, 23, 42, 44] 저장 됨
# {399} 회차가 저장됩니다. ['1', '2', '9', '17', '19', '42']
# 399 회차 : [1, 2, 9, 17, 19, 42] 저장 됨
# {400} 회차가 저장됩니다. ['9', '21', '27', '34', '41', '43']
# 400 회차 : [9, 21, 27, 34, 41, 43] 저장 됨
# {401} 회차가 저장됩니다. ['6', '12', '18', '31', '38', '43']
# 401 회차 : [6, 12, 18, 31, 38, 43] 저장 됨
# {402} 회차가 저장됩니다. ['5', '9', '15', '19', '22', '36']
# 402 회차 : [5, 9, 15, 19, 22, 36] 저장 됨
# {403} 회차가 저장됩니다. ['10', '14', '22', '24', '28', '37']
# 403 회차 : [10, 14, 22, 24, 28, 37] 저장 됨
# {404} 회차가 저장됩니다. ['5', '20', '21', '24', '33', '40']
# 404 회차 : [5, 20, 21, 24, 33, 40] 저장 됨
# {405} 회차가 저장됩니다. ['1', '2', '10', '25', '26', '44']
# 405 회차 : [1, 2, 10, 25, 26, 44] 저장 됨
# {406} 회차가 저장됩니다. ['7', '12', '21', '24', '27', '36']
# 406 회차 : [7, 12, 21, 24, 27, 36] 저장 됨
# {407} 회차가 저장됩니다. ['6', '7', '13', '16', '24', '25']
# 407 회차 : [6, 7, 13, 16, 24, 25] 저장 됨
# {408} 회차가 저장됩니다. ['9', '20', '21', '22', '30', '37']
# 408 회차 : [9, 20, 21, 22, 30, 37] 저장 됨
# {409} 회차가 저장됩니다. ['6', '9', '21', '31', '32', '40']
# 409 회차 : [6, 9, 21, 31, 32, 40] 저장 됨
# {410} 회차가 저장됩니다. ['1', '3', '18', '32', '40', '41']
# 410 회차 : [1, 3, 18, 32, 40, 41] 저장 됨
# {411} 회차가 저장됩니다. ['11', '14', '22', '35', '37', '39']
# 411 회차 : [11, 14, 22, 35, 37, 39] 저장 됨
# {412} 회차가 저장됩니다. ['4', '7', '39', '41', '42', '45']
# 412 회차 : [4, 7, 39, 41, 42, 45] 저장 됨
# {413} 회차가 저장됩니다. ['2', '9', '15', '23', '34', '40']
# 413 회차 : [2, 9, 15, 23, 34, 40] 저장 됨
# {414} 회차가 저장됩니다. ['2', '14', '15', '22', '23', '44']
# 414 회차 : [2, 14, 15, 22, 23, 44] 저장 됨
# {415} 회차가 저장됩니다. ['7', '17', '20', '26', '30', '40']
# 415 회차 : [7, 17, 20, 26, 30, 40] 저장 됨
# {416} 회차가 저장됩니다. ['5', '6', '8', '11', '22', '26']
# 416 회차 : [5, 6, 8, 11, 22, 26] 저장 됨
# {417} 회차가 저장됩니다. ['4', '5', '14', '20', '22', '43']
# 417 회차 : [4, 5, 14, 20, 22, 43] 저장 됨
# {418} 회차가 저장됩니다. ['11', '13', '15', '26', '28', '34']
# 418 회차 : [11, 13, 15, 26, 28, 34] 저장 됨
# {419} 회차가 저장됩니다. ['2', '11', '13', '14', '28', '30']
# 419 회차 : [2, 11, 13, 14, 28, 30] 저장 됨
# {420} 회차가 저장됩니다. ['4', '9', '10', '29', '31', '34']
# 420 회차 : [4, 9, 10, 29, 31, 34] 저장 됨
# {421} 회차가 저장됩니다. ['6', '11', '26', '27', '28', '44']
# 421 회차 : [6, 11, 26, 27, 28, 44] 저장 됨
# {422} 회차가 저장됩니다. ['8', '15', '19', '21', '34', '44']
# 422 회차 : [8, 15, 19, 21, 34, 44] 저장 됨
# {423} 회차가 저장됩니다. ['1', '17', '27', '28', '29', '40']
# 423 회차 : [1, 17, 27, 28, 29, 40] 저장 됨
# {424} 회차가 저장됩니다. ['10', '11', '26', '31', '34', '44']
# 424 회차 : [10, 11, 26, 31, 34, 44] 저장 됨
# {425} 회차가 저장됩니다. ['8', '10', '14', '27', '33', '38']
# 425 회차 : [8, 10, 14, 27, 33, 38] 저장 됨
# {426} 회차가 저장됩니다. ['4', '17', '18', '27', '39', '43']
# 426 회차 : [4, 17, 18, 27, 39, 43] 저장 됨
# {427} 회차가 저장됩니다. ['6', '7', '15', '24', '28', '30']
# 427 회차 : [6, 7, 15, 24, 28, 30] 저장 됨
# {428} 회차가 저장됩니다. ['12', '16', '19', '22', '37', '40']
# 428 회차 : [12, 16, 19, 22, 37, 40] 저장 됨
# {429} 회차가 저장됩니다. ['3', '23', '28', '34', '39', '42']
# 429 회차 : [3, 23, 28, 34, 39, 42] 저장 됨
# {430} 회차가 저장됩니다. ['1', '3', '16', '18', '30', '34']
# 430 회차 : [1, 3, 16, 18, 30, 34] 저장 됨
# {431} 회차가 저장됩니다. ['18', '22', '25', '31', '38', '45']
# 431 회차 : [18, 22, 25, 31, 38, 45] 저장 됨
# {432} 회차가 저장됩니다. ['2', '3', '5', '11', '27', '39']
# 432 회차 : [2, 3, 5, 11, 27, 39] 저장 됨
# {433} 회차가 저장됩니다. ['19', '23', '29', '33', '35', '43']
# 433 회차 : [19, 23, 29, 33, 35, 43] 저장 됨
# {434} 회차가 저장됩니다. ['3', '13', '20', '24', '33', '37']
# 434 회차 : [3, 13, 20, 24, 33, 37] 저장 됨
# {435} 회차가 저장됩니다. ['8', '16', '26', '30', '38', '45']
# 435 회차 : [8, 16, 26, 30, 38, 45] 저장 됨
# {436} 회차가 저장됩니다. ['9', '14', '20', '22', '33', '34']
# 436 회차 : [9, 14, 20, 22, 33, 34] 저장 됨
# {437} 회차가 저장됩니다. ['11', '16', '29', '38', '41', '44']
# 437 회차 : [11, 16, 29, 38, 41, 44] 저장 됨
# {438} 회차가 저장됩니다. ['6', '12', '20', '26', '29', '38']
# 438 회차 : [6, 12, 20, 26, 29, 38] 저장 됨
# {439} 회차가 저장됩니다. ['17', '20', '30', '31', '37', '40']
# 439 회차 : [17, 20, 30, 31, 37, 40] 저장 됨
# {440} 회차가 저장됩니다. ['10', '22', '28', '34', '36', '44']
# 440 회차 : [10, 22, 28, 34, 36, 44] 저장 됨
# {441} 회차가 저장됩니다. ['1', '23', '28', '30', '34', '35']
# 441 회차 : [1, 23, 28, 30, 34, 35] 저장 됨
# {442} 회차가 저장됩니다. ['25', '27', '29', '36', '38', '40']
# 442 회차 : [25, 27, 29, 36, 38, 40] 저장 됨
# {443} 회차가 저장됩니다. ['4', '6', '10', '19', '20', '44']
# 443 회차 : [4, 6, 10, 19, 20, 44] 저장 됨
# {444} 회차가 저장됩니다. ['11', '13', '23', '35', '43', '45']
# 444 회차 : [11, 13, 23, 35, 43, 45] 저장 됨
# {445} 회차가 저장됩니다. ['13', '20', '21', '30', '39', '45']
# 445 회차 : [13, 20, 21, 30, 39, 45] 저장 됨
# {446} 회차가 저장됩니다. ['1', '11', '12', '14', '26', '35']
# 446 회차 : [1, 11, 12, 14, 26, 35] 저장 됨
# {447} 회차가 저장됩니다. ['2', '7', '8', '9', '17', '33']
# 447 회차 : [2, 7, 8, 9, 17, 33] 저장 됨
# {448} 회차가 저장됩니다. ['3', '7', '13', '27', '40', '41']
# 448 회차 : [3, 7, 13, 27, 40, 41] 저장 됨
# {449} 회차가 저장됩니다. ['3', '10', '20', '26', '35', '43']
# 449 회차 : [3, 10, 20, 26, 35, 43] 저장 됨
# {450} 회차가 저장됩니다. ['6', '14', '19', '21', '23', '31']
# 450 회차 : [6, 14, 19, 21, 23, 31] 저장 됨
# {451} 회차가 저장됩니다. ['12', '15', '20', '24', '30', '38']
# 451 회차 : [12, 15, 20, 24, 30, 38] 저장 됨
# {452} 회차가 저장됩니다. ['8', '10', '18', '30', '32', '34']
# 452 회차 : [8, 10, 18, 30, 32, 34] 저장 됨
# {453} 회차가 저장됩니다. ['12', '24', '33', '38', '40', '42']
# 453 회차 : [12, 24, 33, 38, 40, 42] 저장 됨
# {454} 회차가 저장됩니다. ['13', '25', '27', '34', '38', '41']
# 454 회차 : [13, 25, 27, 34, 38, 41] 저장 됨
# {455} 회차가 저장됩니다. ['4', '19', '20', '26', '30', '35']
# 455 회차 : [4, 19, 20, 26, 30, 35] 저장 됨
# {456} 회차가 저장됩니다. ['1', '7', '12', '18', '23', '27']
# 456 회차 : [1, 7, 12, 18, 23, 27] 저장 됨
# {457} 회차가 저장됩니다. ['8', '10', '18', '23', '27', '40']
# 457 회차 : [8, 10, 18, 23, 27, 40] 저장 됨
# {458} 회차가 저장됩니다. ['4', '9', '10', '32', '36', '40']
# 458 회차 : [4, 9, 10, 32, 36, 40] 저장 됨
# {459} 회차가 저장됩니다. ['4', '6', '10', '14', '25', '40']
# 459 회차 : [4, 6, 10, 14, 25, 40] 저장 됨
# {460} 회차가 저장됩니다. ['8', '11', '28', '30', '43', '45']
# 460 회차 : [8, 11, 28, 30, 43, 45] 저장 됨
# {461} 회차가 저장됩니다. ['11', '18', '26', '31', '37', '40']
# 461 회차 : [11, 18, 26, 31, 37, 40] 저장 됨
# {462} 회차가 저장됩니다. ['3', '20', '24', '32', '37', '45']
# 462 회차 : [3, 20, 24, 32, 37, 45] 저장 됨
# {463} 회차가 저장됩니다. ['23', '29', '31', '33', '34', '44']
# 463 회차 : [23, 29, 31, 33, 34, 44] 저장 됨
# {464} 회차가 저장됩니다. ['6', '12', '15', '34', '42', '44']
# 464 회차 : [6, 12, 15, 34, 42, 44] 저장 됨
# {465} 회차가 저장됩니다. ['1', '8', '11', '13', '22', '38']
# 465 회차 : [1, 8, 11, 13, 22, 38] 저장 됨
# {466} 회차가 저장됩니다. ['4', '10', '13', '23', '32', '44']
# 466 회차 : [4, 10, 13, 23, 32, 44] 저장 됨
# {467} 회차가 저장됩니다. ['2', '12', '14', '17', '24', '40']
# 467 회차 : [2, 12, 14, 17, 24, 40] 저장 됨
# {468} 회차가 저장됩니다. ['8', '13', '15', '28', '37', '43']
# 468 회차 : [8, 13, 15, 28, 37, 43] 저장 됨
# {469} 회차가 저장됩니다. ['4', '21', '22', '34', '37', '38']
# 469 회차 : [4, 21, 22, 34, 37, 38] 저장 됨
# {470} 회차가 저장됩니다. ['10', '16', '20', '39', '41', '42']
# 470 회차 : [10, 16, 20, 39, 41, 42] 저장 됨
# {471} 회차가 저장됩니다. ['6', '13', '29', '37', '39', '41']
# 471 회차 : [6, 13, 29, 37, 39, 41] 저장 됨
# {472} 회차가 저장됩니다. ['16', '25', '26', '31', '36', '43']
# 472 회차 : [16, 25, 26, 31, 36, 43] 저장 됨
# {473} 회차가 저장됩니다. ['8', '13', '20', '22', '23', '36']
# 473 회차 : [8, 13, 20, 22, 23, 36] 저장 됨
# {474} 회차가 저장됩니다. ['4', '13', '18', '31', '33', '45']
# 474 회차 : [4, 13, 18, 31, 33, 45] 저장 됨
# {475} 회차가 저장됩니다. ['1', '9', '14', '16', '21', '29']
# 475 회차 : [1, 9, 14, 16, 21, 29] 저장 됨
# {476} 회차가 저장됩니다. ['9', '12', '13', '15', '37', '38']
# 476 회차 : [9, 12, 13, 15, 37, 38] 저장 됨
# {477} 회차가 저장됩니다. ['14', '25', '29', '32', '33', '45']
# 477 회차 : [14, 25, 29, 32, 33, 45] 저장 됨
# {478} 회차가 저장됩니다. ['18', '29', '30', '37', '39', '43']
# 478 회차 : [18, 29, 30, 37, 39, 43] 저장 됨
# {479} 회차가 저장됩니다. ['8', '23', '25', '27', '35', '44']
# 479 회차 : [8, 23, 25, 27, 35, 44] 저장 됨
# {480} 회차가 저장됩니다. ['3', '5', '10', '17', '30', '31']
# 480 회차 : [3, 5, 10, 17, 30, 31] 저장 됨
# {481} 회차가 저장됩니다. ['3', '4', '23', '29', '40', '41']
# 481 회차 : [3, 4, 23, 29, 40, 41] 저장 됨
# {482} 회차가 저장됩니다. ['1', '10', '16', '24', '25', '35']
# 482 회차 : [1, 10, 16, 24, 25, 35] 저장 됨
# {483} 회차가 저장됩니다. ['12', '15', '19', '22', '28', '34']
# 483 회차 : [12, 15, 19, 22, 28, 34] 저장 됨
# {484} 회차가 저장됩니다. ['1', '3', '27', '28', '32', '45']
# 484 회차 : [1, 3, 27, 28, 32, 45] 저장 됨
# {485} 회차가 저장됩니다. ['17', '22', '26', '27', '36', '39']
# 485 회차 : [17, 22, 26, 27, 36, 39] 저장 됨
# {486} 회차가 저장됩니다. ['1', '2', '23', '25', '38', '40']
# 486 회차 : [1, 2, 23, 25, 38, 40] 저장 됨
# {487} 회차가 저장됩니다. ['4', '8', '25', '27', '37', '41']
# 487 회차 : [4, 8, 25, 27, 37, 41] 저장 됨
# {488} 회차가 저장됩니다. ['2', '8', '17', '30', '31', '38']
# 488 회차 : [2, 8, 17, 30, 31, 38] 저장 됨
# {489} 회차가 저장됩니다. ['2', '4', '8', '15', '20', '27']
# 489 회차 : [2, 4, 8, 15, 20, 27] 저장 됨
# {490} 회차가 저장됩니다. ['2', '7', '26', '29', '40', '43']
# 490 회차 : [2, 7, 26, 29, 40, 43] 저장 됨
# {491} 회차가 저장됩니다. ['8', '17', '35', '36', '39', '42']
# 491 회차 : [8, 17, 35, 36, 39, 42] 저장 됨
# {492} 회차가 저장됩니다. ['22', '27', '31', '35', '37', '40']
# 492 회차 : [22, 27, 31, 35, 37, 40] 저장 됨
# {493} 회차가 저장됩니다. ['20', '22', '26', '33', '36', '37']
# 493 회차 : [20, 22, 26, 33, 36, 37] 저장 됨
# {494} 회차가 저장됩니다. ['5', '7', '8', '15', '30', '43']
# 494 회차 : [5, 7, 8, 15, 30, 43] 저장 됨
# {495} 회차가 저장됩니다. ['4', '13', '22', '27', '34', '44']
# 495 회차 : [4, 13, 22, 27, 34, 44] 저장 됨
# {496} 회차가 저장됩니다. ['4', '13', '20', '29', '36', '41']
# 496 회차 : [4, 13, 20, 29, 36, 41] 저장 됨
# {497} 회차가 저장됩니다. ['19', '20', '23', '24', '43', '44']
# 497 회차 : [19, 20, 23, 24, 43, 44] 저장 됨
# {498} 회차가 저장됩니다. ['13', '14', '24', '32', '39', '41']
# 498 회차 : [13, 14, 24, 32, 39, 41] 저장 됨
# {499} 회차가 저장됩니다. ['5', '20', '23', '27', '35', '40']
# 499 회차 : [5, 20, 23, 27, 35, 40] 저장 됨
# {500} 회차가 저장됩니다. ['3', '4', '12', '20', '24', '34']
# 500 회차 : [3, 4, 12, 20, 24, 34] 저장 됨
# {501} 회차가 저장됩니다. ['1', '4', '10', '17', '31', '42']
# 501 회차 : [1, 4, 10, 17, 31, 42] 저장 됨
# {502} 회차가 저장됩니다. ['6', '22', '28', '32', '34', '40']
# 502 회차 : [6, 22, 28, 32, 34, 40] 저장 됨
# {503} 회차가 저장됩니다. ['1', '5', '27', '30', '34', '36']
# 503 회차 : [1, 5, 27, 30, 34, 36] 저장 됨
# {504} 회차가 저장됩니다. ['6', '14', '22', '26', '43', '44']
# 504 회차 : [6, 14, 22, 26, 43, 44] 저장 됨
# {505} 회차가 저장됩니다. ['7', '20', '22', '25', '38', '40']
# 505 회차 : [7, 20, 22, 25, 38, 40] 저장 됨
# {506} 회차가 저장됩니다. ['6', '9', '11', '22', '24', '30']
# 506 회차 : [6, 9, 11, 22, 24, 30] 저장 됨
# {507} 회차가 저장됩니다. ['12', '13', '32', '33', '40', '41']
# 507 회차 : [12, 13, 32, 33, 40, 41] 저장 됨
# {508} 회차가 저장됩니다. ['5', '27', '31', '34', '35', '43']
# 508 회차 : [5, 27, 31, 34, 35, 43] 저장 됨
# {509} 회차가 저장됩니다. ['12', '25', '29', '35', '42', '43']
# 509 회차 : [12, 25, 29, 35, 42, 43] 저장 됨
# {510} 회차가 저장됩니다. ['12', '29', '32', '33', '39', '40']
# 510 회차 : [12, 29, 32, 33, 39, 40] 저장 됨
# {511} 회차가 저장됩니다. ['3', '7', '14', '23', '26', '42']
# 511 회차 : [3, 7, 14, 23, 26, 42] 저장 됨
# {512} 회차가 저장됩니다. ['4', '5', '9', '13', '26', '27']
# 512 회차 : [4, 5, 9, 13, 26, 27] 저장 됨
# {513} 회차가 저장됩니다. ['5', '8', '21', '23', '27', '33']
# 513 회차 : [5, 8, 21, 23, 27, 33] 저장 됨
# {514} 회차가 저장됩니다. ['1', '15', '20', '26', '35', '42']
# 514 회차 : [1, 15, 20, 26, 35, 42] 저장 됨
# {515} 회차가 저장됩니다. ['2', '11', '12', '15', '23', '37']
# 515 회차 : [2, 11, 12, 15, 23, 37] 저장 됨
# {516} 회차가 저장됩니다. ['2', '8', '23', '41', '43', '44']
# 516 회차 : [2, 8, 23, 41, 43, 44] 저장 됨
# {517} 회차가 저장됩니다. ['1', '9', '12', '28', '36', '41']
# 517 회차 : [1, 9, 12, 28, 36, 41] 저장 됨
# {518} 회차가 저장됩니다. ['14', '23', '30', '32', '34', '38']
# 518 회차 : [14, 23, 30, 32, 34, 38] 저장 됨
# {519} 회차가 저장됩니다. ['6', '8', '13', '16', '30', '43']
# 519 회차 : [6, 8, 13, 16, 30, 43] 저장 됨
# {520} 회차가 저장됩니다. ['4', '22', '27', '28', '38', '40']
# 520 회차 : [4, 22, 27, 28, 38, 40] 저장 됨
# {521} 회차가 저장됩니다. ['3', '7', '18', '29', '32', '36']
# 521 회차 : [3, 7, 18, 29, 32, 36] 저장 됨
# {522} 회차가 저장됩니다. ['4', '5', '13', '14', '37', '41']
# 522 회차 : [4, 5, 13, 14, 37, 41] 저장 됨
# {523} 회차가 저장됩니다. ['1', '4', '37', '38', '40', '45']
# 523 회차 : [1, 4, 37, 38, 40, 45] 저장 됨
# {524} 회차가 저장됩니다. ['10', '11', '29', '38', '41', '45']
# 524 회차 : [10, 11, 29, 38, 41, 45] 저장 됨
# {525} 회차가 저장됩니다. ['11', '23', '26', '29', '39', '44']
# 525 회차 : [11, 23, 26, 29, 39, 44] 저장 됨
# {526} 회차가 저장됩니다. ['7', '14', '17', '20', '35', '39']
# 526 회차 : [7, 14, 17, 20, 35, 39] 저장 됨
# {527} 회차가 저장됩니다. ['1', '12', '22', '32', '33', '42']
# 527 회차 : [1, 12, 22, 32, 33, 42] 저장 됨
# {528} 회차가 저장됩니다. ['5', '17', '25', '31', '39', '40']
# ...
# 849 회차 : [5, 13, 17, 29, 34, 39] 저장 됨
# {850} 회차가 저장됩니다. ['16', '20', '24', '28', '36', '39']
# 850 회차 : [16, 20, 24, 28, 36, 39] 저장 됨
# {851} 회차가 저장됩니다. ['14', '18', '22', '26', '31', '44']
# 851 회차 : [14, 18, 22, 26, 31, 44] 저장 됨
# {852} 회차가 저장됩니다. ['11', '17', '28', '30', '33', '35']
# 852 회차 : [11, 17, 28, 30, 33, 35] 저장 됨
# {853} 회차가 저장됩니다. ['2', '8', '23', '26', '27', '44']
# 853 회차 : [2, 8, 23, 26, 27, 44] 저장 됨
# {854} 회차가 저장됩니다. ['20', '25', '31', '32', '36', '43']
# 854 회차 : [20, 25, 31, 32, 36, 43] 저장 됨
# {855} 회차가 저장됩니다. ['8', '15', '17', '19', '43', '44']
# 855 회차 : [8, 15, 17, 19, 43, 44] 저장 됨
# {856} 회차가 저장됩니다. ['10', '24', '40', '41', '43', '44']
# 856 회차 : [10, 24, 40, 41, 43, 44] 저장 됨
# {857} 회차가 저장됩니다. ['6', '10', '16', '28', '34', '38']
# 857 회차 : [6, 10, 16, 28, 34, 38] 저장 됨
# {858} 회차가 저장됩니다. ['9', '13', '32', '38', '39', '43']
# 858 회차 : [9, 13, 32, 38, 39, 43] 저장 됨
# {859} 회차가 저장됩니다. ['8', '22', '35', '38', '39', '41']
# 859 회차 : [8, 22, 35, 38, 39, 41] 저장 됨
# {860} 회차가 저장됩니다. ['4', '8', '18', '25', '27', '32']
# 860 회차 : [4, 8, 18, 25, 27, 32] 저장 됨
# {861} 회차가 저장됩니다. ['11', '17', '19', '21', '22', '25']
# 861 회차 : [11, 17, 19, 21, 22, 25] 저장 됨
# {862} 회차가 저장됩니다. ['10', '34', '38', '40', '42', '43']
# 862 회차 : [10, 34, 38, 40, 42, 43] 저장 됨
# {863} 회차가 저장됩니다. ['16', '21', '28', '35', '39', '43']
# 863 회차 : [16, 21, 28, 35, 39, 43] 저장 됨
# {864} 회차가 저장됩니다. ['3', '7', '10', '13', '25', '36']
# 864 회차 : [3, 7, 10, 13, 25, 36] 저장 됨
# {865} 회차가 저장됩니다. ['3', '15', '22', '32', '33', '45']
# 865 회차 : [3, 15, 22, 32, 33, 45] 저장 됨
# {866} 회차가 저장됩니다. ['9', '15', '29', '34', '37', '39']
# 866 회차 : [9, 15, 29, 34, 37, 39] 저장 됨
# {867} 회차가 저장됩니다. ['14', '17', '19', '22', '24', '40']
# 867 회차 : [14, 17, 19, 22, 24, 40] 저장 됨
# {868} 회차가 저장됩니다. ['12', '17', '28', '41', '43', '44']
# 868 회차 : [12, 17, 28, 41, 43, 44] 저장 됨
# {869} 회차가 저장됩니다. ['2', '6', '20', '27', '37', '39']
# 869 회차 : [2, 6, 20, 27, 37, 39] 저장 됨
# {870} 회차가 저장됩니다. ['21', '25', '30', '32', '40', '42']
# 870 회차 : [21, 25, 30, 32, 40, 42] 저장 됨
# {871} 회차가 저장됩니다. ['2', '6', '12', '26', '30', '34']
# 871 회차 : [2, 6, 12, 26, 30, 34] 저장 됨
# {872} 회차가 저장됩니다. ['2', '4', '30', '32', '33', '43']
# 872 회차 : [2, 4, 30, 32, 33, 43] 저장 됨
# {873} 회차가 저장됩니다. ['3', '5', '12', '13', '33', '39']
# 873 회차 : [3, 5, 12, 13, 33, 39] 저장 됨
# {874} 회차가 저장됩니다. ['1', '15', '19', '23', '28', '42']
# 874 회차 : [1, 15, 19, 23, 28, 42] 저장 됨
# {875} 회차가 저장됩니다. ['19', '22', '30', '34', '39', '44']
# 875 회차 : [19, 22, 30, 34, 39, 44] 저장 됨
# {876} 회차가 저장됩니다. ['5', '16', '21', '26', '34', '42']
# 876 회차 : [5, 16, 21, 26, 34, 42] 저장 됨
# {877} 회차가 저장됩니다. ['5', '17', '18', '22', '23', '43']
# 877 회차 : [5, 17, 18, 22, 23, 43] 저장 됨
# {878} 회차가 저장됩니다. ['2', '6', '11', '16', '25', '31']
# 878 회차 : [2, 6, 11, 16, 25, 31] 저장 됨
# {879} 회차가 저장됩니다. ['1', '4', '10', '14', '15', '35']
# 879 회차 : [1, 4, 10, 14, 15, 35] 저장 됨
# {880} 회차가 저장됩니다. ['7', '17', '19', '23', '24', '45']
# 880 회차 : [7, 17, 19, 23, 24, 45] 저장 됨
# {881} 회차가 저장됩니다. ['4', '18', '20', '26', '27', '32']
# 881 회차 : [4, 18, 20, 26, 27, 32] 저장 됨
# {882} 회차가 저장됩니다. ['18', '34', '39', '43', '44', '45']
# 882 회차 : [18, 34, 39, 43, 44, 45] 저장 됨
# {883} 회차가 저장됩니다. ['9', '18', '32', '33', '37', '44']
# 883 회차 : [9, 18, 32, 33, 37, 44] 저장 됨
# {884} 회차가 저장됩니다. ['4', '14', '23', '28', '37', '45']
# 884 회차 : [4, 14, 23, 28, 37, 45] 저장 됨
# {885} 회차가 저장됩니다. ['1', '3', '24', '27', '39', '45']
# 885 회차 : [1, 3, 24, 27, 39, 45] 저장 됨
# {886} 회차가 저장됩니다. ['19', '23', '28', '37', '42', '45']
# 886 회차 : [19, 23, 28, 37, 42, 45] 저장 됨
# {887} 회차가 저장됩니다. ['8', '14', '17', '27', '36', '45']
# 887 회차 : [8, 14, 17, 27, 36, 45] 저장 됨
# {888} 회차가 저장됩니다. ['3', '7', '12', '31', '34', '38']
# 888 회차 : [3, 7, 12, 31, 34, 38] 저장 됨
# {889} 회차가 저장됩니다. ['3', '13', '29', '38', '39', '42']
# 889 회차 : [3, 13, 29, 38, 39, 42] 저장 됨
# {890} 회차가 저장됩니다. ['1', '4', '14', '18', '29', '37']
# 890 회차 : [1, 4, 14, 18, 29, 37] 저장 됨
# {891} 회차가 저장됩니다. ['9', '13', '28', '31', '39', '41']
# 891 회차 : [9, 13, 28, 31, 39, 41] 저장 됨
# {892} 회차가 저장됩니다. ['4', '9', '17', '18', '26', '42']
# 892 회차 : [4, 9, 17, 18, 26, 42] 저장 됨
# {893} 회차가 저장됩니다. ['1', '15', '17', '23', '25', '41']
# 893 회차 : [1, 15, 17, 23, 25, 41] 저장 됨
# {894} 회차가 저장됩니다. ['19', '32', '37', '40', '41', '43']
# 894 회차 : [19, 32, 37, 40, 41, 43] 저장 됨
# {895} 회차가 저장됩니다. ['16', '26', '31', '38', '39', '41']
# 895 회차 : [16, 26, 31, 38, 39, 41] 저장 됨
# {896} 회차가 저장됩니다. ['5', '12', '25', '26', '38', '45']
# 896 회차 : [5, 12, 25, 26, 38, 45] 저장 됨
# {897} 회차가 저장됩니다. ['6', '7', '12', '22', '26', '36']
# 897 회차 : [6, 7, 12, 22, 26, 36] 저장 됨
# {898} 회차가 저장됩니다. ['18', '21', '28', '35', '37', '42']
# 898 회차 : [18, 21, 28, 35, 37, 42] 저장 됨
# {899} 회차가 저장됩니다. ['8', '19', '20', '21', '33', '39']
# 899 회차 : [8, 19, 20, 21, 33, 39] 저장 됨
# {900} 회차가 저장됩니다. ['7', '13', '16', '18', '35', '38']
# 900 회차 : [7, 13, 16, 18, 35, 38] 저장 됨
# {901} 회차가 저장됩니다. ['5', '18', '20', '23', '30', '34']
# 901 회차 : [5, 18, 20, 23, 30, 34] 저장 됨
# {902} 회차가 저장됩니다. ['7', '19', '23', '24', '36', '39']
# 902 회차 : [7, 19, 23, 24, 36, 39] 저장 됨
# {903} 회차가 저장됩니다. ['2', '15', '16', '21', '22', '28']
# 903 회차 : [2, 15, 16, 21, 22, 28] 저장 됨
# {904} 회차가 저장됩니다. ['2', '6', '8', '26', '43', '45']
# 904 회차 : [2, 6, 8, 26, 43, 45] 저장 됨
# {905} 회차가 저장됩니다. ['3', '4', '16', '27', '38', '40']
# 905 회차 : [3, 4, 16, 27, 38, 40] 저장 됨
# {906} 회차가 저장됩니다. ['2', '5', '14', '28', '31', '32']
# 906 회차 : [2, 5, 14, 28, 31, 32] 저장 됨
# {907} 회차가 저장됩니다. ['21', '27', '29', '38', '40', '44']
# 907 회차 : [21, 27, 29, 38, 40, 44] 저장 됨
# {908} 회차가 저장됩니다. ['3', '16', '21', '22', '23', '44']
# 908 회차 : [3, 16, 21, 22, 23, 44] 저장 됨
# {909} 회차가 저장됩니다. ['7', '24', '29', '30', '34', '35']
# 909 회차 : [7, 24, 29, 30, 34, 35] 저장 됨
# {910} 회차가 저장됩니다. ['1', '11', '17', '27', '35', '39']
# 910 회차 : [1, 11, 17, 27, 35, 39] 저장 됨
# {911} 회차가 저장됩니다. ['4', '5', '12', '14', '32', '42']
# 911 회차 : [4, 5, 12, 14, 32, 42] 저장 됨
# {912} 회차가 저장됩니다. ['5', '8', '18', '21', '22', '38']
# 912 회차 : [5, 8, 18, 21, 22, 38] 저장 됨
# {913} 회차가 저장됩니다. ['6', '14', '16', '21', '27', '37']
# 913 회차 : [6, 14, 16, 21, 27, 37] 저장 됨
# {914} 회차가 저장됩니다. ['16', '19', '24', '33', '42', '44']
# 914 회차 : [16, 19, 24, 33, 42, 44] 저장 됨
# {915} 회차가 저장됩니다. ['2', '6', '11', '13', '22', '37']
# 915 회차 : [2, 6, 11, 13, 22, 37] 저장 됨
# {916} 회차가 저장됩니다. ['6', '21', '22', '32', '35', '36']
# 916 회차 : [6, 21, 22, 32, 35, 36] 저장 됨
# {917} 회차가 저장됩니다. ['1', '3', '23', '24', '27', '43']
# 917 회차 : [1, 3, 23, 24, 27, 43] 저장 됨
# {918} 회차가 저장됩니다. ['7', '11', '12', '31', '33', '38']
# 918 회차 : [7, 11, 12, 31, 33, 38] 저장 됨
# {919} 회차가 저장됩니다. ['9', '14', '17', '18', '42', '44']
# 919 회차 : [9, 14, 17, 18, 42, 44] 저장 됨
# {920} 회차가 저장됩니다. ['2', '3', '26', '33', '34', '43']
# 920 회차 : [2, 3, 26, 33, 34, 43] 저장 됨
# {921} 회차가 저장됩니다. ['5', '7', '12', '22', '28', '41']
# 921 회차 : [5, 7, 12, 22, 28, 41] 저장 됨
# {922} 회차가 저장됩니다. ['2', '6', '13', '17', '27', '43']
# 922 회차 : [2, 6, 13, 17, 27, 43] 저장 됨
# {923} 회차가 저장됩니다. ['3', '17', '18', '23', '36', '41']
# 923 회차 : [3, 17, 18, 23, 36, 41] 저장 됨
# {924} 회차가 저장됩니다. ['3', '11', '34', '42', '43', '44']
# 924 회차 : [3, 11, 34, 42, 43, 44] 저장 됨
# {925} 회차가 저장됩니다. ['13', '24', '32', '34', '39', '42']
# 925 회차 : [13, 24, 32, 34, 39, 42] 저장 됨
# {926} 회차가 저장됩니다. ['10', '16', '18', '20', '25', '31']
# 926 회차 : [10, 16, 18, 20, 25, 31] 저장 됨
# {927} 회차가 저장됩니다. ['4', '15', '22', '38', '41', '43']
# 927 회차 : [4, 15, 22, 38, 41, 43] 저장 됨
# {928} 회차가 저장됩니다. ['3', '4', '10', '20', '28', '44']
# 928 회차 : [3, 4, 10, 20, 28, 44] 저장 됨
# {929} 회차가 저장됩니다. ['7', '9', '12', '15', '19', '23']
# 929 회차 : [7, 9, 12, 15, 19, 23] 저장 됨
# {930} 회차가 저장됩니다. ['8', '21', '25', '38', '39', '44']
# 930 회차 : [8, 21, 25, 38, 39, 44] 저장 됨
# {931} 회차가 저장됩니다. ['14', '15', '23', '25', '35', '43']
# 931 회차 : [14, 15, 23, 25, 35, 43] 저장 됨
# {932} 회차가 저장됩니다. ['1', '6', '15', '36', '37', '38']
# 932 회차 : [1, 6, 15, 36, 37, 38] 저장 됨
# {933} 회차가 저장됩니다. ['23', '27', '29', '31', '36', '45']
# 933 회차 : [23, 27, 29, 31, 36, 45] 저장 됨
# {934} 회차가 저장됩니다. ['1', '3', '30', '33', '36', '39']
# 934 회차 : [1, 3, 30, 33, 36, 39] 저장 됨
# {935} 회차가 저장됩니다. ['4', '10', '20', '32', '38', '44']
# 935 회차 : [4, 10, 20, 32, 38, 44] 저장 됨
# {936} 회차가 저장됩니다. ['7', '11', '13', '17', '18', '29']
# 936 회차 : [7, 11, 13, 17, 18, 29] 저장 됨
# {937} 회차가 저장됩니다. ['2', '10', '13', '22', '29', '40']
# 937 회차 : [2, 10, 13, 22, 29, 40] 저장 됨
# {938} 회차가 저장됩니다. ['4', '8', '10', '16', '31', '36']
# 938 회차 : [4, 8, 10, 16, 31, 36] 저장 됨
# {939} 회차가 저장됩니다. ['4', '11', '28', '39', '42', '45']
# 939 회차 : [4, 11, 28, 39, 42, 45] 저장 됨
# {940} 회차가 저장됩니다. ['3', '15', '20', '22', '24', '41']
# 940 회차 : [3, 15, 20, 22, 24, 41] 저장 됨
# {941} 회차가 저장됩니다. ['12', '14', '25', '27', '39', '40']
# 941 회차 : [12, 14, 25, 27, 39, 40] 저장 됨
# {942} 회차가 저장됩니다. ['10', '12', '18', '35', '42', '43']
# 942 회차 : [10, 12, 18, 35, 42, 43] 저장 됨
# {943} 회차가 저장됩니다. ['1', '8', '13', '36', '44', '45']
# 943 회차 : [1, 8, 13, 36, 44, 45] 저장 됨
# {944} 회차가 저장됩니다. ['2', '13', '16', '19', '32', '33']
# 944 회차 : [2, 13, 16, 19, 32, 33] 저장 됨
# {945} 회차가 저장됩니다. ['9', '10', '15', '30', '33', '37']
# 945 회차 : [9, 10, 15, 30, 33, 37] 저장 됨
# {946} 회차가 저장됩니다. ['9', '18', '19', '30', '34', '40']
# 946 회차 : [9, 18, 19, 30, 34, 40] 저장 됨
# {947} 회차가 저장됩니다. ['3', '8', '17', '20', '27', '35']
# 947 회차 : [3, 8, 17, 20, 27, 35] 저장 됨
# {948} 회차가 저장됩니다. ['13', '18', '30', '31', '38', '41']
# 948 회차 : [13, 18, 30, 31, 38, 41] 저장 됨
# {949} 회차가 저장됩니다. ['14', '21', '35', '36', '40', '44']
# 949 회차 : [14, 21, 35, 36, 40, 44] 저장 됨
# {950} 회차가 저장됩니다. ['3', '4', '15', '22', '28', '40']
# 950 회차 : [3, 4, 15, 22, 28, 40] 저장 됨
# {951} 회차가 저장됩니다. ['2', '12', '30', '31', '39', '43']
# 951 회차 : [2, 12, 30, 31, 39, 43] 저장 됨
# {952} 회차가 저장됩니다. ['4', '12', '22', '24', '33', '41']
# 952 회차 : [4, 12, 22, 24, 33, 41] 저장 됨
# {953} 회차가 저장됩니다. ['7', '9', '22', '27', '37', '42']
# 953 회차 : [7, 9, 22, 27, 37, 42] 저장 됨
# {954} 회차가 저장됩니다. ['1', '9', '26', '28', '30', '41']
# 954 회차 : [1, 9, 26, 28, 30, 41] 저장 됨
# {955} 회차가 저장됩니다. ['4', '9', '23', '26', '29', '33']
# 955 회차 : [4, 9, 23, 26, 29, 33] 저장 됨
# {956} 회차가 저장됩니다. ['10', '11', '20', '21', '25', '41']
# 956 회차 : [10, 11, 20, 21, 25, 41] 저장 됨
# {957} 회차가 저장됩니다. ['4', '15', '24', '35', '36', '40']
# 957 회차 : [4, 15, 24, 35, 36, 40] 저장 됨
# {958} 회차가 저장됩니다. ['2', '9', '10', '16', '35', '37']
# 958 회차 : [2, 9, 10, 16, 35, 37] 저장 됨
# {959} 회차가 저장됩니다. ['1', '14', '15', '24', '40', '41']
# 959 회차 : [1, 14, 15, 24, 40, 41] 저장 됨
# {960} 회차가 저장됩니다. ['2', '18', '24', '30', '32', '45']
# 960 회차 : [2, 18, 24, 30, 32, 45] 저장 됨
# {961} 회차가 저장됩니다. ['11', '20', '29', '31', '33', '42']
# 961 회차 : [11, 20, 29, 31, 33, 42] 저장 됨
# {962} 회차가 저장됩니다. ['1', '18', '28', '31', '34', '43']
# 962 회차 : [1, 18, 28, 31, 34, 43] 저장 됨
# {963} 회차가 저장됩니다. ['6', '12', '19', '23', '34', '42']
# 963 회차 : [6, 12, 19, 23, 34, 42] 저장 됨
# {964} 회차가 저장됩니다. ['6', '21', '36', '38', '39', '43']
# 964 회차 : [6, 21, 36, 38, 39, 43] 저장 됨
# {965} 회차가 저장됩니다. ['2', '13', '25', '28', '29', '36']
# 965 회차 : [2, 13, 25, 28, 29, 36] 저장 됨
# {966} 회차가 저장됩니다. ['1', '21', '25', '29', '34', '37']
# 966 회차 : [1, 21, 25, 29, 34, 37] 저장 됨
# {967} 회차가 저장됩니다. ['1', '6', '13', '37', '38', '40']
# 967 회차 : [1, 6, 13, 37, 38, 40] 저장 됨
# {968} 회차가 저장됩니다. ['2', '5', '12', '14', '24', '39']
# 968 회차 : [2, 5, 12, 14, 24, 39] 저장 됨
# {969} 회차가 저장됩니다. ['3', '9', '10', '29', '40', '45']
# 969 회차 : [3, 9, 10, 29, 40, 45] 저장 됨
# {970} 회차가 저장됩니다. ['9', '11', '16', '21', '28', '36']
# 970 회차 : [9, 11, 16, 21, 28, 36] 저장 됨
# {971} 회차가 저장됩니다. ['2', '6', '17', '18', '21', '26']
# 971 회차 : [2, 6, 17, 18, 21, 26] 저장 됨
# {972} 회차가 저장됩니다. ['3', '6', '17', '23', '37', '39']
# 972 회차 : [3, 6, 17, 23, 37, 39] 저장 됨
# {973} 회차가 저장됩니다. ['22', '26', '31', '37', '41', '42']
# 973 회차 : [22, 26, 31, 37, 41, 42] 저장 됨
# {974} 회차가 저장됩니다. ['1', '2', '11', '16', '39', '44']
# 974 회차 : [1, 2, 11, 16, 39, 44] 저장 됨
# {975} 회차가 저장됩니다. ['7', '8', '9', '17', '22', '24']
# 975 회차 : [7, 8, 9, 17, 22, 24] 저장 됨
# {976} 회차가 저장됩니다. ['4', '12', '14', '25', '35', '37']
# 976 회차 : [4, 12, 14, 25, 35, 37] 저장 됨
# {977} 회차가 저장됩니다. ['2', '9', '10', '14', '22', '44']
# 977 회차 : [2, 9, 10, 14, 22, 44] 저장 됨
# {978} 회차가 저장됩니다. ['1', '7', '15', '32', '34', '42']
# 978 회차 : [1, 7, 15, 32, 34, 42] 저장 됨
# {979} 회차가 저장됩니다. ['7', '11', '16', '21', '27', '33']
# 979 회차 : [7, 11, 16, 21, 27, 33] 저장 됨
# {980} 회차가 저장됩니다. ['3', '13', '16', '23', '24', '35']
# 980 회차 : [3, 13, 16, 23, 24, 35] 저장 됨
# {981} 회차가 저장됩니다. ['27', '36', '37', '41', '43', '45']
# 981 회차 : [27, 36, 37, 41, 43, 45] 저장 됨
# {982} 회차가 저장됩니다. ['5', '7', '13', '20', '21', '44']
# 982 회차 : [5, 7, 13, 20, 21, 44] 저장 됨
# {983} 회차가 저장됩니다. ['13', '23', '26', '31', '35', '43']
# 983 회차 : [13, 23, 26, 31, 35, 43] 저장 됨
# {984} 회차가 저장됩니다. ['3', '10', '23', '35', '36', '37']
# 984 회차 : [3, 10, 23, 35, 36, 37] 저장 됨
# {985} 회차가 저장됩니다. ['17', '21', '23', '30', '34', '44']
# 985 회차 : [17, 21, 23, 30, 34, 44] 저장 됨
# {986} 회차가 저장됩니다. ['7', '10', '16', '28', '41', '42']
# 986 회차 : [7, 10, 16, 28, 41, 42] 저장 됨
# {987} 회차가 저장됩니다. ['2', '4', '15', '23', '29', '38']
# 987 회차 : [2, 4, 15, 23, 29, 38] 저장 됨
# {988} 회차가 저장됩니다. ['2', '13', '20', '30', '31', '41']
# 988 회차 : [2, 13, 20, 30, 31, 41] 저장 됨
# {989} 회차가 저장됩니다. ['17', '18', '21', '27', '29', '33']
# 989 회차 : [17, 18, 21, 27, 29, 33] 저장 됨
# {990} 회차가 저장됩니다. ['2', '4', '25', '26', '36', '37']
# 990 회차 : [2, 4, 25, 26, 36, 37] 저장 됨
# {991} 회차가 저장됩니다. ['13', '18', '25', '31', '33', '44']
# 991 회차 : [13, 18, 25, 31, 33, 44] 저장 됨
# {992} 회차가 저장됩니다. ['12', '20', '26', '33', '44', '45']
# 992 회차 : [12, 20, 26, 33, 44, 45] 저장 됨
# {993} 회차가 저장됩니다. ['6', '14', '16', '18', '24', '42']
# 993 회차 : [6, 14, 16, 18, 24, 42] 저장 됨
# {994} 회차가 저장됩니다. ['1', '3', '8', '24', '27', '35']
# 994 회차 : [1, 3, 8, 24, 27, 35] 저장 됨
# {995} 회차가 저장됩니다. ['1', '4', '13', '29', '38', '39']
# 995 회차 : [1, 4, 13, 29, 38, 39] 저장 됨
# {996} 회차가 저장됩니다. ['6', '11', '15', '24', '32', '39']
# 996 회차 : [6, 11, 15, 24, 32, 39] 저장 됨
# {997} 회차가 저장됩니다. ['4', '7', '14', '16', '24', '44']
# 997 회차 : [4, 7, 14, 16, 24, 44] 저장 됨
# {998} 회차가 저장됩니다. ['13', '17', '18', '20', '42', '45']
# 998 회차 : [13, 17, 18, 20, 42, 45] 저장 됨
# {999} 회차가 저장됩니다. ['1', '3', '9', '14', '18', '28']
# 999 회차 : [1, 3, 9, 14, 18, 28] 저장 됨
# {1000} 회차가 저장됩니다. ['2', '8', '19', '22', '32', '42']
# 1000 회차 : [2, 8, 19, 22, 32, 42] 저장 됨
# {1001} 회차가 저장됩니다. ['6', '10', '12', '14', '20', '42']
# 1001 회차 : [6, 10, 12, 14, 20, 42] 저장 됨
# {1002} 회차가 저장됩니다. ['17', '25', '33', '35', '38', '45']
# 1002 회차 : [17, 25, 33, 35, 38, 45] 저장 됨
# {1003} 회차가 저장됩니다. ['1', '4', '29', '39', '43', '45']
# 1003 회차 : [1, 4, 29, 39, 43, 45] 저장 됨
# {1004} 회차가 저장됩니다. ['7', '15', '30', '37', '39', '44']
# 1004 회차 : [7, 15, 30, 37, 39, 44] 저장 됨
# {1005} 회차가 저장됩니다. ['8', '13', '18', '24', '27', '29']
# 1005 회차 : [8, 13, 18, 24, 27, 29] 저장 됨
# {1006} 회차가 저장됩니다. ['8', '11', '15', '16', '17', '37']
# 1006 회차 : [8, 11, 15, 16, 17, 37] 저장 됨
# {1007} 회차가 저장됩니다. ['8', '11', '16', '19', '21', '25']
# 1007 회차 : [8, 11, 16, 19, 21, 25] 저장 됨
# {1008} 회차가 저장됩니다. ['9', '11', '30', '31', '41', '44']
# 1008 회차 : [9, 11, 30, 31, 41, 44] 저장 됨
# {1009} 회차가 저장됩니다. ['15', '23', '29', '34', '40', '44']
# 1009 회차 : [15, 23, 29, 34, 40, 44] 저장 됨
# {1010} 회차가 저장됩니다. ['9', '12', '15', '25', '34', '36']
# 1010 회차 : [9, 12, 15, 25, 34, 36] 저장 됨
# {1011} 회차가 저장됩니다. ['1', '9', '12', '26', '35', '38']
# 1011 회차 : [1, 9, 12, 26, 35, 38] 저장 됨
# {1012} 회차가 저장됩니다. ['5', '11', '18', '20', '35', '45']
# 1012 회차 : [5, 11, 18, 20, 35, 45] 저장 됨
# {1013} 회차가 저장됩니다. ['21', '22', '26', '34', '36', '41']
# 1013 회차 : [21, 22, 26, 34, 36, 41] 저장 됨
# {1014} 회차가 저장됩니다. ['3', '11', '14', '18', '26', '27']
# 1014 회차 : [3, 11, 14, 18, 26, 27] 저장 됨
# {1015} 회차가 저장됩니다. ['14', '23', '31', '33', '37', '40']
# 1015 회차 : [14, 23, 31, 33, 37, 40] 저장 됨
# {1016} 회차가 저장됩니다. ['15', '26', '28', '34', '41', '42']
# 1016 회차 : [15, 26, 28, 34, 41, 42] 저장 됨
# {1017} 회차가 저장됩니다. ['12', '18', '22', '23', '30', '34']
# 1017 회차 : [12, 18, 22, 23, 30, 34] 저장 됨
# {1018} 회차가 저장됩니다. ['3', '19', '21', '25', '37', '45']
# 1018 회차 : [3, 19, 21, 25, 37, 45] 저장 됨
# {1019} 회차가 저장됩니다. ['1', '4', '13', '17', '34', '39']
# 1019 회차 : [1, 4, 13, 17, 34, 39] 저장 됨
# {1020} 회차가 저장됩니다. ['12', '27', '29', '38', '41', '45']
# 1020 회차 : [12, 27, 29, 38, 41, 45] 저장 됨
# {1021} 회차가 저장됩니다. ['12', '15', '17', '24', '29', '45']
# 1021 회차 : [12, 15, 17, 24, 29, 45] 저장 됨
# {1022} 회차가 저장됩니다. ['5', '6', '11', '29', '42', '45']
# 1022 회차 : [5, 6, 11, 29, 42, 45] 저장 됨
# {1023} 회차가 저장됩니다. ['10', '14', '16', '18', '29', '35']
# 1023 회차 : [10, 14, 16, 18, 29, 35] 저장 됨
# {1024} 회차가 저장됩니다. ['9', '18', '20', '22', '38', '44']
# 1024 회차 : [9, 18, 20, 22, 38, 44] 저장 됨

# %%
mydb = mysql.connector.connect(host = '192.168.35.159', port = '3306', user='', password = '')
mydb

table_name = 'lot_num'      # table name 지정

mycursor = mydb.cursor(buffered = True)


mycursor.execute('use lotto_db')

mycursor.execute('show tables')
mycursor.fetchall()

mycursor.execute('desc lot_num')
mycursor.fetchall()
# mycursor.execute('drop table lot_num')
# Out:
# [('ID', 'int(11)', 'NO', 'PRI', None, 'auto_increment'),
#  ('NUM1', 'int(11)', 'NO', '', None, ''),
#  ('NUM2', 'int(11)', 'NO', '', None, ''),
#  ('NUM3', 'int(11)', 'NO', '', None, ''),
#  ('NUM4', 'int(11)', 'NO', '', None, ''),
#  ('NUM5', 'int(11)', 'NO', '', None, ''),
#  ('NUM6', 'int(11)', 'NO', '', None, '')]

# %%
mydb.close()

# %%
driver.close()

# %%
mycursor.execute('SELECT * FROM {} ORDER BY ID DESC LIMIT 1'.format(table_name))
list(mycursor.fetchall()[0][1:])
# Out:
# [9, 18, 20, 22, 38, 44]
